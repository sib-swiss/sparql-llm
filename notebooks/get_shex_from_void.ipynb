# %% [markdown]
# Generate OWL ontology from VoID profile
#
# TODO: this way? But VoID is missing data properties like `rdfs:label`
#
# ```turtle
# up:Gene rdfs:label xsd:string ;
#   up:encode up:Protein .
# ```

# %%
import requests
from rdflib import Graph


# TODO: build decent SHACL shapes?

query = """prefix void:     <http://rdfs.org/ns/void#>
prefix dcat:     <http://www.w3.org/ns/dcat#>
prefix dct:      <http://purl.org/dc/terms/>
prefix sx:       <http://shex.io/ns/shex#>
prefix void_ext: <http://ldf.fi/void-ext#>
prefix xsd:      <http://www.w3.org/2001/XMLSchema#>
prefix up:       <http://purl.uniprot.org/core/>
prefix faldo:    <http://biohackathon.org/resource/faldo#>
prefix sm:       <http://shex.io/ns/shapeMap#>
prefix rdf:      <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

CONSTRUCT {

    # ?shape a sx:Shape .
    # ?shape sx:expressions [
      a sx:TripleConstraint ;
      sx:predicate ?property ;
      sx:valueExpr [
       sx:min ?minDtCardinality ;
       sx:max ?maxDtCardinality ;
       sx:datatype ?datatype
     ]
   ] .
   _:shapeMap a sm:ShapeMap ;
     sm:associations (
        [ sm:node [
        sm:focus rdf:subject ;
        rdf:predicate rdf:type ;
        sm:object ?class
        ] ;
       sm:shape ?shape
       ]
    )
} WHERE {

    # ?ns void:classPartition ?cp .
    # ?cp void:class ?class .
    BIND(IRI(CONCAT(STR(?ns),'-shape-',MD5(STR(?class)))) AS ?shape) .
    # ?cp void:propertyPartition ?pp .
    # ?pp void:property ?property .
#    BIND(BNODE() AS ?shProperty)
    OPTIONAL {
        # ?pp void_ext:datatypePartition ?dp .
        # ?dp void_ext:datatype ?datatype .
    }
    OPTIONAL {
        #Todo provide this count in our service description.
        # ?cp void_ext:distinctIRIReferenceSubjects ?distinctSubjectIri .
        # ?pp void:triples ?dtTriples .
        FILTER(?dtTriples = ?distinctSubjectIri)
        BIND(1 AS ?minDtCardinality)
        BIND(1 AS ?maxDtCardinality)
    }
    OPTIONAL {
        # ?pp void:classPartition ?ppcp .
        # ?ppcp void:class ?propertyClass .
    }
}"""

response = requests.post(
    "https://sparql.uniprot.org/sparql/",
    headers={
        "Accept": "text/turtle"
    },
    data={
        "query": query
    },
    timeout=60,
)
response.raise_for_status()
g = Graph()
g.bind("faldo", "http://biohackathon.org/resource/faldo#")
g.bind("up", "http://purl.uniprot.org/core/")

g.parse(data=response.text.replace("[ ],", ""), format="turtle")
# NOTE: replace is a hack to remove useless blank nodes

# print(response.text)
print(g.serialize(format="turtle"))
print(len(g))
# Out:
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @prefix faldo: <http://biohackathon.org/resource/faldo#> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix ns1: <http://shex.io/ns/shapeMap#> .
# @prefix ns2: <http://shex.io/ns/shex#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix schema: <https://schema.org/> .
# @prefix sh: <http://www.w3.org/ns/shacl#> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
# @prefix up: <http://purl.uniprot.org/core/> .
# @prefix vann: <http://purl.org/vocab/vann/> .
# @prefix void: <http://rdfs.org/ns/void#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_chebi-shape-3b46ba4c0adbd1be8c4d87b306c67b25> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate owl:inverseOf ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_citationmapping-shape-89df24df35df8882616112ab6a78df83> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate owl:imports ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_citationmapping-shape-e0f099c7f2ad6d53142226f1411a1dbb> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_citations-shape-89df24df35df8882616112ab6a78df83> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate owl:imports ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_core-shape-17b4b079e0bbed1b382b55d62fcf73ea> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate owl:distinctMembers ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_core-shape-e70106cf33c4a8d55f7031297af9b64e> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate owl:oneOf ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_database-shape-89df24df35df8882616112ab6a78df83> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate owl:imports ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_diseases-shape-89df24df35df8882616112ab6a78df83> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate owl:imports ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_enzymes-shape-89df24df35df8882616112ab6a78df83> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate owl:imports ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_enzymes-shape-cb3417facb7298e39c95a88df965e375> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:label ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_go-shape-89df24df35df8882616112ab6a78df83> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate owl:imports ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_journal-shape-89df24df35df8882616112ab6a78df83> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate owl:imports ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_keywords-shape-89df24df35df8882616112ab6a78df83> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate owl:imports ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_locations-shape-89df24df35df8882616112ab6a78df83> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate owl:imports ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_obsolete-shape-89df24df35df8882616112ab6a78df83> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate owl:imports ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_pathways-shape-89df24df35df8882616112ab6a78df83> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate owl:imports ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_proteomes-shape-89df24df35df8882616112ab6a78df83> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate owl:imports ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_proteomes-shape-dfeaa076c456882174ca4ec99ed8d070> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:name ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_taxonomy-shape-89df24df35df8882616112ab6a78df83> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate owl:imports ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_taxonomy-shape-dfeaa076c456882174ca4ec99ed8d070> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:name ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_tissues-shape-89df24df35df8882616112ab6a78df83> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate owl:imports ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniparc-shape-827483a1c735fb5923fdacb35c0051f9> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate skos:prefLabel ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniparc-shape-89df24df35df8882616112ab6a78df83> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate owl:imports ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniparc-shape-9b4fa9f729d19c51a8ea9c197fd44848> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:structuredNameType ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-2dbf6e5a4aa9c721c2fcfb6477484b3a> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:label ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-57650054ca7dce861eefd2c27d240119> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-5787c183698dabcbe3fb0297e94d561c> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:label ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-5b40ed546e81c4752eae0a0e96a0b8d4> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:name ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-6c992f2edf0d0d3ae55868a579fa119a> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-7e1b728ed44bdb12130967e449bf003b> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-7e278393af166e401d0160f436d4e955> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-89df24df35df8882616112ab6a78df83> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate owl:imports ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-90ff75f5516ef1aed804506904fef585> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:label ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-c05c1d2f52c6be3e33f066d767a5c687> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-dfeaa076c456882174ca4ec99ed8d070> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:label ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-fb035ac5b9698b766023a39c9e73b590> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniref-shape-89df24df35df8882616112ab6a78df83> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate owl:imports ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_chebi-shape-472ee8b9e92f00863f1b11929967a7fa> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate owl:inverseOf ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate owl:inverseOf ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_core-shape-9e2e8496ae88c482c6265ddae823cab6> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:isDefinedBy ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:label ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_go-shape-9ed2fb7d3b7985c23e788a879a4db9d7> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate owl:onProperty ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate owl:someValuesFrom ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_keywords-shape-6be100d081a438502013ba4e5fef3db7> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:database ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:label ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_locations-shape-6be100d081a438502013ba4e5fef3db7> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:database ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:label ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_proteomes-shape-36985cd5a5d275a1e69fd510e8a7680a> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:label ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:int ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_proteomes-shape-a093af1caacd11ea5f1cac09da3f805b> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:seeAlso ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_taxonomy-shape-7a49f5dd0954737e0f7e916a39e41c59> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:width ;
#             ns2:valueExpr [ ns2:datatype xsd:int ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:height ;
#             ns2:valueExpr [ ns2:datatype xsd:int ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniparc-shape-583efc6f2fa1e0db47dcd3fda52816a0> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate faldo:reference ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate faldo:position ;
#             ns2:valueExpr [ ns2:datatype xsd:int ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniparc-shape-b91777470c025260b15c204c6561f495> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate faldo:end ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate faldo:begin ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-05a5218ebd98669c461ff861cdbf3289> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-0e113072e4a8453c9f6b1c472de6fd41> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-26098b4e958939a726d3b5a45ec8881d> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-2c9ae183f10ed18a9d09d5827e03e64b> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-2cbb0d0b0002189e79e960f575fae3e2> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-3772236379da94aa16944dd3f19afb43> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-48700d3cd953ae01dd5dcfaf1d82f6ae> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-51fde6b603c4bdb87cf5ab7596b81875> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-859c4cbf6c9e4d7307bfb48f57ef997e> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-ba8dc4e6b6355d80549d81f1ff29ce07> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-bec878853bd184de3a3a69da2d06993c> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-cf5df24016e1127c34310613cef7d3db> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-e8b935a34267bdf03bb5d31a6e6a588a> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-f4c4cea1ff4625ae4d0170e2d7f95eb5> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:conflictingSequence ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_chebi-shape-9ed2fb7d3b7985c23e788a879a4db9d7> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate owl:onProperty ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate owl:someValuesFrom ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate owl:onProperty ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_core-shape-0b6c09b24f163eed6117b836adfe2441> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:label ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:isDefinedBy ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_core-shape-137c9dc1cb27b23cc8bf8dc3ec2d5c89> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdf:rest ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdf:first ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdf:first ;
#             ns2:valueExpr [ ns2:datatype xsd:float ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_core-shape-17624ea26f31de5e2bdd2b74809bb511> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:label ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:isDefinedBy ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_core-shape-6493ba7c426773f6bfdb9812b4068a95> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:label ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:isDefinedBy ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_database-shape-097dd304d445252fccbe3949d86a2abb> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate skos:exactMatch ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate foaf:primaryTopicOf ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate dcterms:identifier ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_enzymes-shape-097dd304d445252fccbe3949d86a2abb> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate foaf:primaryTopicOf ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate skos:exactMatch ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate dcterms:identifier ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_locations-shape-097dd304d445252fccbe3949d86a2abb> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate dcterms:identifier ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate foaf:primaryTopicOf ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate skos:exactMatch ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_pathways-shape-2081af8c45b177ab33633bc66cba1ab2> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:subClassOf ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate skos:narrower ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:label ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_rhea-shape-ad808933a855b5113f5840f343578761> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:label ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:subClassOf ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_sparql-examples-shape-89df24df35df8882616112ab6a78df83> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate owl:imports ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate sh:declare ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_tissues-shape-5787c183698dabcbe3fb0297e94d561c> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:seeAlso ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate skos:altLabel ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate skos:prefLabel ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-1706fefd0c85b5429f9076d017a18098> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:xeno ;
#             ns2:valueExpr [ ns2:datatype xsd:boolean ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:experiments ;
#             ns2:valueExpr [ ns2:datatype xsd:int ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:participant ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-17821ba21bbc7a6a3750544bd04ae21b> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-1b543a7608f6ac146954d535971498cb> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-27fa3b5b769de83067372850e7c7b216> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-2de2a994443bc5e080463fd0981b7274> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-36065e27b4975c2d4ceb5e64c7ddbe36> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-619c77745215aa2b12d271cddae7a430> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-6257b88c57891283d1f5a216cd387cd0> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:participant ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:xeno ;
#             ns2:valueExpr [ ns2:datatype xsd:boolean ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:experiments ;
#             ns2:valueExpr [ ns2:datatype xsd:int ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-6d59a27c709e4ca3dd0054a396525255> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-78554e2493cde742745505bf2550eb11> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:mass ;
#             ns2:valueExpr [ ns2:datatype xsd:int ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-7a20fdc8f287454d6fa110ca0c843780> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-7e37c98a80e6a4bf471aa4eb9a0ca3cd> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:mass ;
#             ns2:valueExpr [ ns2:datatype xsd:int ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-8202ce84078ae605b9c3eba187fc7d4f> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:conflictingSequence ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-84c9417ec568e10c2c679df5df8354cb> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-8c3c186386a62fb96fcb8e8e90f2b330> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-940b17962eb013e41b2e5f6cdbc9769a> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:certain ;
#             ns2:valueExpr [ ns2:datatype xsd:boolean ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:maximum ;
#             ns2:valueExpr [ ns2:datatype xsd:int ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-964933704efe9f9549a11ecee49c34ef> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-9b09b153a080dba5fd355e0793d3d69a> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:participant ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:experiments ;
#             ns2:valueExpr [ ns2:datatype xsd:int ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:xeno ;
#             ns2:valueExpr [ ns2:datatype xsd:boolean ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-b9a59d910bb1911e4d23f61bb7954a48> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:enzyme ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:alternativeName ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:recommendedName ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-bc5981c14bafc789cf284f6cd9b1689c> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-c3385de0f031e5166d7c7fa404c5e286> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-c5534b84c660e3989129e62725dced37> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:conflictingSequence ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-ca7b78231a196f7aeb9c0e41cad5a5c9> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:substitution ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-cb3417facb7298e39c95a88df965e375> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:catalyzedReaction ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:enzymeClass ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate skos:closeMatch ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-cbd6a50b4e6f54dcb49c3aea32ac401c> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-dc7a9d0a3e67725ea253a2c5cb4be03c> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-de50291c1aa40e1096a2acac4fdb0f43> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:seeAlso ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_chebi-shape-1ca745c9f8b3c9769bd64e64b306d5f2> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate owl:annotatedSource ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate owl:annotatedTarget ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate <http://www.geneontology.org/formats/oboInOwl#hasDbXref> ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate owl:annotatedProperty ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_core-shape-44424c25d1d25a2048890497c4856abd> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:isDefinedBy ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:seeAlso ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:label ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_core-shape-5d8d7b2654e10107de09e7646407caa5> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:seeAlso ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:label ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:isDefinedBy ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_core-shape-bb70ba4af84eba77e76cf90374b5e869> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:isDefinedBy ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:seeAlso ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:label ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_core-shape-c012b7ec75460f4fa419f022afb089eb> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:isDefinedBy ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:domain ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:range ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:label ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_core-shape-e3f70d87b893a7f3633bce037dee3ce2> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:seeAlso ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:label ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:isDefinedBy ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_locations-shape-d2abaf94fcc81e0160a2a35d866f67d4> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:subClassOf ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:alias ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate skos:prefLabel ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_proteomes-shape-871b8ecaf1f0928b22c672f0eedcbab1> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:pages ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:date ;
#             ns2:valueExpr [ ns2:datatype xsd:date ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:title ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:author ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_sparql-examples-shape-5449a27bfa4bfae4f541cd431f70436e> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate sh:prefixes ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate schema:target ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate sh:ask ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_sparql-examples-shape-5eeb053114221999cf7f89f7320b3fc6> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate sh:prefixes ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate schema:target ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate sh:construct ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniparc-shape-5999abf94bbccfd9146aa014b5afbb70> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequenceFor ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:seeAlso ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:md5Checksum ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdf:value ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-27c3dd9ac8f2732e1afdd939e280c1db> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-2c7209991559b9f71dcee619259ca89a> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:resolution ;
#             ns2:valueExpr [ ns2:datatype xsd:float ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:database ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:chainSequenceMapping ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:method ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-391d731be5239d7a6e17d8a20d20cc64> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate faldo:possiblePosition ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate faldo:possiblePosition ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate faldo:reference ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate faldo:reference ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-583efc6f2fa1e0db47dcd3fda52816a0> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate faldo:position ;
#             ns2:valueExpr [ ns2:datatype xsd:int ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate faldo:reference ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate faldo:reference ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate faldo:reference ;
#             ns2:valueExpr [ ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-73316865aae99d8b77753f8ee39e17cc> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:range ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:substitution ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-74cc61b5afedcf8f87e17f096654408f> a ns2:Shape ;
#     ns2:expressions [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:sequence ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate up:conflictingSequence ;
#             ns2:valueExpr [ ] ],
#         [ a ns2:TripleConstraint ;
#             ns2:predicate rdfs:comment ;
#             ns2:valueExpr [ ns2:datatype xsd:string ] ] .
#
# <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-827483a1c735fb5923fdacb35c0051f9> a ns2:Shape ;
# ...
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object <http://www.w3.org/ns/sparql-service-description#Service> ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_void-shape-cf0228a016dacbaa5cc8bcf3fb044cd5> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Book_Citation ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_proteomes-shape-871b8ecaf1f0928b22c672f0eedcbab1> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object <http://purl.obolibrary.org/obo/STATO_0000193> ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_proteomes-shape-36985cd5a5d275a1e69fd510e8a7680a> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Reference_Proteome ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_proteomes-shape-21b2c44096ea5c278ee00a5100d0c10e> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Proteome ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_proteomes-shape-1d30f54a7efacd04989bf4dcab63d460> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object <http://busco.ezlab.org/schema#Score> ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_proteomes-shape-05695744908e13f158a50c6fb97f462f> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object <http://busco.ezlab.org/schema#Score> ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_proteomes-shape-05695744908e13f158a50c6fb97f462f> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object faldo:Position ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-7c0cae77eca52763dc573555fae0964c> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Submission_Citation ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-03f9fbbac7535cc019821f7f68920a32> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object <http://busco.ezlab.org/schema#Score> ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_proteomes-shape-05695744908e13f158a50c6fb97f462f> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object rdf:Statement ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-afab0dea22c979f0d9750a1dbe4e2e42> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object faldo:Position ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-7c0cae77eca52763dc573555fae0964c> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object rdf:Statement ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-afab0dea22c979f0d9750a1dbe4e2e42> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object <http://busco.ezlab.org/schema#Score> ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_proteomes-shape-05695744908e13f158a50c6fb97f462f> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object <http://busco.ezlab.org/schema#Score> ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_proteomes-shape-05695744908e13f158a50c6fb97f462f> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object faldo:Position ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-7c0cae77eca52763dc573555fae0964c> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Protein ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-81e6dc72cafed42a6ba572f6f759140e> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object faldo:Position ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-7c0cae77eca52763dc573555fae0964c> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Structure_Resource ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-2c7209991559b9f71dcee619259ca89a> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Proteome_Component ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_proteomes-shape-a093af1caacd11ea5f1cac09da3f805b> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Structure_Resource ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-2c7209991559b9f71dcee619259ca89a> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object faldo:Position ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-7c0cae77eca52763dc573555fae0964c> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Proteome ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_proteomes-shape-1d30f54a7efacd04989bf4dcab63d460> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Proteome ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_proteomes-shape-1d30f54a7efacd04989bf4dcab63d460> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Structure_Resource ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-2c7209991559b9f71dcee619259ca89a> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object rdf:Statement ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-afab0dea22c979f0d9750a1dbe4e2e42> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Protein ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-81e6dc72cafed42a6ba572f6f759140e> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Alternative_Initiation_Annotation ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-1df2f455a937b1f11f7771c4c40289b5> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Protein ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-81e6dc72cafed42a6ba572f6f759140e> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Subcellular_Location_Annotation ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-8ae93580f4f9010647418ac9bc9899ad> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object <http://www.w3.org/ns/sparql-service-description#Graph> ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_void-shape-7cb4e6a45cb6e9b5d1e8ea459192da1b> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Reference_Proteome ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_proteomes-shape-21b2c44096ea5c278ee00a5100d0c10e> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Protein ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-81e6dc72cafed42a6ba572f6f759140e> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Submission_Citation ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-03f9fbbac7535cc019821f7f68920a32> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Thesis_Citation ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-548cd606e266d96a93dfa3bf04dfcb76> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Protein ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-81e6dc72cafed42a6ba572f6f759140e> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Reference_Proteome ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_proteomes-shape-21b2c44096ea5c278ee00a5100d0c10e> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Activity_Regulation_Annotation ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-ca9c3e2a01ae3746d5b8aa82a12679dd> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Propeptide_Annotation ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-bec878853bd184de3a3a69da2d06993c> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Active_Site_Annotation ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-7a20fdc8f287454d6fa110ca0c843780> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Protein ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-81e6dc72cafed42a6ba572f6f759140e> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Subunit_Annotation ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-fe1192498fea159676d9b35284dbfc7c> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Allergen_Annotation ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-51fde6b603c4bdb87cf5ab7596b81875> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object owl:Ontology ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_citations-shape-89df24df35df8882616112ab6a78df83> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Temperature_Dependence_Annotation ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-da5bece87eff9ebd804cf891aeb69bbf> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Journal_Citation ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_citations-shape-ad4f9786c857ed8d10bffe22b9586508> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Protein ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-81e6dc72cafed42a6ba572f6f759140e> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Absorption_Annotation ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-940b17962eb013e41b2e5f6cdbc9769a> ] ) .
#
# [] a ns1:ShapeMap ;
#     ns1:associations ( [ ns1:node [ ns1:focus rdf:subject ;
#                         ns1:object up:Subcellular_Location_Annotation ;
#                         rdf:predicate rdf:type ] ;
#                 ns1:shape <https://sparql.uniprot.org/.well-known/void#_graph_uniprot-shape-8ae93580f4f9010647418ac9bc9899ad> ] ) .
#
#
# 16240

# %% [markdown]
# ```
# ./shaclex --schema uniprot_shex.ttl --schemaFormat ShExJ --outSchemaFormat ShExC --showSchema
# ```

# %%
import json

from expasy_chat.validate_sparql import get_shex_dict_from_void

shex_dict = get_shex_dict_from_void("https://sparql.uniprot.org/sparql/")
for cls, shex_shape in shex_dict.items():
    print(cls)
    if "label" in shex_shape:
        print(shex_shape["label"])
    print(shex_shape["shex"])
    print()
# print(json.dumps(shex_dict, indent=2))

print(len(shex_dict))
# Out:
# http://purl.uniprot.org/core/Citation_Statement
# Citation Statement
# The relationship between a resource and a citation.
# up:Citation_Statement IRI {
#   up:mappedAnnotation [ up:Annotation ] ;
#   up:scope xsd:string ;
#   up:attribution IRI ;
#   rdf:object [ up:Book_Citation | up:Electronic_Citation | up:Journal_Citation | up:Observation_Citation | up:Patent_Citation | up:Submission_Citation | up:Thesis_Citation ] ;
#   rdf:predicate IRI ;
#   rdf:subject [ up:Protein ] ;
#   up:context [ up:Plasmid | up:Strain | up:Tissue | up:Transposon ]
# }
#
#
#
# http://www.w3.org/1999/02/22-rdf-syntax-ns#Statement
# rdf:Statement IRI {
#   up:mappedAnnotation [ up:Annotation ] ;
#   rdf:subject [ up:Annotation | up:Absorption_Annotation | up:Activity_Regulation_Annotation | up:Allergen_Annotation | up:Alternative_Initiation_Annotation | up:Alternative_Promoter_Usage_Annotation | up:Alternative_Splicing_Annotation | up:Biotechnology_Annotation | up:Catalytic_Activity_Annotation | up:Caution_Annotation | up:Citation_Statement | up:Cofactor_Annotation | up:Developmental_Stage_Annotation | up:Disease_Annotation | up:Disruption_Phenotype_Annotation | up:Domain_Annotation | up:External_Sequence | up:Function_Annotation | up:Gene | up:Induction_Annotation | up:Kinetics_Annotation | up:Modified_Sequence | up:PH_Dependence_Annotation | up:PTM_Annotation | up:Part | up:Pharmaceutical_Annotation | up:Polymorphism_Annotation | up:Protein | up:RNA_Editing_Annotation | up:Redox_Potential_Annotation | up:Ribosomal_Frameshifting | up:Similarity_Annotation | up:Simple_Sequence | rdf:Statement | up:Structured_Name | up:Subcellular_Location_Annotation | up:Subunit_Annotation | up:Temperature_Dependence_Annotation | up:Tissue_Specificity_Annotation | up:Toxic_Dose_Annotation | up:Unknown_Sequence ] ;
#   rdf:object xsd:string ;
#   up:scope xsd:string ;
#   up:attribution IRI ;
#   rdf:predicate IRI ;
#   up:citation [ up:Book_Citation | up:Electronic_Citation | up:Journal_Citation | up:Observation_Citation | up:Patent_Citation | up:Submission_Citation | up:Thesis_Citation ] ;
#   up:context [ up:Plasmid | up:Strain | up:Tissue | up:Transposon ]
# }
#
#
#
# http://purl.uniprot.org/core/Annotation
# Annotation
# Description of a resource on a specific topic.
# up:Annotation IRI {
#   rdfs:comment xsd:string ;
#   up:sequence [ up:Chain_Annotation | up:External_Sequence | up:Modified_Sequence | up:Peptide_Annotation | up:Simple_Sequence | up:Unknown_Sequence ]
# }
#
#
#
# http://purl.uniprot.org/core/Book_Citation
# Book Citation
# A chapter from a book.
# up:Book_Citation IRI {
#   up:author xsd:string ;
#   up:date xsd:date ;
#   up:editor xsd:string ;
#   up:group xsd:string ;
#   up:name xsd:string ;
#   up:pages xsd:string ;
#   up:place xsd:string ;
#   up:publisher xsd:string ;
#   up:title xsd:string ;
#   up:volume xsd:string ;
#   dc:identifier xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Journal_Citation
# Journal Citation
# An article published in a journal.
# up:Journal_Citation IRI {
#   up:author xsd:string ;
#   up:authorsIncomplete xsd:boolean ;
#   rdfs:comment xsd:string ;
#   up:date xsd:date ;
#   up:group xsd:string ;
#   dc:identifier xsd:string ;
#   up:name xsd:string ;
#   up:pages xsd:string ;
#   up:title xsd:string ;
#   up:volume xsd:string ;
#   skos:exactMatch IRI ;
#   foaf:primaryTopicOf IRI ;
#   up:erratum [ up:Electronic_Citation | up:Journal_Citation ]
# }
#
#
#
# http://purl.uniprot.org/core/Submission_Citation
# Submission Citation
# Data that was submitted directly to a database.
# up:Submission_Citation IRI {
#   up:author xsd:string ;
#   up:date xsd:date ;
#   up:group xsd:string ;
#   up:submittedTo xsd:string ;
#   up:title xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Thesis_Citation
# Thesis Citation
# A Ph.D. thesis.
# up:Thesis_Citation IRI {
#   up:author xsd:string ;
#   up:date xsd:date ;
#   up:institution xsd:string ;
#   up:place xsd:string ;
#   up:title xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Member_Of_Redudant_Proteome
# Member Of Redudant Proteome
# This entry was obsoleted because its sequence belongs to a redundant protoeome
# up:Member_Of_Redudant_Proteome IRI {
#   up:replacedBy [ up:Member_Of_Redudant_Proteome | up:Protein ] ;
#   up:created xsd:date ;
#   up:mnemonic xsd:string ;
#   up:modified xsd:date ;
#   up:obsolete xsd:boolean ;
#   up:reviewed xsd:boolean ;
#   up:version xsd:int
# }
#
#
#
# http://purl.uniprot.org/core/Protein
# Protein
# Description of a protein.
# up:Protein IRI {
#   up:replacedBy [ up:Member_Of_Redudant_Proteome | up:Protein ] ;
#   up:created xsd:date ;
#   up:mnemonic xsd:string ;
#   up:modified xsd:date ;
#   up:obsolete xsd:boolean ;
#   up:oldMnemonic xsd:string ;
#   up:reviewed xsd:boolean ;
#   up:version xsd:int ;
#   up:withdrawnFromINSDC xsd:string ;
#   up:alternativeName [ up:Structured_Name ] ;
#   up:annotation [ up:Absorption_Annotation | up:Active_Site_Annotation | up:Activity_Regulation_Annotation | up:Allergen_Annotation | up:Alternative_Initiation_Annotation | up:Alternative_Promoter_Usage_Annotation | up:Alternative_Sequence_Annotation | up:Alternative_Splicing_Annotation | up:Annotation | up:Beta_Strand_Annotation | up:Binding_Site_Annotation | up:Biotechnology_Annotation | up:Catalytic_Activity_Annotation | up:Caution_Annotation | up:Chain_Annotation | up:Cofactor_Annotation | up:Coiled_Coil_Annotation | up:Compositional_Bias_Annotation | up:Cross-link_Annotation | up:Developmental_Stage_Annotation | up:Disease_Annotation | up:Disruption_Phenotype_Annotation | up:Disulfide_Bond_Annotation | up:Domain_Annotation | up:Domain_Extent_Annotation | up:Erroneous_Gene_Model_Prediction_Annotation | up:Erroneous_Initiation_Annotation | up:Erroneous_Termination_Annotation | up:Erroneous_Translation_Annotation | up:Frameshift_Annotation | up:Function_Annotation | up:Glycosylation_Annotation | up:Helix_Annotation | up:Induction_Annotation | up:Initiator_Methionine_Annotation | up:Intramembrane_Annotation | up:Kinetics_Annotation | up:Lipidation_Annotation | up:Mass_Spectrometry_Annotation | up:Modified_Residue_Annotation | up:Motif_Annotation | up:Mutagenesis_Annotation | up:Natural_Variant_Annotation | up:Non-adjacent_Residues_Annotation | up:Non-standard_Residue_Annotation | up:Non-terminal_Residue_Annotation | up:Nucleotide_Binding_Annotation | up:PH_Dependence_Annotation | up:PTM_Annotation | up:Pathway_Annotation | up:Peptide_Annotation | up:Pharmaceutical_Annotation | up:Polymorphism_Annotation | up:Propeptide_Annotation | up:RNA_Editing_Annotation | up:Redox_Potential_Annotation | up:Region_Annotation | up:Repeat_Annotation | up:Ribosomal_Frameshifting | up:Sequence_Caution_Annotation | up:Sequence_Conflict_Annotation | up:Sequence_Uncertainty_Annotation | up:Signal_Peptide_Annotation | up:Similarity_Annotation | up:Site_Annotation | up:Subcellular_Location_Annotation | up:Subunit_Annotation | up:Temperature_Dependence_Annotation | up:Tissue_Specificity_Annotation | up:Topological_Domain_Annotation | up:Toxic_Dose_Annotation | up:Transit_Peptide_Annotation | up:Transmembrane_Annotation | up:Turn_Annotation | up:Zinc_Finger_Annotation ] ;
#   up:citation [ up:Book_Citation | up:Electronic_Citation | up:Journal_Citation | up:Observation_Citation | up:Patent_Citation | up:Submission_Citation | up:Thesis_Citation ] ;
#   up:component [ up:Part ] ;
#   up:conflictingSequence [ up:External_Sequence ] ;
#   up:domain [ up:Part ] ;
#   up:encodedBy [ up:Gene ] ;
#   up:encodedIn [ up:Plasmid ] ;
#   up:interaction [ up:Interaction | up:Non_Self_Interaction | up:Self_Interaction ] ;
#   up:isolatedFrom [ up:Tissue ] ;
#   up:potentialSequence [ up:External_Sequence | up:Modified_Sequence | up:Simple_Sequence ] ;
#   up:recommendedName [ up:Structured_Name ] ;
#   rdfs:seeAlso [ up:Nucleotide_Resource | up:Resource | up:Structure_Resource | up:Transcript_Resource ] ;
#   up:sequence [ up:External_Sequence | up:Modified_Sequence | up:Simple_Sequence | up:Unknown_Sequence ] ;
#   up:submittedName [ up:Structured_Name ] ;
#   up:complete xsd:boolean ;
#   up:attribution IRI ;
#   up:classifiedWith IRI ;
#   up:enzyme IRI ;
#   up:existence IRI ;
#   up:organism IRI ;
#   up:proteome IRI ;
#   up:replaces IRI
# }
#
#
#
# http://purl.uniprot.org/core/Proteome
# Proteome
# Description of a proteome.
# up:Proteome IRI {
#   up:citation [ up:Book_Citation | up:Journal_Citation | up:Submission_Citation ] ;
#   skos:closeMatch [ obo:STATO_0000193 ] ;
#   busco:has_score [ busco:Score ] ;
#   skos:narrower [ up:Proteome_Component ] ;
#   up:panproteome [ up:Proteome | up:Reference_Proteome | up:Representative_Proteome ] ;
#   up:redundantTo [ up:Proteome | up:Reference_Proteome | up:Representative_Proteome ] ;
#   up:strain [ up:Strain ] ;
#   rdfs:comment xsd:string ;
#   up:exclusionReason xsd:string ;
#   dc:modified xsd:date ;
#   up:organism IRI ;
#   rdfs:seeAlso IRI
# }
#
#
#
# http://purl.uniprot.org/core/Reference_Proteome
# Reference_Proteome
# Some proteomes have been (manually and algorithmically) selected as reference
# proteomes.
# up:Reference_Proteome IRI {
#   up:citation [ up:Book_Citation | up:Journal_Citation | up:Submission_Citation ] ;
#   busco:has_score [ busco:Score ] ;
#   up:panproteome [ up:Proteome | up:Reference_Proteome | up:Representative_Proteome ] ;
#   dc:modified xsd:date ;
#   up:organism IRI ;
#   skos:closeMatch [ obo:STATO_0000193 ] ;
#   skos:narrower [ up:Proteome_Component ] ;
#   up:strain [ up:Strain ] ;
#   rdfs:comment xsd:string ;
#   rdfs:seeAlso IRI
# }
#
#
#
# http://purl.uniprot.org/core/Taxon
# Taxon
# An element of a taxonomy for classifying life forms.
# up:Taxon IRI {
#   foaf:depiction [ foaf:Image ] ;
#   up:host [ up:Taxon ] ;
#   skos:narrowerTransitive [ up:Taxon ] ;
#   up:replacedBy [ up:Taxon ] ;
#   up:replaces [ up:Taxon ] ;
#   up:strain [ up:Strain ] ;
#   rdfs:subClassOf [ up:Taxon ] ;
#   up:commonName xsd:string ;
#   up:mnemonic xsd:string ;
#   up:obsolete xsd:boolean ;
#   up:otherName xsd:string ;
#   up:partOfLineage xsd:boolean ;
#   up:scientificName xsd:string ;
#   up:synonym xsd:string ;
#   up:rank IRI ;
#   rdfs:seeAlso IRI
# }
#
#
#
# http://biohackathon.org/resource/faldo#ExactPosition
# faldo:ExactPosition IRI {
#   faldo:reference [ up:Sequence | up:External_Sequence | up:Modified_Sequence | up:Simple_Sequence ] ;
#   faldo:position xsd:int
# }
#
#
#
# http://biohackathon.org/resource/faldo#Region
# faldo:Region IRI {
#   faldo:begin [ faldo:ExactPosition | faldo:InRangePosition | faldo:OneOfPosition | faldo:Position ] ;
#   faldo:end [ faldo:ExactPosition | faldo:InRangePosition | faldo:OneOfPosition | faldo:Position ]
# }
#
#
#
# http://purl.obolibrary.org/obo/STATO_0000193
# obo:STATO_0000193 IRI {
#   rdfs:comment xsd:int ;
#   rdfs:label xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Proteome_Component
# Proteome_Component
# The component of a proteome. e.g. Chromosome, Contig or Plasmid
# up:Proteome_Component IRI {
#   rdfs:comment xsd:string ;
#   rdfs:seeAlso IRI
# }
#
#
#
# http://busco.ezlab.org/schema#Score
# busco:Score IRI {
#   busco:completeMulti xsd:int ;
#   busco:completeSingle xsd:int ;
#   busco:complete xsd:int ;
#   busco:fragmented xsd:int ;
#   busco:missing xsd:int ;
#   busco:referenceDataset xsd:string
# }
#
#
#
# http://xmlns.com/foaf/0.1/Image
# foaf:Image IRI {
#   up:height xsd:int ;
#   up:width xsd:int
# }
#
#
#
# http://purl.uniprot.org/core/Strain
# Taxonomy rank Strain
# A strain of a species.
# up:Strain IRI {
#   up:name xsd:string ;
#   rdfs:label xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Sequence
# Sequence
# An amino acid sequence.
# up:Sequence IRI {
#   up:md5Checksum xsd:string ;
#   rdf:value xsd:string ;
#   rdfs:seeAlso IRI ;
#   up:sequenceFor IRI ;
#   up:memberOf [ up:Cluster ] ;
#   up:representativeFor [ up:Cluster ] ;
#   up:seedFor [ up:Cluster ] ;
#   rdfs:label xsd:string ;
#   up:length xsd:int ;
#   up:organism IRI
# }
#
#
#
# http://purl.uniprot.org/core/Gene
# Gene
# up:Gene IRI {
#   skos:prefLabel xsd:string ;
#   skos:altLabel xsd:string ;
#   up:locusName xsd:string ;
#   up:orfName xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Structured_Name
# Structured_Name
# A resource that holds a set of the known names for this protein together.
# up:Structured_Name IRI {
#   up:structuredNameType xsd:string ;
#   up:allergenName xsd:string ;
#   up:cdAntigenName xsd:string ;
#   up:ecName xsd:string ;
#   up:fullName xsd:string ;
#   up:internationalNonproprietaryName xsd:string ;
#   up:shortName xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Active_Site_Annotation
# Active Site
# Amino acid(s) involved in the activity of an enzyme.
# up:Active_Site_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   up:sequence [ up:Modified_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Activity_Regulation_Annotation
# Activity Regulation
# Description of an enzyme, transporter and microbial transcription regulation mechanism.
# up:Activity_Regulation_Annotation IRI {
#   up:sequence [ up:Chain_Annotation | up:Modified_Sequence | up:Peptide_Annotation | up:Simple_Sequence | up:Unknown_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Allergen_Annotation
# Allergen
# Information relevant to allergenic proteins.
# up:Allergen_Annotation IRI {
#   up:sequence [ up:Chain_Annotation ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Alternative_Initiation_Annotation
# Alternative Initiation
# up:Alternative_Initiation_Annotation IRI {
#   up:sequence [ up:External_Sequence | up:Modified_Sequence | up:Simple_Sequence | up:Unknown_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Alternative_Promoter_Usage_Annotation
# Alternative Promoter Usage
# up:Alternative_Promoter_Usage_Annotation IRI {
#   up:sequence [ up:External_Sequence | up:Modified_Sequence | up:Simple_Sequence | up:Unknown_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Alternative_Sequence_Annotation
# Splice Variant
# Description of sequence variants produced by alternative splicing.
# up:Alternative_Sequence_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   rdfs:comment xsd:string ;
#   up:substitution xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Alternative_Splicing_Annotation
# Alternative Splicing
# up:Alternative_Splicing_Annotation IRI {
#   up:sequence [ up:External_Sequence | up:Modified_Sequence | up:Simple_Sequence | up:Unknown_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Beta_Strand_Annotation
# Strand
# Beta strand regions within the experimentally determined protein structure
# up:Beta_Strand_Annotation IRI {
#   up:range [ faldo:Region ]
# }
#
#
#
# http://purl.uniprot.org/core/Binding_Site_Annotation
# Binding Site
# Binding site for any chemical group (co-enzyme, prosthetic group, etc.).
# up:Binding_Site_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   up:sequence [ up:Modified_Sequence ] ;
#   rdfs:comment xsd:string ;
#   up:ligand IRI ;
#   up:ligandPart IRI
# }
#
#
#
# http://purl.uniprot.org/core/Biotechnology_Annotation
# Biotechnology
# Description of the use of a specific protein in a biotechnological process.
# up:Biotechnology_Annotation IRI {
#   up:sequence [ up:Chain_Annotation | up:Modified_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Catalytic_Activity_Annotation
# Catalytic Activity Annotation
# Description of the reactions catalyzed by an enzyme.
# up:Catalytic_Activity_Annotation IRI {
#   up:catalyticActivity [ up:Catalytic_Activity ] ;
#   up:sequence [ up:Chain_Annotation | up:Modified_Sequence | up:Simple_Sequence | up:Unknown_Sequence ] ;
#   up:catalyzedPhysiologicalReaction IRI
# }
#
#
#
# http://purl.uniprot.org/core/Caution_Annotation
# Caution
# Warning about possible errors and/or grounds for confusion.
# up:Caution_Annotation IRI {
#   up:sequence [ up:Chain_Annotation | up:Modified_Sequence | up:Peptide_Annotation | up:Simple_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Chain_Annotation
# Chain
# Extent of a polypeptide chain in the mature protein.
# up:Chain_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   rdfs:comment xsd:string ;
#   up:mass xsd:int
# }
#
#
#
# http://purl.uniprot.org/core/Cofactor_Annotation
# Cofactor
# Description of an enzyme cofactor.
# up:Cofactor_Annotation IRI {
#   up:sequence [ up:Chain_Annotation | up:Modified_Sequence | up:Peptide_Annotation | up:Simple_Sequence | up:Unknown_Sequence ] ;
#   rdfs:comment xsd:string ;
#   up:cofactor IRI
# }
#
#
#
# http://purl.uniprot.org/core/Coiled_Coil_Annotation
# Coiled-Coil
# Extent of a coiled-coil region.
# up:Coiled_Coil_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   up:sequence [ up:Modified_Sequence ]
# }
#
#
#
# http://purl.uniprot.org/core/Compositional_Bias_Annotation
# Compositionally Biased Region
# Extent of a compositionally biased region.
# up:Compositional_Bias_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Cross-link_Annotation
# Crosslink
# Posttranslationally formed amino acid bonds.
# up:Cross-link_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   up:sequence [ up:Modified_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Developmental_Stage_Annotation
# Developmental Stage
# Description of the developmentally-specific expression of a protein.
# up:Developmental_Stage_Annotation IRI {
#   up:sequence [ up:Chain_Annotation | up:Modified_Sequence | up:Peptide_Annotation | up:Simple_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Disease_Annotation
# Disease Annotation
# Description of the diseases associated with a deficiency of a protein.
# up:Disease_Annotation IRI {
#   up:sequence [ up:Chain_Annotation | up:Modified_Sequence ] ;
#   rdfs:comment xsd:string ;
#   up:disease IRI
# }
#
#
#
# http://purl.uniprot.org/core/Disruption_Phenotype_Annotation
# Disruption Phenotype
# up:Disruption_Phenotype_Annotation IRI {
#   up:sequence [ up:Chain_Annotation | up:Modified_Sequence | up:Peptide_Annotation | up:Simple_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Disulfide_Bond_Annotation
# Disulfide Bond
# Describes residues which are linked by an intra-chain disulfide bond. If the endpoints are identical, the disulfide bond is an interchain one.
# up:Disulfide_Bond_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   up:sequence [ up:Modified_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Domain_Annotation
# Domain
# Description of the domain structure of a protein.
# up:Domain_Annotation IRI {
#   up:sequence [ up:Chain_Annotation | up:External_Sequence | up:Modified_Sequence | up:Peptide_Annotation | up:Simple_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Domain_Extent_Annotation
# Domain Extent
# Extent of a domain, which is defined as a specific combination of secondary structures organized into a characteristic three-dimensional structure or fold.
# up:Domain_Extent_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Erroneous_Gene_Model_Prediction_Annotation
# Erroneous Gene Model Prediction
# up:Erroneous_Gene_Model_Prediction_Annotation IRI {
#   up:conflictingSequence [ up:External_Sequence ] ;
#   up:sequence [ up:Modified_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Erroneous_Initiation_Annotation
# Erroneous Initiation
# up:Erroneous_Initiation_Annotation IRI {
#   up:conflictingSequence [ up:External_Sequence ] ;
#   up:sequence [ up:Modified_Sequence | up:Simple_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Erroneous_Termination_Annotation
# Erroneous Termination
# up:Erroneous_Termination_Annotation IRI {
#   up:conflictingSequence [ up:External_Sequence ] ;
#   up:sequence [ up:Modified_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Erroneous_Translation_Annotation
# Erroneous Translation
# up:Erroneous_Translation_Annotation IRI {
#   up:conflictingSequence [ up:External_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Electronic_Citation
# Electronic Citation
# An electronic publication.
# up:Electronic_Citation IRI {
#   up:author xsd:string ;
#   up:date xsd:date ;
#   dc:identifier xsd:string ;
#   up:locator xsd:string ;
#   up:name xsd:string ;
#   up:title xsd:string ;
#   skos:exactMatch IRI
# }
#
#
#
# http://purl.uniprot.org/core/Absorption_Annotation
# Absorption
# Indicates the wavelength in nm at which photoreactive proteins such as opsins and DNA photolyases show maximal absorption.
# up:Absorption_Annotation IRI {
#   up:certain xsd:boolean ;
#   rdfs:comment xsd:string ;
#   up:maximum xsd:int
# }
#
#
#
# http://purl.uniprot.org/core/Catalytic_Activity
# Catalytic Activity
# The catalytic activity of an enzyme.
# up:Catalytic_Activity IRI {
#   up:catalyzedReaction IRI ;
#   skos:closeMatch IRI ;
#   up:enzymeClass IRI ;
#   rdfs:label xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/External_Sequence
# External Sequence
# The protein described in the linked record is an alternative splice form of the same gene product as described in this record. The function between the two isoforms is highly divergent.
# up:External_Sequence IRI {
#   up:basedOn [ up:External_Sequence | up:Simple_Sequence ] ;
#   up:citation [ up:Book_Citation | up:Electronic_Citation | up:Journal_Citation | up:Observation_Citation | up:Patent_Citation | up:Submission_Citation | up:Thesis_Citation ] ;
#   up:modification [ up:Alternative_Sequence_Annotation ] ;
#   up:translatedFrom [ up:Nucleotide_Resource ] ;
#   rdfs:comment xsd:string ;
#   up:fragment xsd:string ;
#   up:mass xsd:int ;
#   up:md5Checksum xsd:string ;
#   up:modified xsd:date ;
#   up:name xsd:string ;
#   up:precursor xsd:boolean ;
#   rdf:value xsd:string ;
#   up:version xsd:int ;
#   up:replaces IRI
# }
#
#
#
# http://purl.uniprot.org/core/Frameshift_Annotation
# Frameshift
# up:Frameshift_Annotation IRI {
#   up:conflictingSequence [ up:External_Sequence ] ;
#   up:sequence [ up:Modified_Sequence | up:Simple_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Function_Annotation
# Function
# General description of the functions of a protein.
# up:Function_Annotation IRI {
#   up:sequence [ up:Chain_Annotation | up:External_Sequence | up:Modified_Sequence | up:Peptide_Annotation | up:Simple_Sequence | up:Unknown_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Glycosylation_Annotation
# Glycosylation Site
# Describes the occurrence of the attachment of a glycan (mono- or polysaccharide) to a residue of a protein.
# up:Glycosylation_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   up:sequence [ up:Modified_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Helix_Annotation
# Helix
# Helical regions within the experimentally determined protein structure
# up:Helix_Annotation IRI {
#   up:range [ faldo:Region ]
# }
#
#
#
# http://biohackathon.org/resource/faldo#InRangePosition
# faldo:InRangePosition IRI {
#   faldo:begin [ faldo:ExactPosition | faldo:Position ] ;
#   faldo:end [ faldo:ExactPosition | faldo:Position ] ;
#   faldo:reference [ up:External_Sequence | up:Simple_Sequence ]
# }
#
#
#
# http://purl.uniprot.org/core/Induction_Annotation
# Induction
# Description of the compounds or conditions that stimulate the synthesis of a protein.
# up:Induction_Annotation IRI {
#   up:sequence [ up:Chain_Annotation | up:External_Sequence | up:Modified_Sequence | up:Peptide_Annotation | up:Simple_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Initiator_Methionine_Annotation
# Initiator Methionine
# Indicates that the initiator methionine has been cleaved off and is not shown in the sequence.
# up:Initiator_Methionine_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   up:sequence [ up:External_Sequence | up:Modified_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Interaction
# Interaction
# Description of a protein-protein interaction.
# up:Interaction IRI {
#   up:participant [ up:Participant ] ;
#   up:experiments xsd:int ;
#   up:xeno xsd:boolean
# }
#
#
#
# http://purl.uniprot.org/core/Intramembrane_Annotation
# INTRAMEM
# Extent of a region located in a membrane without crossing it
# up:Intramembrane_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   up:sequence [ up:Modified_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Kinetics_Annotation
# Kinetics
# Mentions the Michaelis-Menten constant (KM) and maximal velocity (Vmax) of enzymes.
# up:Kinetics_Annotation IRI {
#   up:sequence [ up:Chain_Annotation | up:Modified_Sequence | up:Simple_Sequence ] ;
#   rdfs:comment xsd:string ;
#   up:measuredActivity xsd:string ;
#   up:measuredAffinity xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Lipidation_Annotation
# Lipid Binding
# Covalent binding of a lipid moiety.
# up:Lipidation_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   up:sequence [ up:Modified_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Mass_Spectrometry_Annotation
# Mass
# Indicates the mass of a sequence determined by mass spectrometry.
# up:Mass_Spectrometry_Annotation IRI {
#   up:sequence [ up:Chain_Annotation | up:Modified_Sequence | up:Peptide_Annotation | up:Simple_Sequence ] ;
#   rdfs:comment xsd:string ;
#   up:measuredError xsd:float ;
#   up:measuredValue xsd:float ;
#   up:method IRI
# }
#
#
#
# http://purl.uniprot.org/core/Modified_Residue_Annotation
# Modified Residue
# Posttranslational modification of a residue.
# up:Modified_Residue_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   up:sequence [ up:External_Sequence | up:Modified_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Modified_Sequence
# Modified Sequence
# up:Modified_Sequence IRI {
#   up:basedOn [ up:External_Sequence | up:Simple_Sequence ] ;
#   up:modification [ up:Alternative_Sequence_Annotation ] ;
#   up:name xsd:string ;
#   rdf:value xsd:string ;
#   up:replaces IRI
# }
#
#
#
# http://purl.uniprot.org/core/Motif_Annotation
# Motif
# Short (<=20 amino acids) sequence motif of biological interest.
# up:Motif_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   up:sequence [ up:Modified_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Mutagenesis_Annotation
# Mutagenesis Site
# Site which has been experimentally altered.
# up:Mutagenesis_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   up:sequence [ up:Modified_Sequence ] ;
#   rdfs:comment xsd:string ;
#   up:substitution xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Natural_Variant_Annotation
# Sequence Variant
# Authors report that sequence variants exist.
# up:Natural_Variant_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   up:sequence [ up:Modified_Sequence ] ;
#   rdfs:comment xsd:string ;
#   up:substitution xsd:string ;
#   skos:related IRI ;
#   rdfs:seeAlso IRI
# }
#
#
#
# http://purl.uniprot.org/core/Non-adjacent_Residues_Annotation
# Non-consecutive Residues
# Indicates that two residues in a sequence are not consecutive and that there are a number of unsequenced residues between them.
# up:Non-adjacent_Residues_Annotation IRI {
#   up:range [ faldo:Region ]
# }
#
#
#
# http://purl.uniprot.org/core/Non-standard_Residue_Annotation
# Non standard residue
# Describes the occurrence of a non standard residue in the sequence record.
# up:Non-standard_Residue_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Non-terminal_Residue_Annotation
# Non-terminal Residue
# The residue at an extremity of the sequence is not the terminal residue.
# up:Non-terminal_Residue_Annotation IRI {
#   up:range [ faldo:Region ]
# }
#
#
#
# http://purl.uniprot.org/core/Non_Self_Interaction
# Non self interaction
# Description of a non self protein-protein interaction.
# up:Non_Self_Interaction IRI {
#   up:participant [ up:Participant ] ;
#   up:experiments xsd:int ;
#   up:xeno xsd:boolean
# }
#
#
#
# http://purl.uniprot.org/core/Nucleotide_Binding_Annotation
# DNA Binding
# Extent of a DNA-binding region.
# up:Nucleotide_Binding_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Nucleotide_Resource
# Nucleotide Resource
# A resource that descripes a nucleotide sequence.
# up:Nucleotide_Resource IRI {
#   up:citation [ up:Book_Citation | up:Electronic_Citation | up:Journal_Citation | up:Patent_Citation | up:Submission_Citation | up:Thesis_Citation ] ;
#   up:locatedOn [ up:Genomic_DNA | up:Genomic_RNA | up:MRNA | up:Other_DNA | up:Other_RNA | up:Transcribed_RNA | up:Unassigned_DNA | up:Unassigned_RNA | up:Viral_cRNA ] ;
#   up:database IRI ;
#   up:sequenceDiscrepancy IRI
# }
#
#
#
# http://biohackathon.org/resource/faldo#OneOfPosition
# faldo:OneOfPosition IRI {
#   faldo:possiblePosition [ faldo:ExactPosition | faldo:Position ] ;
#   faldo:reference [ up:External_Sequence | up:Simple_Sequence ]
# }
#
#
#
# http://purl.uniprot.org/core/PH_Dependence_Annotation
# pH Dependence
# Describes the optimum pH for enzyme activity and/or the variation of enzyme activity with pH variation.
# up:PH_Dependence_Annotation IRI {
#   up:sequence [ up:Chain_Annotation | up:Modified_Sequence | up:Peptide_Annotation | up:Simple_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/PTM_Annotation
# PTM
# Description of a posttranslational modification.
# up:PTM_Annotation IRI {
#   up:sequence [ up:Chain_Annotation | up:External_Sequence | up:Modified_Sequence | up:Peptide_Annotation | up:Simple_Sequence | up:Unknown_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Participant
# Interaction participant
# A participant in a protein-protein interaction.
# up:Participant IRI {
#   owl:sameAs [ up:Chain_Annotation | up:External_Sequence | up:Modified_Sequence | up:Peptide_Annotation | up:Propeptide_Annotation | up:Protein | up:Simple_Sequence ] ;
#   rdfs:label xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Part
# Protein part
# Description of a part of a protein.
# up:Part IRI {
#   up:alternativeName [ up:Structured_Name ] ;
#   up:recommendedName [ up:Structured_Name ] ;
#   up:enzyme IRI
# }
#
#
#
# http://purl.uniprot.org/core/Pathway_Annotation
# Pathway annotation
# Description of the metabolic pathways with which a protein is associated.
# up:Pathway_Annotation IRI {
#   up:sequence [ up:Modified_Sequence | up:Simple_Sequence ] ;
#   rdfs:seeAlso IRI
# }
#
#
#
# http://purl.uniprot.org/core/Peptide_Annotation
# Peptide
# Extent of a released active peptide.
# up:Peptide_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   rdfs:comment xsd:string ;
#   up:mass xsd:int
# }
#
#
#
# http://purl.uniprot.org/core/Pharmaceutical_Annotation
# Pharmaceutical
# Description of the use of a protein as a pharmaceutical drug.
# up:Pharmaceutical_Annotation IRI {
#   up:sequence [ up:Peptide_Annotation ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Observation_Citation
# Observation Citation
# Citation of an unpublished result.
# up:Observation_Citation IRI {
#   up:author xsd:string ;
#   up:date xsd:date ;
#   up:group xsd:string ;
#   up:title xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Patent_Citation
# Patent Citation
# A patent application.
# up:Patent_Citation IRI {
#   up:author xsd:string ;
#   up:date xsd:date ;
#   up:title xsd:string ;
#   skos:exactMatch IRI
# }
#
#
#
# http://purl.uniprot.org/core/Plasmid
# Plasmid
# Description of a Plasmid
# up:Plasmid IRI {
#   rdfs:label xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Polymorphism_Annotation
# Polymorphism
# Description of polymorphisms.
# up:Polymorphism_Annotation IRI {
#   up:sequence [ up:Chain_Annotation | up:Modified_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://biohackathon.org/resource/faldo#Position
# faldo:Position IRI {
#   faldo:begin [ faldo:ExactPosition | faldo:Position ] ;
#   faldo:end [ faldo:ExactPosition | faldo:Position ] ;
#   faldo:possiblePosition [ faldo:ExactPosition | faldo:Position ] ;
#   faldo:reference [ up:External_Sequence | up:Modified_Sequence | up:Simple_Sequence ] ;
#   faldo:position xsd:int
# }
#
#
#
# http://purl.uniprot.org/core/Propeptide_Annotation
# Propeptide
# Extent of a propeptide.
# up:Propeptide_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/RNA_Editing_Annotation
# RNA Editing
# Description of any type of RNA editing that leads to one or more amino acid changes.
# up:RNA_Editing_Annotation IRI {
#   faldo:location [ faldo:ExactPosition | faldo:Position ] ;
#   up:sequence [ up:Modified_Sequence ] ;
#   rdfs:comment xsd:string ;
#   up:frameshift xsd:boolean
# }
#
#
#
# http://purl.uniprot.org/core/Region_Annotation
# Region
# up:Region_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   up:sequence [ up:Modified_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Repeat_Annotation
# Repeat
# Extent of an internal sequence repetition.
# up:Repeat_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Resource
# Resource
# A life science resource.
# up:Resource IRI {
#   rdfs:seeAlso [ up:External_Sequence | up:Modified_Sequence | up:Simple_Sequence | up:Unknown_Sequence ] ;
#   rdfs:comment xsd:string ;
#   up:database IRI ;
#   up:signatureSequenceMatch IRI ;
#   up:translatedFrom IRI
# }
#
#
#
# http://purl.uniprot.org/core/Ribosomal_Frameshifting
# Ribosomal Frameshifting
# up:Ribosomal_Frameshifting IRI {
#   up:sequence [ up:External_Sequence | up:Modified_Sequence | up:Simple_Sequence | up:Unknown_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Self_Interaction
# Self protein interaction
# Description of a self protein-protein interaction.
# up:Self_Interaction IRI {
#   up:participant [ up:Participant ] ;
#   up:experiments xsd:int ;
#   up:xeno xsd:boolean
# }
#
#
#
# http://purl.uniprot.org/core/Sequence_Caution_Annotation
# Sequence Caution
# Warning about possible errors related to the protein sequence
# up:Sequence_Caution_Annotation IRI {
#   up:conflictingSequence [ up:External_Sequence ] ;
#   up:sequence [ up:Modified_Sequence | up:Simple_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Sequence_Conflict_Annotation
# Sequence Conflict
# Different sources report differing sequences.
# up:Sequence_Conflict_Annotation IRI {
#   up:conflictingSequence [ up:External_Sequence ] ;
#   up:range [ faldo:Region ] ;
#   up:sequence [ up:External_Sequence | up:Modified_Sequence ] ;
#   up:substitution xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Sequence_Uncertainty_Annotation
# Unsure Residue
# Used to describe region(s) of a sequence for which the authors are unsure about the sequence assignment.
# up:Sequence_Uncertainty_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Signal_Peptide_Annotation
# Signal Peptide
# Extent of a signal sequence (prepeptide).
# up:Signal_Peptide_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Similarity_Annotation
# Similarity
# Description of the similarities (sequence or structural) of a protein with other proteins.
# up:Similarity_Annotation IRI {
#   up:sequence [ up:Chain_Annotation ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Site_Annotation
# Site
# Any interesting single amino-acid site on the sequence, that is not defined by another feature key. It can also apply to an amino acid bond which is represented by the positions of the two flanking amino acids.
# up:Site_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   up:sequence [ up:Modified_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Subcellular_Location_Annotation
# Subcellular Location Annotation
# Description of the subcellular location of the mature protein.
# up:Subcellular_Location_Annotation IRI {
#   up:sequence [ up:Chain_Annotation | up:External_Sequence | up:Modified_Sequence | up:Peptide_Annotation | up:Simple_Sequence | up:Unknown_Sequence ] ;
#   rdfs:comment xsd:string ;
#   up:locatedIn IRI
# }
#
#
#
# http://purl.uniprot.org/core/Subunit_Annotation
# Subunit
# Description of the quaternary structure of a protein.
# up:Subunit_Annotation IRI {
#   up:sequence [ up:Chain_Annotation | up:External_Sequence | up:Modified_Sequence | up:Peptide_Annotation | up:Simple_Sequence | up:Unknown_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Temperature_Dependence_Annotation
# Temperature Dependence
# Indicates the optimum temperature for enzyme activity and/or the variation of enzyme activity with temperature variation; the thermostability/thermolability of the enzyme is also mentioned when it is known.
# up:Temperature_Dependence_Annotation IRI {
#   up:sequence [ up:Chain_Annotation | up:Modified_Sequence | up:Peptide_Annotation | up:Simple_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Tissue_Specificity_Annotation
# Tissue Specificity
# Description of the tissue specificity of a protein.
# up:Tissue_Specificity_Annotation IRI {
#   up:sequence [ up:Chain_Annotation | up:External_Sequence | up:Modified_Sequence | up:Peptide_Annotation | up:Simple_Sequence | up:Unknown_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Topological_Domain_Annotation
# Topological Domain
# A topological domain.
# up:Topological_Domain_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   up:sequence [ up:Modified_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Toxic_Dose_Annotation
# Toxic Dose
# Information on the LD(50). LD stands for "Lethal Dose". LD(50) is the amount of a toxin, given all at once, which causes the death of 50% (one half) of a group of test animals.
# up:Toxic_Dose_Annotation IRI {
#   up:sequence [ up:Chain_Annotation | up:Peptide_Annotation ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Redox_Potential_Annotation
# Redox Potential
# Reports the value of the standard (midpoint) oxido-reduction potential(s) for electron transport proteins.
# up:Redox_Potential_Annotation IRI {
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Simple_Sequence
# Simple Sequence
# up:Simple_Sequence IRI {
#   up:fragment xsd:string ;
#   up:mass xsd:int ;
#   up:md5Checksum xsd:string ;
#   up:modified xsd:date ;
#   up:name xsd:string ;
#   up:precursor xsd:boolean ;
#   rdf:value xsd:string ;
#   up:version xsd:int ;
#   up:replaces IRI
# }
#
#
#
# http://purl.uniprot.org/core/Tissue
# Tissue
# A tissue such as lung or heart.
# up:Tissue IRI {
#   rdfs:label xsd:string ;
#   skos:altLabel xsd:string ;
#   skos:prefLabel xsd:string ;
#   rdfs:seeAlso IRI
# }
#
#
#
# http://purl.uniprot.org/core/Structure_Resource
# Structure Resource
# A resource that describes the 3D structure of a protein.
# up:Structure_Resource IRI {
#   up:resolution xsd:float ;
#   up:chainSequenceMapping IRI ;
#   up:database IRI ;
#   up:method IRI
# }
#
#
#
# http://purl.uniprot.org/core/Transcript_Resource
# Transcript Resource
# up:Transcript_Resource IRI {
#   owl:sameAs [ up:Transcript_Resource ] ;
#   rdfs:seeAlso [ up:External_Sequence | up:Modified_Sequence | up:Simple_Sequence ] ;
#   up:transcribedFrom [ up:Transcript_Resource ] ;
#   up:translatedTo [ up:Transcript_Resource ] ;
#   rdfs:comment xsd:string ;
#   up:database IRI
# }
#
#
#
# http://purl.uniprot.org/core/Transit_Peptide_Annotation
# Transit Peptide
# Extent of a transit peptide (mitochondrion, chloroplast, thylakoid, cyanelle or microbody).
# up:Transit_Peptide_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   up:sequence [ up:Modified_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Transmembrane_Annotation
# Transmembrane
# Extent of a transmembrane region.
# up:Transmembrane_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   up:sequence [ up:Modified_Sequence ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Turn_Annotation
# Turn
# Turns within the experimentally determined protein structure.
# up:Turn_Annotation IRI {
#   up:range [ faldo:Region ]
# }
#
#
#
# http://purl.uniprot.org/core/Zinc_Finger_Annotation
# Zinc Finger
# Extent of a zinc finger region.
# up:Zinc_Finger_Annotation IRI {
#   up:range [ faldo:Region ] ;
#   rdfs:comment xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Transposon
# Transposon
# A transposon
# up:Transposon IRI {
#   rdfs:label xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Unknown_Sequence
# Unknown Sequence
# up:Unknown_Sequence IRI {
#   up:name xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Cluster
# Cluster (UniRef)
# Cluster of proteins with similar sequences.
# up:Cluster IRI {
#   up:member [ up:Sequence ] ;
#   up:identity xsd:float ;
#   rdfs:label xsd:string ;
#   up:modified xsd:date ;
#   up:commonTaxon IRI ;
#   up:someMembersClassifiedWith IRI
# }
#
#
#
# http://www.w3.org/2000/01/rdf-schema#Datatype
# rdfs:Datatype IRI {
#   owl:oneOf [ rdf:List ]
# }
#
#
#
# http://www.w3.org/1999/02/22-rdf-syntax-ns#List
# rdf:List IRI {
#   rdf:rest [ rdf:List ] ;
#   rdf:first xsd:float
# }
#
#
#
# http://purl.uniprot.org/core/Mass_Measurement_Method
# Mass Measurement
# An experimental method for measuring the mass of a molecule.
# up:Mass_Measurement_Method IRI {
#   rdfs:isDefinedBy [ owl:Ontology ] ;
#   rdfs:comment xsd:string ;
#   rdfs:label xsd:string ;
#   rdfs:seeAlso IRI
# }
#
#
#
# http://purl.uniprot.org/core/Organelle
# Organelle
# up:Organelle IRI {
#   rdfs:isDefinedBy [ owl:Ontology ] ;
#   rdfs:label xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Protein_Existence
# Protein existence evidence
# up:Protein_Existence IRI {
#   rdfs:isDefinedBy [ owl:Ontology ] ;
#   rdfs:comment xsd:string ;
#   rdfs:label xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Rank
# Taxon rank
# A rank of a taxon.
# up:Rank IRI {
#   rdfs:isDefinedBy [ owl:Ontology ] ;
#   rdfs:comment xsd:string ;
#   rdfs:label xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Status
# Status
# Indicator for the reliability of a piece of information.
# up:Status IRI {
#   rdfs:isDefinedBy [ owl:Ontology ] ;
#   rdfs:comment xsd:string ;
#   rdfs:label xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Structure_Determination_Method
# Structure Determination
# An experimental method for determining the 3D structure of a protein.
# up:Structure_Determination_Method IRI {
#   rdfs:isDefinedBy [ owl:Ontology ] ;
#   rdfs:comment xsd:string ;
#   rdfs:label xsd:string ;
#   rdfs:seeAlso IRI
# }
#
#
#
# http://purl.uniprot.org/core/Database
# Database (description of)
# Metadata for a life science database.
# up:Database IRI {
#   up:citation [ up:Citation ] ;
#   up:abbreviation xsd:string ;
#   up:category xsd:string ;
#   rdfs:comment xsd:string ;
#   dc:identifier xsd:string ;
#   rdfs:label xsd:string ;
#   up:linkIsExplicit xsd:boolean ;
#   up:urlTemplate xsd:string ;
#   rdfs:seeAlso IRI
# }
#
#
#
# http://purl.uniprot.org/core/Citation
# Citation
# Description of a publication from which data was obtained.
# up:Citation IRI {
#   dc:identifier xsd:string ;
#   skos:exactMatch IRI ;
#   foaf:primaryTopicOf IRI
# }
#
#
#
# http://purl.uniprot.org/core/Disease
# Disease
# up:Disease IRI {
#   skos:altLabel xsd:string ;
#   rdfs:comment xsd:string ;
#   up:mnemonic xsd:string ;
#   skos:prefLabel xsd:string ;
#   rdfs:seeAlso IRI
# }
#
#
#
# http://purl.uniprot.org/core/Enzyme
# Enzyme
# A specific catalytic activity, defined by the Enzyme Commission of the Nomenclature Committee of the International Union of Biochemistry and Molecular Biology (IUBMB).
# up:Enzyme IRI {
#   up:activity [ up:Catalytic_Activity ] ;
#   skos:broaderTransitive [ up:Enzyme ] ;
#   up:citation [ up:Citation ] ;
#   skos:narrowerTransitive [ up:Enzyme ] ;
#   up:replacedBy [ up:Enzyme ] ;
#   up:replaces [ up:Enzyme ] ;
#   rdfs:subClassOf [ up:Enzyme ] ;
#   skos:altLabel xsd:string ;
#   rdfs:comment xsd:string ;
#   up:obsolete xsd:boolean ;
#   skos:prefLabel xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Concept
# Concept
# A concept used to classify resources.
# up:Concept IRI {
#   up:category [ up:Concept ] ;
#   skos:narrower [ up:Concept ] ;
#   rdfs:seeAlso [ owl:Class ] ;
#   rdfs:subClassOf [ up:Concept ] ;
#   skos:altLabel xsd:string ;
#   rdfs:comment xsd:string ;
#   skos:prefLabel xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Cellular_Component
# Cellular Component
# up:Cellular_Component IRI {
#   up:citation [ up:Citation ] ;
#   skos:exactMatch [ owl:Class ] ;
#   up:partOf [ up:Cellular_Component ] ;
#   up:relatedLocation [ up:Cellular_Component ] ;
#   rdfs:subClassOf [ up:Cellular_Component ] ;
#   up:alias xsd:string ;
#   skos:altLabel xsd:string ;
#   rdfs:comment xsd:string ;
#   skos:prefLabel xsd:string ;
#   owl:sameAs IRI ;
#   rdfs:seeAlso IRI
# }
#
#
#
# http://purl.uniprot.org/core/Topology
# Topology
# up:Topology IRI {
#   up:relatedLocation [ up:Topology ] ;
#   rdfs:subClassOf [ up:Cellular_Component | up:Topology ] ;
#   up:alias xsd:string ;
#   skos:altLabel xsd:string ;
#   rdfs:comment xsd:string ;
#   skos:prefLabel xsd:string ;
#   owl:sameAs IRI
# }
#
#
#
# http://purl.org/ontology/bibo/Journal
# bibo:Journal IRI {
#   bibo:coden xsd:string ;
#   rdfs:comment xsd:string ;
#   bibo:eissn xsd:string ;
#   bibo:issn xsd:string ;
#   dc:publisher xsd:string ;
#   up:shortCoden xsd:string ;
#   bibo:shortTitle xsd:string ;
#   bibo:title xsd:string ;
#   skos:closeMatch IRI ;
#   skos:exactMatch IRI ;
#   rdfs:seeAlso IRI
# }
#
#
#
# http://purl.uniprot.org/core/Orientation
# Orientation
# up:Orientation IRI {
#   up:alias xsd:string ;
#   rdfs:comment xsd:string ;
#   skos:prefLabel xsd:string ;
#   rdfs:subClassOf IRI
# }
#
#
#
# http://purl.uniprot.org/core/Pathway
# Pathway
# A hierarchical discription of a metabolic pathway.
# up:Pathway IRI {
#   skos:narrower [ up:Pathway ] ;
#   rdfs:subClassOf [ up:Pathway ] ;
#   rdfs:label xsd:string
# }
#
#
#
# http://purl.uniprot.org/core/Representative_Proteome
# Representative_Proteome
# A proteome that is believed by curators, or selected programmatically to be representative for a number of related Proteomes
# up:Representative_Proteome IRI {
#   up:citation [ up:Book_Citation | up:Journal_Citation | up:Submission_Citation ] ;
#   skos:closeMatch [ obo:STATO_0000193 ] ;
#   busco:has_score [ busco:Score ] ;
#   skos:narrower [ up:Proteome_Component ] ;
#   up:panproteome [ up:Proteome | up:Reference_Proteome | up:Representative_Proteome ] ;
#   up:strain [ up:Strain ] ;
#   rdfs:comment xsd:string ;
#   up:exclusionReason xsd:string ;
#   dc:modified xsd:date ;
#   up:organism IRI ;
#   rdfs:seeAlso IRI
# }
#
#
#
# http://www.w3.org/2000/01/rdf-schema#Class
# rdfs:Class IRI {
#   rdfs:subClassOf [ rdfs:Class ] ;
#   rdfs:comment xsd:string ;
#   rdfs:label xsd:string
# }
#
#
#
# 140
