# %% [markdown]
# # 🐢 Generate RDF files for Bgee SPARQL queries
#
# Queries from https://github.com/RIKEN-DKO/Generation_SPARQL/blob/main/augment_queries/augment_queries.ipynb
#
# Extracted from Bgee SPARQL tutorial https://www.bgee.org/support/tutorial-query-bgee-knowledge-graph-sparql
#
# To be added to https://github.com/sib-swiss/sparql-examples

# %%
bgee_queries = [
    {
        "id": "1",
        "description": "What are the species present in Bgee?",
        "query": """
PREFIX up: <http://purl.uniprot.org/core/>

SELECT ?species WHERE {
    # ?species a up:Taxon .
}
""",
    },
    {
        "id": "2",
        "description": "What are the species present in Bgee and their scientific and common names?",
        "query": """
PREFIX up: <http://purl.uniprot.org/core/>

SELECT ?species ?sci_name ?common_name WHERE {
    # ?species a up:Taxon ;
        up:scientificName ?sci_name ;
        up:rank up:Species .
    OPTIONAL { ?species up:commonName ?common_name . }
}
""",
    },
    {
        "id": "3",
        "description": "What are the anatomical entities where the APOC1 gene is expressed?",
        "query": """
PREFIX orth: <http://purl.org/net/orth#>
PREFIX genex: <http://purl.org/genex#>
PREFIX obo: <http://purl.obolibrary.org/obo/>

SELECT DISTINCT ?anat ?anatName WHERE {
    # ?seq a orth:Gene ;
        genex:isExpressedIn ?anat ;
        rdfs:label "APOC1" .
    # ?anat a genex:AnatomicalEntity ;
        rdfs:label ?anatName .
}
""",
    },
    {
        "id": "4",
        "description": "What are the anatomical entities where the APOC1 Homo sapiens gene is expressed?",
        "query": """
PREFIX orth: <http://purl.org/net/orth#>
PREFIX genex: <http://purl.org/genex#>
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX up: <http://purl.uniprot.org/core/>

SELECT DISTINCT ?anat ?anatName WHERE {
    # ?seq a orth:Gene ;
        genex:isExpressedIn ?anat ;
        rdfs:label "APOC1" .
    # ?anat a genex:AnatomicalEntity ;
        rdfs:label ?anatName .
    # ?seq orth:organism ?organism .
    # ?organism obo:RO_0002162  ?species .
    # ?species a up:Taxon ;
        up:scientificName "Homo sapiens" .
}
""",
    },
    {
        "id": "5",
        "description": "What are the anatomical entities where the APOC1 gene is expressed independently of the developmental stage, sex, strain and cell type?",
        "query": """
PREFIX orth: <http://purl.org/net/orth#>
PREFIX genex: <http://purl.org/genex#>
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX efo: <http://www.ebi.ac.uk/efo/>

SELECT DISTINCT ?anat ?anatName {
    # ?seq a orth:Gene ;
        genex:isExpressedIn ?condition ;
        rdfs:label "APOC1" .
    # ?condition a genex:ExpressionCondition ;
        genex:hasAnatomicalEntity ?anat ;
        genex:hasAnatomicalEntity obo:GO_0005575 ;
        genex:hasDevelopmentalStage ?stage ;
        genex:hasSex "any" ;
        genex:hasStrain ?strain .
    # ?anat a genex:AnatomicalEntity ;
        rdfs:label ?anatName .
    # ?stage a efo:EFO_0000399 ;
        rdfs:label "life cycle" .
    # ?strain rdfs:label "wild-type" .
}
""",
    },
    {
        "id": "6",
        "description": "What are the anatomical entities where the human gene APOC1 is expressed in the post-juvenile stage?",
        "query": """
PREFIX orth: <http://purl.org/net/orth#>
PREFIX genex: <http://purl.org/genex#>
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX up: <http://purl.uniprot.org/core/>
PREFIX efo: <http://www.ebi.ac.uk/efo/>

SELECT DISTINCT ?anat ?anatName ?stage WHERE {
    # ?seq a orth:Gene ;
        rdfs:label "APOC1" ;
        genex:isExpressedIn ?condition ;
        orth:organism ?organism .
    # ?condition a genex:ExpressionCondition ;
        genex:hasAnatomicalEntity ?anat ;
        genex:hasAnatomicalEntity obo:GO_0005575 ;
        genex:hasDevelopmentalStage ?stage ;
        genex:hasSex "any" ;
        genex:hasStrain ?strain .
    # ?anat rdfs:label ?anatName .
    # ?stage a efo:EFO_0000399 ;
        rdfs:label "post-juvenile" .
    # ?strain a efo:EFO_0005135 ;
        rdfs:label "wild-type" .
    # ?organism obo:RO_0002162  ?species .
    # ?species a up:Taxon ;
        up:commonName "human" .
}
""",
    },
    {
        "id": "7",
        "description": "What are the anatomical entities where the human gene APOC1 is expressed in the post-juvenile stage?",
        "query": """
PREFIX orth: <http://purl.org/net/orth#>
PREFIX genex: <http://purl.org/genex#>
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX up: <http://purl.uniprot.org/core/>
PREFIX efo: <http://www.ebi.ac.uk/efo/>

SELECT DISTINCT ?anat ?anatName ?stage WHERE {
    # ?seq a orth:Gene ;
        rdfs:label "APOC1" ;
        genex:isExpressedIn ?condition ;
        orth:organism ?organism .
    # ?condition a genex:ExpressionCondition ;
        genex:hasAnatomicalEntity ?anat ;
        genex:hasAnatomicalEntity obo:GO_0005575 ;
        genex:hasDevelopmentalStage ?stage .
    # ?anat a genex:AnatomicalEntity ;
        rdfs:label ?anatName .
    # ?stage a efo:EFO_0000399 ;
        rdfs:label "post-juvenile" .
    # ?organism obo:RO_0002162  ?species .
    # ?species a up:Taxon ;
        up:commonName "human" .
}
""",
    },
    {
        "id": "8",
        "description": "What are the anatomical entities where the human gene APOC1 is expressed in the post-juvenile stage along with its expression score independently of the strain, sex, and cell type?",
        "query": """
PREFIX orth: <http://purl.org/net/orth#>
PREFIX genex: <http://purl.org/genex#>
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX up: <http://purl.uniprot.org/core/>

SELECT DISTINCT ?anat ?anatName ?score ?stage WHERE {
    # ?seq a orth:Gene ;
        rdfs:label "APOC1" ;
        orth:organism ?organism .
    # ?expression a genex:Expression ;
        genex:hasExpressionCondition ?condition ;
        genex:hasExpressionLevel ?score ;
        genex:hasSequenceUnit ?seq .
    # ?condition a genex:ExpressionCondition ;
        genex:hasAnatomicalEntity ?anat ;
        genex:hasAnatomicalEntity obo:GO_0005575 ;
        genex:hasDevelopmentalStage ?stage ;
        genex:hasSex "any" ;
        genex:hasStrain ?strain .
    # ?anat a genex:AnatomicalEntity ;
        rdfs:label ?anatName .
    # ?stage rdfs:label "post-juvenile" .
    # ?strain rdfs:label "wild-type" .
    # ?organism obo:RO_0002162  ?species .
    # ?species a up:Taxon ;
        up:commonName "human" .
FILTER (?anat !=  obo:GO_0005575)
} ORDER BY DESC(?score)
""",
    },
    {
        "id": "8-a",
        "description": "What are the anatomical entities where the human gene APOC1 is expressed at the post-juvenile stage along with its expression score independently of the strain, sex, and cell type?",
        "query": """
PREFIX orth: <http://purl.org/net/orth#>
PREFIX genex: <http://purl.org/genex#>
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX up: <http://purl.uniprot.org/core/>
PREFIX up-taxon:<http://purl.uniprot.org/taxonomy/>
PREFIX ensembl: <http://rdf.ebi.ac.uk/resource/ensembl/>
PREFIX lscr: <http://purl.org/lscr#>
PREFIX efo: <http://www.ebi.ac.uk/efo/>

SELECT DISTINCT ?anat ?anatName ?score WHERE {
    # ?seq a orth:Gene .
    # ?expression a genex:Expression ;
        genex:hasExpressionCondition ?condition ;
        genex:hasExpressionLevel ?score ;
        genex:hasSequenceUnit ?seq .
    # ?seq lscr:xrefEnsemblGene ensembl:ENSG00000130208 .
    # ?condition a genex:ExpressionCondition ;
        genex:hasAnatomicalEntity ?anat .
    # ?anat a genex:AnatomicalEntity ;
        rdfs:label ?anatName .
    # ?condition genex:hasDevelopmentalStage obo:UBERON_0000113 ;
        genex:hasSex "any" ;
        genex:hasStrain ?strain .
    # ?strain a efo:EFO_0005135 ;
        rdfs:label "wild-type" .
    # ?seq orth:organism ?organism .
    # ?organism obo:RO_0002162  up-taxon:9606 .
    FILTER (?anat !=  obo:GO_0005575)
} ORDER BY DESC(?score)
""",
    },
    {
        "id": "8-b",
        "description": "What are the anatomical entities where the human gene APOC1 is expressed at the post-juvenile stage along with its expression score independently of the strain, sex, and cell type?",
        "query": """
PREFIX orth: <http://purl.org/net/orth#>
PREFIX genex: <http://purl.org/genex#>
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX up: <http://purl.uniprot.org/core/>
PREFIX up-taxon:<http://purl.uniprot.org/taxonomy/>
PREFIX ensembl: <http://rdf.ebi.ac.uk/resource/ensembl/>
PREFIX lscr: <http://purl.org/lscr#>
PREFIX efo: <http://www.ebi.ac.uk/efo/>

SELECT DISTINCT ?anat ?anatName ?score  {
    # ?seq a orth:Gene ;
        lscr:xrefEnsemblGene ensembl:ENSG00000130208 .
    # ?expression a genex:Expression ;
        genex:hasExpressionCondition ?condition ;
        genex:hasExpressionLevel ?score ;
        genex:hasSequenceUnit ?seq .
    # ?condition a genex:ExpressionCondition ;
        genex:hasAnatomicalEntity ?anat ;
        genex:hasDevelopmentalStage obo:UBERON_0000113 ;
        genex:hasSex "any" ;
        genex:hasStrain ?strain .
    # ?anat a genex:AnatomicalEntity ;
        rdfs:label ?anatName .
    # ?strain a efo:EFO_0005135 ;
        rdfs:label "wild-type" .
    FILTER (?anat !=  obo:GO_0005575)
} ORDER BY DESC(?score)
""",
    },
    {
        "id": "9",
        "description": "What are the anatomical entities including cell types, if any, where the human gene APOC1 is expressed at the post-juvenile stage along with its expression score independently of the strain and sex?",
        "query": """
PREFIX orth: <http://purl.org/net/orth#>
PREFIX genex: <http://purl.org/genex#>
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX up: <http://purl.uniprot.org/core/>
PREFIX efo: <http://www.ebi.ac.uk/efo/>

SELECT DISTINCT ?anat ?cellType ?anatName ?cellTypeName ?score ?stage WHERE {
    # ?seq a orth:Gene ;
        rdfs:label "APOC1" ;
        orth:organism ?organism .
    # ?expression a genex:Expression ;
        genex:hasExpressionCondition ?condition ;
        genex:hasExpressionLevel ?score ;
        genex:hasSequenceUnit ?seq .
    # ?condition a genex:ExpressionCondition ;
        genex:hasAnatomicalEntity ?anat ;
        genex:hasAnatomicalEntity ?cellType ;
        genex:hasDevelopmentalStage ?stage ;
        genex:hasSex "any" ;
        genex:hasStrain ?strain .
    # ?anat a genex:AnatomicalEntity ;
        rdfs:label ?anatName .
    # ?cellType rdfs:label ?cellTypeName .
    # ?stage rdfs:label "post-juvenile" .
    # ?strain a efo:EFO_0005135 ;
        rdfs:label "wild-type" .
    # ?organism obo:RO_0002162  ?species .
    # ?species a up:Taxon ;
        up:commonName "human" .
    FILTER (?anat != obo:GO_0005575)
    FILTER (?anat != ?cellType)
} ORDER BY DESC(?score)
""",
    },
    {
        "id": "10",
        "description": "What are the anatomical entities including cell types, if any, where the human gene APOC1 is expressed at the post-juvenile stage along with its expression score independently of the strain and sex?",
        "query": """
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX orth: <http://purl.org/net/orth#>
PREFIX genex: <http://purl.org/genex#>
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX up: <http://purl.uniprot.org/core/>
PREFIX efo: <http://www.ebi.ac.uk/efo/>

SELECT DISTINCT ?anat ?cellType ?anatName ?cellTypeName ?score ?stage WHERE {
    # ?seq a orth:Gene ;
        rdfs:label "APOC1" ;
        orth:organism ?organism .
    # ?expression a genex:Expression ;
        genex:hasExpressionCondition ?condition ;
        genex:hasExpressionLevel ?score ;
        genex:hasSequenceUnit ?seq .
    # ?condition a genex:ExpressionCondition ;
        genex:hasAnatomicalEntity ?anat ;
        genex:hasAnatomicalEntity ?cellType ;
        genex:hasDevelopmentalStage ?stage .
    # ?anat a genex:AnatomicalEntity ;
        rdfs:label ?anatName .
    # ?cellType rdfs:label ?cellTypeName .
    # ?stage a efo:EFO_0000399 ;
        rdfs:label "post-juvenile" .
    # ?organism obo:RO_0002162  ?species .
    # ?species a up:Taxon ;
        up:commonName "human" .
    FILTER (?anat !=  obo:GO_0005575)
    FILTER (?anat != ?cellType)
} ORDER BY DESC(?score)
""",
    },
    {
        "id": "11",
        "description": "What are the developmental stages present in Bgee?",
        "query": """
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX dcterms: <http://purl.org/dc/terms/>
PREFIX efo: <http://www.ebi.ac.uk/efo/>

SELECT DISTINCT ?stage ?stageName ?stageDescription WHERE {
    # ?stage a efo:EFO_0000399 ;
        rdfs:label ?stageName ;
        dcterms:description ?stageDescription .
}
""",
    },
    {
        "id": "11-a",
        "description": "What is the post-juvenile stage link and description?",
        "query": """
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX dcterms: <http://purl.org/dc/terms/>
PREFIX efo: <http://www.ebi.ac.uk/efo/>

SELECT DISTINCT ?stage ?stageName ?stageDescription WHERE {
    # ?stage a efo:EFO_0000399 ;
        rdfs:label ?stageName ;
        dcterms:description ?stageDescription .
    FILTER (CONTAINS(?stageName,"post-juvenile"))
}
""",
    },
    {
        "id": "12",
        "description": "What are the anatomical entities where the eel gene apoc1 is expressed along with its expression score independently of the strain, sex, and cell type?",
        "query": """PREFIX orth: <http://purl.org/net/orth#>
PREFIX genex: <http://purl.org/genex#>
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX up: <http://purl.uniprot.org/core/>
PREFIX up-taxon:<http://purl.uniprot.org/taxonomy/>
PREFIX lscr: <http://purl.org/lscr#>
PREFIX dcterms: <http://purl.org/dc/terms/>
PREFIX efo: <http://www.ebi.ac.uk/efo/>

SELECT DISTINCT ?anat ?anatName ?stageIRI ?score WHERE {
    # ?seq a orth:Gene ;
        lscr:xrefNCBIGene <https://www.ncbi.nlm.nih.gov/gene/118230125> .
    # ?expression a genex:Expression ;
        genex:hasExpressionCondition ?condition ;
        genex:hasExpressionLevel ?score ;
        genex:hasSequenceUnit ?seq .
    # ?anat a genex:AnatomicalEntity ;
        rdfs:label ?anatName .
    # ?condition a genex:ExpressionCondition ;
        genex:hasAnatomicalEntity ?anat ;
        genex:hasDevelopmentalStage ?stageIRI ;
        genex:hasSex "any" ;
        genex:hasStrain ?strain .
    # ?stageIRI a efo:EFO_0000399 .
    # ?strain a efo:EFO_0005135 ;
        rdfs:label "wild-type" .
    FILTER (?anat != obo:GO_0005575)
} ORDER BY DESC(?score)
""",
    },
    {
        "id": "12-a",
        "description": "What are the anatomical entities where the eel gene apoc1 is expressed along with its expression score independently of the strain, sex, and cell type?",
        "query": """
PREFIX orth: <http://purl.org/net/orth#>
PREFIX genex: <http://purl.org/genex#>
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX up: <http://purl.uniprot.org/core/>
PREFIX up-taxon:<http://purl.uniprot.org/taxonomy/>
PREFIX lscr: <http://purl.org/lscr#>
PREFIX dcterms: <http://purl.org/dc/terms/>
PREFIX efo: <http://www.ebi.ac.uk/efo/>

SELECT DISTINCT ?anat ?anatName ?stageIRI ?score WHERE {
    # ?seq a orth:Gene ;
        dcterms:identifier "118230125" .
    # ?expression a genex:Expression ;
        genex:hasExpressionCondition ?condition ;
        genex:hasExpressionLevel ?score ;
        genex:hasSequenceUnit ?seq .
    # ?condition a genex:ExpressionCondition ;
        genex:hasAnatomicalEntity ?anat ;
        genex:hasDevelopmentalStage ?stageIRI ;
        genex:hasSex "any" ;
        genex:hasStrain ?strain .
    # ?anat rdfs:label ?anatName .
    # ?strain a efo:EFO_0005135 ;
        rdfs:label "wild-type" .
FILTER (?anat !=  obo:GO_0005575)
} ORDER BY DESC(?score)
""",
    },
    {
        "id": "13",
        "description": "What are the anatomical entities where the P02654 gene is expressed? Note that P02654 is a UniProtKB identifier of the APOC1 human gene.",
        "query": """
PREFIX orth: <http://purl.org/net/orth#>
PREFIX genex: <http://purl.org/genex#>
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX up-protein:<http://purl.uniprot.org/uniprot/>
PREFIX lscr: <http://purl.org/lscr#>

SELECT DISTINCT ?anat ?anatName WHERE {
    # ?seq a orth:Gene ;
        genex:isExpressedIn ?anat ;
        lscr:xrefUniprot up-protein:P02654 .
    # ?anat a genex:AnatomicalEntity ;
        rdfs:label ?anatName .
}
""",
    },
    {
        "id": "14",
        "description": "What is all the metadata related to the ENSG00000130208 gene, where ENSG00000130208 is the identifier of the APOC1 human gene.",
        "query": """
PREFIX orth: <http://purl.org/net/orth#>
PREFIX lscr: <http://purl.org/lscr#>
PREFIX dcterms: <http://purl.org/dc/terms/>

SELECT DISTINCT ?symbol ?description ?id
# ?links ?organism ?uniprot ?ensembl ?ncbi WHERE {
    # ?seq a orth:Gene ;
        rdfs:label ?symbol ;
        rdfs:seeAlso ?links ;
        dcterms:description ?description ;
        dcterms:identifier ?id ;
        orth:organism ?organism .
    OPTIONAL{?seq lscr:xrefUniprot ?uniprot .}
    OPTIONAL{?seq lscr:xrefEnsemblGene ?ensembl .}
    OPTIONAL{?seq lscr:xrefNCBIGene ?ncbi .}
    FILTER (?id = "ENSG00000130208")
}
""",
    },
    {
        "id": "15",
        "description": "What are the anatomical entities where the APOC1 Homo sapiens gene is not expressed, that is where is APOC1 absent?",
        "query": """
PREFIX orth: <http://purl.org/net/orth#>
PREFIX genex: <http://purl.org/genex#>
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX up: <http://purl.uniprot.org/core/>

SELECT DISTINCT ?anat ?anatName WHERE {
    # ?seq a orth:Gene ;
        rdfs:label "APOC1" ;
        genex:isAbsentIn ?anat ;
        orth:organism ?organism .
    # ?anat a genex:AnatomicalEntity ;
        rdfs:label ?anatName .
    # ?organism obo:RO_0002162  ?species .
    # ?species a up:Taxon ;
        up:scientificName "Homo sapiens" .
}
""",
    },
]

# %%
# also store NL questions corresponding to the queries

nlqs = [None] * 16

nlqs[0] = ""
nlqs[1] = "What are the species present in Bgee?"
nlqs[2] = "What are the species present in Bgee and their scientific and common names?"
nlqs[3] = "What are the anatomical entities where the APOC1 gene is expressed?"
nlqs[4] = (
    "What are the anatomical entities where the APOC1 Homo sapiens gene is expressed?"
)
nlqs[5] = (
    "What are the anatomical entities where the APOC1 gene is expressed independently of the developmental stage, sex, strain and cell type?"
)
nlqs[6] = (
    "What are the anatomical entities where the human gene APOC1 is expressed in the post-juvenile stage?"
)
nlqs[7] = (
    "What are the anatomical entities where the human gene APOC1 is expressed in the post-juvenile stage?"
)
nlqs[8] = (
    "What are the anatomical entities where the human gene APOC1 is expressed in the post-juvenile stage along with its expression score independently of the strain, sex, and cell type?"
)
nlqs[9] = (
    "What are the anatomical entities including cell types, if any, where the human gene APOC1 is expressed at the post-juvenile stage along with its expression score independently of the strain and sex?"
)
nlqs[10] = (
    "What are the anatomical entities including cell types, if any, where the human gene APOC1 is expressed at the post-juvenile stage along with its expression score independently of the strain and sex?"
)
nlqs[11] = "What are the developmental stages present in Bgee?"
nlqs[12] = (
    "What are the anatomical entities where the eel gene apoc1 is expressed along with its expression score independently of the strain, sex, and cell type?"
)
nlqs[13] = (
    "What are the anatomical entities where the P02654 gene is expressed? Note that P02654 is a UniProtKB identifier of the APOC1 human gene."
)
nlqs[14] = (
    "What is all the metadata related to the ENSG00000130208 gene, where ENSG00000130208 is the identifier of the APOC1 human gene. "
)
nlqs[15] = (
    "What are the anatomical entities where the APOC1 Homo sapiens gene is not expressed, that is where is APOC1 absent ?"
)

# %%
import os

from rdflib import RDF, RDFS, BNode, Graph, Literal, Namespace
from SPARQLWrapper import JSON, SPARQLWrapper

queries_dir = "../../sparql-examples/bgee"
# queries_dir = "../data/bgee_queries"
os.makedirs(queries_dir, exist_ok=True)

EX = Namespace("https://www.bgee.org/sparql/.well-known/sparql-examples/")
UP = Namespace("http://purl.uniprot.org/core/")
SH = Namespace("http://www.w3.org/ns/shacl#")

sparql_endpoint = SPARQLWrapper("https://www.bgee.org/sparql/")
sparql_endpoint.setReturnFormat(JSON)

# for i in range(1, len(nlqs)):
for bq in bgee_queries:
    g = Graph()
    g.bind("ex", EX)
    g.bind("up", UP)
    g.bind("sh", SH)
    g.bind("rdf", RDF)
    g.bind("rdfs", RDFS)

    query_resource = EX[str(bq["id"])]
    g.add((query_resource, RDF.type, SH.SPARQLSelectExecutable))
    g.add((query_resource, RDF.type, SH.SPARQLExecutable))
    g.add((query_resource, SH.prefixes, BNode("sparql_examples_prefixes")))

    g.add((query_resource, RDFS.comment, Literal(bq["description"])))
    # TODO: what do we do for 8, 11 and 12 that have multiple queries for 1 description?
    # query = qs[i][0]
    g.add((query_resource, SH.select, Literal(bq["query"])))

    # Check query gets results
    try:
        sparql_endpoint.setQuery(bq["query"])
        results = sparql_endpoint.query().convert()
        n_res = len(results["results"]["bindings"])
        if n_res > 0:
            print(f"✅ Query {bq['id']} got {n_res} results")
        else:
            print(f"⚠️ Query {bq['id']} got {n_res} results")
    except Exception as e:
        print(f"❌ Query {bq['id']} failed: {e}")

    # NOTE: Dirty hack to get the BNode formatted as we want. Otherwise RDFLib expands it to [ ]
    ttl_str = g.serialize(format="turtle").replace(
        "sh:prefixes [ ] ;", "sh:prefixes _:sparql_examples_prefixes ;"
    )
    with open(f"{queries_dir}/{bq['id']}.ttl", "w") as f:
        f.write(ttl_str)
# Out:
# ✅ Query 1 got 52 results
# ✅ Query 2 got 52 results
# ✅ Query 3 got 584 results
# ✅ Query 4 got 526 results
# ✅ Query 5 got 585 results
# ✅ Query 6 got 457 results
# ✅ Query 7 got 457 results
# ✅ Query 8 got 456 results
# ✅ Query 8-a got 456 results
# ✅ Query 8-b got 456 results
# ✅ Query 9 got 456 results
# ✅ Query 10 got 456 results
# ✅ Query 11 got 1155 results
# ✅ Query 11-a got 1 results
# ✅ Query 12 got 99 results
# ✅ Query 12-a got 99 results
# ✅ Query 13 got 526 results
# ✅ Query 14 got 16 results
# ✅ Query 15 got 6 results
