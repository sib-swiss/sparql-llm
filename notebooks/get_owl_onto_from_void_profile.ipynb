# %% [markdown]
# Generate OWL ontology from VoID profile
#
# TODO: this way? But VoID is missing data properties like `rdfs:label`
#
# ```turtle
# up:Gene rdfs:label xsd:string ;
#   up:encode up:Protein .
# ```

# %%
import requests
from rdflib import Graph

query = """PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX sh: <http://www.w3.org/ns/shacl#>
PREFIX void: <http://rdfs.org/ns/void#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>

CONSTRUCT {
    # ?class1 a owl:Class ;
        rdfs:label ?class1Label ;
        rdfs:comment ?class1Comment ;
        rdfs:subClassOf ?superClass1 .

    # ?prop a owl:ObjectProperty ;
        rdfs:domain ?class1 ;
        rdfs:range ?class2 ;
        rdfs:label ?propLabel ;
        rdfs:comment ?propComment ;
        rdfs:subPropertyOf ?superProp .

    # ?class2 a owl:Class ;
        rdfs:label ?class2Label ;
        rdfs:comment ?class2Comment .

} WHERE {
    # ?s <http://www.w3.org/ns/sparql-service-description#graph> ?graph .
    # ?graph void:classPartition ?cp1 .
    # ?cp1 void:class ?class1 ;
          void:propertyPartition ?pp1 .
    # ?pp1 void:property ?prop ;
          void:triples ?pp1triples ;
          void:classPartition ?cp2 .
    # ?cp2 void:class ?class2 .

    OPTIONAL { ?class1 rdfs:label ?class1Label . }
    OPTIONAL { ?class2 rdfs:label ?class2Label . }
    OPTIONAL { ?prop rdfs:label ?propLabel . }

    OPTIONAL { ?class1 rdfs:comment ?class1Comment . }
    OPTIONAL { ?class2 rdfs:comment ?class2Comment . }
    OPTIONAL { ?prop rdfs:comment ?propComment . }

    OPTIONAL {
        # ?class1 rdfs:subClassOf ?superClass1 .
        FILTER (isIRI(?superClass1))
    }
    OPTIONAL {
        # ?prop rdfs:subPropertyOf ?superProp .
        FILTER (isIRI(?superProp))
    }
    OPTIONAL {
        # ?class2 rdfs:subClassOf ?superClass2 .
        FILTER (isIRI(?superClass2))
    }
} ORDER BY DESC(?pp1triples)"""

response = requests.post(
    "https://sparql.uniprot.org/sparql/",
    headers={"Accept": "text/turtle"},
    data={"query": query},
    timeout=60,
)
response.raise_for_status()
g = Graph()
g.bind("faldo", "http://biohackathon.org/resource/faldo#")
g.bind("up", "http://purl.uniprot.org/core/")

g.parse(data=response.text, format="turtle")

# print(response.text)
print(g.serialize(format="turtle"))
print(len(g))
# Out:
# @prefix faldo: <http://biohackathon.org/resource/faldo#> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix sh: <http://www.w3.org/ns/shacl#> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
# @prefix up: <http://purl.uniprot.org/core/> .
#
# faldo:begin a owl:ObjectProperty ;
#     rdfs:domain faldo:InRangePosition,
#         faldo:Position,
#         faldo:Region ;
#     rdfs:range faldo:ExactPosition,
#         faldo:InRangePosition,
#         faldo:OneOfPosition,
#         faldo:Position .
#
# faldo:end a owl:ObjectProperty ;
#     rdfs:domain faldo:InRangePosition,
#         faldo:Position,
#         faldo:Region ;
#     rdfs:range faldo:ExactPosition,
#         faldo:InRangePosition,
#         faldo:OneOfPosition,
#         faldo:Position .
#
# faldo:possiblePosition a owl:ObjectProperty ;
#     rdfs:domain faldo:OneOfPosition,
#         faldo:Position ;
#     rdfs:range faldo:ExactPosition,
#         faldo:Position .
#
# faldo:reference a owl:ObjectProperty ;
#     rdfs:domain faldo:ExactPosition,
#         faldo:InRangePosition,
#         faldo:OneOfPosition,
#         faldo:Position ;
#     rdfs:range up:External_Sequence,
#         up:Modified_Sequence,
#         up:Simple_Sequence .
#
# <http://busco.ezlab.org/schema#has_score> a owl:ObjectProperty ;
#     rdfs:domain up:Proteome,
#         up:Reference_Proteome,
#         up:Representative_Proteome ;
#     rdfs:range <http://busco.ezlab.org/schema#Score> .
#
# up:activity a owl:ObjectProperty ;
#     rdfs:label "catalytic activity" ;
#     rdfs:comment "The catalytic activity of an enzyme." ;
#     rdfs:domain up:Enzyme ;
#     rdfs:range up:Catalytic_Activity .
#
# up:alternativeName a owl:ObjectProperty ;
#     rdfs:label "alternativeName" ;
#     rdfs:comment "A synonym of the recommended name." ;
#     rdfs:domain up:Part,
#         up:Protein ;
#     rdfs:range up:Structured_Name ;
#     rdfs:subPropertyOf up:structuredName .
#
# up:annotation a owl:ObjectProperty ;
#     rdfs:label "annotation" ;
#     rdfs:comment "Attaches an annotation to a resource." ;
#     rdfs:domain up:Protein ;
#     rdfs:range up:Absorption_Annotation,
#         up:Active_Site_Annotation,
#         up:Activity_Regulation_Annotation,
#         up:Allergen_Annotation,
#         up:Alternative_Initiation_Annotation,
#         up:Alternative_Promoter_Usage_Annotation,
#         up:Alternative_Sequence_Annotation,
#         up:Alternative_Splicing_Annotation,
#         up:Annotation,
#         up:Beta_Strand_Annotation,
#         up:Binding_Site_Annotation,
#         up:Biotechnology_Annotation,
#         up:Catalytic_Activity_Annotation,
#         up:Caution_Annotation,
#         up:Chain_Annotation,
#         up:Cofactor_Annotation,
#         up:Coiled_Coil_Annotation,
#         up:Compositional_Bias_Annotation,
#         up:Cross-link_Annotation,
#         up:Developmental_Stage_Annotation,
#         up:Disease_Annotation,
#         up:Disruption_Phenotype_Annotation,
#         up:Disulfide_Bond_Annotation,
#         up:Domain_Annotation,
#         up:Domain_Extent_Annotation,
#         up:Erroneous_Gene_Model_Prediction_Annotation,
#         up:Erroneous_Initiation_Annotation,
#         up:Erroneous_Termination_Annotation,
#         up:Erroneous_Translation_Annotation,
#         up:Frameshift_Annotation,
#         up:Function_Annotation,
#         up:Glycosylation_Annotation,
#         up:Helix_Annotation,
#         up:Induction_Annotation,
#         up:Initiator_Methionine_Annotation,
#         up:Intramembrane_Annotation,
#         up:Kinetics_Annotation,
#         up:Lipidation_Annotation,
#         up:Mass_Spectrometry_Annotation,
#         up:Modified_Residue_Annotation,
#         up:Motif_Annotation,
#         up:Mutagenesis_Annotation,
#         up:Natural_Variant_Annotation,
#         up:Non-adjacent_Residues_Annotation,
#         up:Non-standard_Residue_Annotation,
#         up:Non-terminal_Residue_Annotation,
#         up:Nucleotide_Binding_Annotation,
#         up:PH_Dependence_Annotation,
#         up:PTM_Annotation,
#         up:Pathway_Annotation,
#         up:Peptide_Annotation,
#         up:Pharmaceutical_Annotation,
#         up:Polymorphism_Annotation,
#         up:Propeptide_Annotation,
#         up:RNA_Editing_Annotation,
#         up:Redox_Potential_Annotation,
#         up:Region_Annotation,
#         up:Repeat_Annotation,
#         up:Ribosomal_Frameshifting,
#         up:Sequence_Caution_Annotation,
#         up:Sequence_Conflict_Annotation,
#         up:Sequence_Uncertainty_Annotation,
#         up:Signal_Peptide_Annotation,
#         up:Similarity_Annotation,
#         up:Site_Annotation,
#         up:Subcellular_Location_Annotation,
#         up:Subunit_Annotation,
#         up:Temperature_Dependence_Annotation,
#         up:Tissue_Specificity_Annotation,
#         up:Topological_Domain_Annotation,
#         up:Toxic_Dose_Annotation,
#         up:Transit_Peptide_Annotation,
#         up:Transmembrane_Annotation,
#         up:Turn_Annotation,
#         up:Zinc_Finger_Annotation .
#
# up:basedOn a owl:ObjectProperty ;
#     rdfs:label "based on" ;
#     rdfs:comment "The sequence on which the description of a modified sequence is based." ;
#     rdfs:domain up:External_Sequence,
#         up:Modified_Sequence ;
#     rdfs:range up:External_Sequence,
#         up:Simple_Sequence .
#
# up:catalyticActivity a owl:ObjectProperty ;
#     rdfs:label "catalytic activity" ;
#     rdfs:domain up:Catalytic_Activity_Annotation ;
#     rdfs:range up:Catalytic_Activity .
#
# up:category a owl:ObjectProperty ;
#     rdfs:label "category" ;
#     rdfs:domain up:Concept ;
#     rdfs:range up:Concept .
#
# up:citation a owl:ObjectProperty ;
#     rdfs:label "citation" ;
#     rdfs:comment "A publication from which data was extracted, or which contains additional information." ;
#     rdfs:domain up:Cellular_Component,
#         up:Database,
#         up:Enzyme,
#         up:External_Sequence,
#         up:Nucleotide_Resource,
#         up:Protein,
#         up:Proteome,
#         up:Reference_Proteome,
#         up:Representative_Proteome,
#         rdf:Statement ;
#     rdfs:range up:Book_Citation,
#         up:Citation,
#         up:Electronic_Citation,
#         up:Journal_Citation,
#         up:Observation_Citation,
#         up:Patent_Citation,
#         up:Submission_Citation,
#         up:Thesis_Citation .
#
# up:component a owl:ObjectProperty ;
#     rdfs:label "proteome component" ;
#     rdfs:comment "A component of a protein." ;
#     rdfs:domain up:Protein ;
#     rdfs:range up:Part ;
#     rdfs:subPropertyOf up:part .
#
# up:conflictingSequence a owl:ObjectProperty ;
#     rdfs:label "conflicting sequence" ;
#     rdfs:domain up:Erroneous_Gene_Model_Prediction_Annotation,
#         up:Erroneous_Initiation_Annotation,
#         up:Erroneous_Termination_Annotation,
#         up:Erroneous_Translation_Annotation,
#         up:Frameshift_Annotation,
#         up:Protein,
#         up:Sequence_Caution_Annotation,
#         up:Sequence_Conflict_Annotation ;
#     rdfs:range up:External_Sequence .
#
# up:context a owl:ObjectProperty ;
#     rdfs:label "context" ;
#     rdfs:domain up:Citation_Statement,
#         rdf:Statement ;
#     rdfs:range up:Plasmid,
#         up:Strain,
#         up:Tissue,
#         up:Transposon .
#
# up:domain a owl:ObjectProperty ;
#     rdfs:label "domain" ;
#     rdfs:comment "A domain of a protein." ;
#     rdfs:domain up:Protein ;
#     rdfs:range up:Part ;
#     rdfs:subPropertyOf up:part .
#
# up:encodedBy a owl:ObjectProperty ;
#     rdfs:label "encoded by" ;
#     rdfs:comment "The gene by which a protein is encoded." ;
#     rdfs:domain up:Protein ;
#     rdfs:range up:Gene .
#
# up:encodedIn a owl:ObjectProperty ;
#     rdfs:label "encoded in" ;
#     rdfs:comment "The subcellular location where a protein is encoded." ;
#     rdfs:domain up:Protein ;
#     rdfs:range up:Plasmid .
#
# up:erratum a owl:ObjectProperty ;
#     rdfs:label "erratum" ;
#     rdfs:comment "An erratum for a publication." ;
#     rdfs:domain up:Journal_Citation ;
#     rdfs:range up:Electronic_Citation,
#         up:Journal_Citation .
#
# up:host a owl:ObjectProperty ;
#     rdfs:label "host" ;
#     rdfs:domain up:Taxon ;
#     rdfs:range up:Taxon .
#
# up:interaction a owl:ObjectProperty ;
#     rdfs:label "interaction" ;
#     rdfs:domain up:Protein ;
#     rdfs:range up:Interaction,
#         up:Non_Self_Interaction,
#         up:Self_Interaction .
#
# up:isolatedFrom a owl:ObjectProperty ;
#     rdfs:label "isolatedFrom" ;
#     rdfs:domain up:Protein ;
#     rdfs:range up:Tissue .
#
# up:locatedOn a owl:ObjectProperty ;
#     rdfs:label "located on" ;
#     rdfs:comment "The molecule a this resource is located on." ;
#     rdfs:domain up:Nucleotide_Resource ;
#     rdfs:range up:Genomic_DNA,
#         up:Genomic_RNA,
#         up:MRNA,
#         up:Other_DNA,
#         up:Other_RNA,
#         up:Transcribed_RNA,
#         up:Unassigned_DNA,
#         up:Unassigned_RNA,
#         up:Viral_cRNA .
#
# up:mappedAnnotation a owl:ObjectProperty ;
#     rdfs:label "mapped annotation" ;
#     rdfs:comment "Maps annotation to a resource. Used to link annotations/comments from external non UniProt sources via Citations to UniProt resources." ;
#     rdfs:domain up:Citation_Statement,
#         rdf:Statement ;
#     rdfs:range up:Annotation .
#
# up:member a owl:ObjectProperty ;
#     rdfs:label "member" ;
#     rdfs:comment "One of several similar resources." ;
#     rdfs:domain up:Cluster ;
#     rdfs:range up:Sequence .
#
# up:memberOf a owl:ObjectProperty ;
#     rdfs:label "member of" ;
#     rdfs:domain up:Sequence ;
#     rdfs:range up:Cluster .
#
# up:modification a owl:ObjectProperty ;
#     rdfs:label "modification" ;
#     rdfs:comment "A modification of a sequence." ;
#     rdfs:domain up:External_Sequence,
#         up:Modified_Sequence ;
#     rdfs:range up:Alternative_Sequence_Annotation .
#
# up:panproteome a owl:ObjectProperty ;
#     rdfs:label "panproteome" ;
#     rdfs:comment """The current pan proteome sequences are derived from the reference proteome
# clusters (75% proteome similarity for Fungus and 55% proteome similarity for
# Archaea and Bacteria). A reference proteome cluster is also known as a
# representative proteome group (RPG) (Chen et al., 2011). A RPG contains similar
# proteomes calculated based on their co-membership in UniRef50 clusters. For each
# non-singleton reference proteome cluster, a pan proteome is a set of sequences
# consisting of all the sequences in the reference proteome, plus the addition of
# unique protein sequences that are found in other species or strains of the
# cluster but not in the reference proteome. These additional sequences are
# identified using UniRef50 membership.""" ;
#     rdfs:domain up:Proteome,
#         up:Reference_Proteome,
#         up:Representative_Proteome ;
#     rdfs:range up:Proteome,
#         up:Reference_Proteome,
#         up:Representative_Proteome .
#
# up:partOf a owl:ObjectProperty ;
#     rdfs:label "part of" ;
#     rdfs:domain up:Cellular_Component ;
#     rdfs:range up:Cellular_Component .
#
# up:participant a owl:ObjectProperty ;
#     rdfs:label "participant" ;
#     rdfs:comment "A protein that participates in a protein-protein interaction." ;
#     rdfs:domain up:Interaction,
#         up:Non_Self_Interaction,
#         up:Self_Interaction ;
#     rdfs:range up:Participant .
#
# up:potentialSequence a owl:ObjectProperty ;
#     rdfs:label "potential sequence" ;
#     rdfs:comment "This is a predicate added by an automated procedure to link entries/proteins that might be isoforms of each other." ;
#     rdfs:domain up:Protein ;
#     rdfs:range up:External_Sequence,
#         up:Modified_Sequence,
#         up:Simple_Sequence .
#
# up:range a owl:ObjectProperty ;
#     rdfs:label "range" ;
#     rdfs:comment "A specialization of faldo:location where all objects are faldo:Regions" ;
#     rdfs:domain up:Active_Site_Annotation,
#         up:Alternative_Sequence_Annotation,
#         up:Beta_Strand_Annotation,
#         up:Binding_Site_Annotation,
#         up:Chain_Annotation,
#         up:Coiled_Coil_Annotation,
#         up:Compositional_Bias_Annotation,
#         up:Cross-link_Annotation,
#         up:Disulfide_Bond_Annotation,
#         up:Domain_Extent_Annotation,
#         up:Glycosylation_Annotation,
#         up:Helix_Annotation,
#         up:Initiator_Methionine_Annotation,
#         up:Intramembrane_Annotation,
#         up:Lipidation_Annotation,
#         up:Modified_Residue_Annotation,
#         up:Motif_Annotation,
#         up:Mutagenesis_Annotation,
#         up:Natural_Variant_Annotation,
#         up:Non-adjacent_Residues_Annotation,
#         up:Non-standard_Residue_Annotation,
#         up:Non-terminal_Residue_Annotation,
#         up:Nucleotide_Binding_Annotation,
#         up:Peptide_Annotation,
#         up:Propeptide_Annotation,
#         up:Region_Annotation,
#         up:Repeat_Annotation,
#         up:Sequence_Conflict_Annotation,
#         up:Sequence_Uncertainty_Annotation,
#         up:Signal_Peptide_Annotation,
#         up:Site_Annotation,
#         up:Topological_Domain_Annotation,
#         up:Transit_Peptide_Annotation,
#         up:Transmembrane_Annotation,
#         up:Turn_Annotation,
#         up:Zinc_Finger_Annotation ;
#     rdfs:range faldo:Region ;
#     rdfs:subPropertyOf faldo:location .
#
# up:recommendedName a owl:ObjectProperty ;
#     rdfs:label "recommended name" ;
#     rdfs:comment "The name recommended by the UniProt consortium." ;
#     rdfs:domain up:Part,
#         up:Protein ;
#     rdfs:range up:Structured_Name ;
#     rdfs:subPropertyOf up:structuredName .
#
# up:redundantTo a owl:ObjectProperty ;
#     rdfs:label "redundantTo" ;
#     rdfs:comment "Indicates which proteome this proteome is redundant to." ;
#     rdfs:domain up:Proteome ;
#     rdfs:range up:Proteome,
#         up:Reference_Proteome,
#         up:Representative_Proteome .
#
# up:relatedLocation a owl:ObjectProperty ;
#     rdfs:label "related location" ;
#     rdfs:domain up:Cellular_Component,
#         up:Topology ;
#     rdfs:range up:Cellular_Component,
#         up:Topology .
#
# up:replacedBy a owl:ObjectProperty ;
#     rdfs:label "replaced by" ;
#     rdfs:comment "A resource that replaces this resource." ;
#     rdfs:domain up:Enzyme,
#         up:Protein,
#         up:Taxon ;
#     rdfs:range up:Enzyme,
#         up:Protein,
#         up:Taxon .
#
# up:replaces a owl:ObjectProperty ;
#     rdfs:label "replaces" ;
#     rdfs:comment "A resource that is replaced by this resource." ;
#     rdfs:domain up:Enzyme,
#         up:Taxon ;
#     rdfs:range up:Enzyme,
#         up:Taxon .
#
# up:representativeFor a owl:ObjectProperty ;
#     rdfs:label "representative for" ;
#     rdfs:domain up:Sequence ;
#     rdfs:range up:Cluster .
#
# up:seedFor a owl:ObjectProperty ;
#     rdfs:label "seed for" ;
#     rdfs:domain up:Sequence ;
#     rdfs:range up:Cluster .
#
# up:sequence a owl:ObjectProperty ;
#     rdfs:label "sequence" ;
#     rdfs:comment "An amino acid sequence." ;
#     rdfs:domain up:Active_Site_Annotation,
#         up:Activity_Regulation_Annotation,
#         up:Allergen_Annotation,
#         up:Alternative_Initiation_Annotation,
#         up:Alternative_Promoter_Usage_Annotation,
#         up:Alternative_Splicing_Annotation,
#         up:Annotation,
#         up:Binding_Site_Annotation,
#         up:Biotechnology_Annotation,
#         up:Catalytic_Activity_Annotation,
#         up:Caution_Annotation,
#         up:Cofactor_Annotation,
#         up:Coiled_Coil_Annotation,
#         up:Cross-link_Annotation,
#         up:Developmental_Stage_Annotation,
#         up:Disease_Annotation,
#         up:Disruption_Phenotype_Annotation,
#         up:Disulfide_Bond_Annotation,
#         up:Domain_Annotation,
#         up:Erroneous_Gene_Model_Prediction_Annotation,
#         up:Erroneous_Initiation_Annotation,
#         up:Erroneous_Termination_Annotation,
#         up:Frameshift_Annotation,
#         up:Function_Annotation,
#         up:Glycosylation_Annotation,
#         up:Induction_Annotation,
#         up:Initiator_Methionine_Annotation,
#         up:Intramembrane_Annotation,
#         up:Kinetics_Annotation,
#         up:Lipidation_Annotation,
#         up:Mass_Spectrometry_Annotation,
#         up:Modified_Residue_Annotation,
#         up:Motif_Annotation,
#         up:Mutagenesis_Annotation,
#         up:Natural_Variant_Annotation,
#         up:PH_Dependence_Annotation,
#         up:PTM_Annotation,
#         up:Pathway_Annotation,
#         up:Pharmaceutical_Annotation,
#         up:Polymorphism_Annotation,
#         up:Protein,
#         up:RNA_Editing_Annotation,
#         up:Region_Annotation,
#         up:Ribosomal_Frameshifting,
#         up:Sequence_Caution_Annotation,
#         up:Sequence_Conflict_Annotation,
#         up:Similarity_Annotation,
#         up:Site_Annotation,
#         up:Subcellular_Location_Annotation,
#         up:Subunit_Annotation,
#         up:Temperature_Dependence_Annotation,
#         up:Tissue_Specificity_Annotation,
#         up:Topological_Domain_Annotation,
#         up:Toxic_Dose_Annotation,
#         up:Transit_Peptide_Annotation,
#         up:Transmembrane_Annotation ;
#     rdfs:range up:Chain_Annotation,
#         up:External_Sequence,
#         up:Modified_Sequence,
#         up:Peptide_Annotation,
#         up:Simple_Sequence,
#         up:Unknown_Sequence .
#
# up:strain a owl:ObjectProperty ;
#     rdfs:label "strain" ;
#     rdfs:domain up:Proteome,
#         up:Reference_Proteome,
#         up:Representative_Proteome,
#         up:Taxon ;
#     rdfs:range up:Strain .
#
# up:submittedName a owl:ObjectProperty ;
#     rdfs:label "submitted name" ;
#     rdfs:comment "A name provided by the submitter of the underlying nucleotide sequence." ;
#     rdfs:domain up:Protein ;
#     rdfs:range up:Structured_Name ;
#     rdfs:subPropertyOf up:structuredName .
#
# up:transcribedFrom a owl:ObjectProperty ;
#     rdfs:label "transcribed from" ;
#     rdfs:domain up:Transcript_Resource ;
#     rdfs:range up:Transcript_Resource .
#
# up:translatedFrom a owl:ObjectProperty ;
#     rdfs:label "translated from" ;
#     rdfs:domain up:External_Sequence ;
#     rdfs:range up:Nucleotide_Resource .
#
# up:translatedTo a owl:ObjectProperty ;
#     rdfs:label "translated to" ;
#     rdfs:domain up:Transcript_Resource ;
#     rdfs:range up:Transcript_Resource .
#
# <http://www.geneontology.org/formats/oboInOwl#replaces> a owl:ObjectProperty ;
#     rdfs:domain owl:Class ;
#     rdfs:range owl:Class .
#
# rdf:object a owl:ObjectProperty ;
#     rdfs:domain up:Citation_Statement,
#         rdf:Statement ;
#     rdfs:range faldo:ExactPosition,
#         faldo:Position,
#         up:Active_Site_Annotation,
#         up:Alternative_Sequence_Annotation,
#         up:Beta_Strand_Annotation,
#         up:Binding_Site_Annotation,
#         up:Book_Citation,
#         up:Catalytic_Activity,
#         up:Chain_Annotation,
#         up:Coiled_Coil_Annotation,
#         up:Compositional_Bias_Annotation,
#         up:Cross-link_Annotation,
#         up:Disulfide_Bond_Annotation,
#         up:Domain_Extent_Annotation,
#         up:Electronic_Citation,
#         up:Erroneous_Gene_Model_Prediction_Annotation,
#         up:Erroneous_Initiation_Annotation,
#         up:Erroneous_Termination_Annotation,
#         up:Erroneous_Translation_Annotation,
#         up:Frameshift_Annotation,
#         up:Glycosylation_Annotation,
#         up:Helix_Annotation,
#         up:Initiator_Methionine_Annotation,
#         up:Intramembrane_Annotation,
#         up:Journal_Citation,
#         up:Lipidation_Annotation,
#         up:Mass_Spectrometry_Annotation,
#         up:Modified_Residue_Annotation,
#         up:Motif_Annotation,
#         up:Mutagenesis_Annotation,
#         up:Natural_Variant_Annotation,
#         up:Non-adjacent_Residues_Annotation,
#         up:Non-standard_Residue_Annotation,
#         up:Non-terminal_Residue_Annotation,
#         up:Nucleotide_Binding_Annotation,
#         up:Observation_Citation,
#         up:Patent_Citation,
#         up:Pathway_Annotation,
#         up:Peptide_Annotation,
#         up:Plasmid,
#         up:Propeptide_Annotation,
#         up:Region_Annotation,
#         up:Repeat_Annotation,
#         up:Sequence_Caution_Annotation,
#         up:Sequence_Conflict_Annotation,
#         up:Sequence_Uncertainty_Annotation,
#         up:Signal_Peptide_Annotation,
#         up:Site_Annotation,
#         up:Strain,
#         up:Submission_Citation,
#         up:Thesis_Citation,
#         up:Tissue,
#         up:Topological_Domain_Annotation,
#         up:Transit_Peptide_Annotation,
#         up:Transmembrane_Annotation,
#         up:Turn_Annotation,
#         up:Zinc_Finger_Annotation .
#
# rdf:rest a owl:ObjectProperty ;
#     rdfs:domain rdf:List ;
#     rdfs:range rdf:List .
#
# rdf:subject a owl:ObjectProperty ;
#     rdfs:domain up:Citation_Statement,
#         rdf:Statement ;
#     rdfs:range up:Absorption_Annotation,
#         up:Activity_Regulation_Annotation,
#         up:Allergen_Annotation,
#         up:Alternative_Initiation_Annotation,
#         up:Alternative_Promoter_Usage_Annotation,
#         up:Alternative_Splicing_Annotation,
#         up:Annotation,
#         up:Biotechnology_Annotation,
#         up:Catalytic_Activity_Annotation,
#         up:Caution_Annotation,
#         up:Citation_Statement,
#         up:Cofactor_Annotation,
#         up:Developmental_Stage_Annotation,
#         up:Disease_Annotation,
#         up:Disruption_Phenotype_Annotation,
#         up:Domain_Annotation,
#         up:External_Sequence,
#         up:Function_Annotation,
#         up:Gene,
#         up:Induction_Annotation,
#         up:Kinetics_Annotation,
#         up:Modified_Sequence,
#         up:PH_Dependence_Annotation,
#         up:PTM_Annotation,
#         up:Part,
#         up:Pharmaceutical_Annotation,
#         up:Polymorphism_Annotation,
#         up:Protein,
#         up:RNA_Editing_Annotation,
#         up:Redox_Potential_Annotation,
#         up:Ribosomal_Frameshifting,
#         up:Similarity_Annotation,
#         up:Simple_Sequence,
#         up:Structured_Name,
#         up:Subcellular_Location_Annotation,
#         up:Subunit_Annotation,
#         up:Temperature_Dependence_Annotation,
#         up:Tissue_Specificity_Annotation,
#         up:Toxic_Dose_Annotation,
#         up:Unknown_Sequence,
#         rdf:Statement .
#
# rdfs:domain a owl:ObjectProperty ;
#     rdfs:domain owl:DatatypeProperty,
#         owl:FunctionalProperty,
#         owl:InverseFunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:range owl:Class .
#
# rdfs:isDefinedBy a owl:ObjectProperty ;
#     rdfs:domain up:Mass_Measurement_Method,
#         up:Organelle,
#         up:Protein_Existence,
#         up:Rank,
#         up:Status,
#         up:Structure_Determination_Method,
#         owl:Class,
#         owl:DatatypeProperty,
#         owl:FunctionalProperty,
#         owl:InverseFunctionalProperty,
#         owl:NamedIndividual,
#         owl:ObjectProperty,
#         owl:Thing ;
#     rdfs:range owl:Ontology .
#
# rdfs:range a owl:ObjectProperty ;
#     rdfs:domain owl:DatatypeProperty,
#         owl:FunctionalProperty,
#         owl:InverseFunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:range up:Rank,
#         rdfs:Datatype,
#         owl:Class,
#         owl:NamedIndividual,
#         owl:Thing .
#
# rdfs:seeAlso a owl:ObjectProperty ;
#     rdfs:domain up:Concept,
#         up:Protein,
#         up:Resource,
#         up:Transcript_Resource,
#         owl:Class ;
#     rdfs:range up:External_Sequence,
#         up:Modified_Sequence,
#         up:Nucleotide_Resource,
#         up:Resource,
#         up:Simple_Sequence,
#         up:Structure_Resource,
#         up:Transcript_Resource,
#         up:Unknown_Sequence,
#         owl:Class .
#
# rdfs:subClassOf a owl:ObjectProperty ;
#     rdfs:domain up:Cellular_Component,
#         up:Concept,
#         up:Enzyme,
#         up:Pathway,
#         up:Taxon,
#         up:Topology,
#         rdfs:Class,
#         owl:Class ;
#     rdfs:range up:Cellular_Component,
#         up:Concept,
#         up:Enzyme,
#         up:Pathway,
#         up:Taxon,
#         up:Topology,
#         rdfs:Class,
#         owl:Class,
#         owl:Restriction .
#
# rdfs:subPropertyOf a owl:ObjectProperty ;
#     rdfs:domain owl:DatatypeProperty,
#         owl:FunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:range owl:DatatypeProperty,
#         owl:ObjectProperty .
#
# owl:allValuesFrom a owl:ObjectProperty ;
#     rdfs:domain owl:Restriction ;
#     rdfs:range owl:Class .
#
# owl:annotatedSource a owl:ObjectProperty ;
#     rdfs:domain owl:Axiom ;
#     rdfs:range owl:Class .
#
# owl:disjointWith a owl:ObjectProperty ;
#     rdfs:domain owl:Class ;
#     rdfs:range owl:Class .
#
# owl:equivalentClass a owl:ObjectProperty ;
#     rdfs:domain owl:Class ;
#     rdfs:range owl:Class,
#         owl:Restriction .
#
# owl:inverseOf a owl:ObjectProperty ;
#     rdfs:domain owl:ObjectProperty,
#         owl:TransitiveProperty ;
#     rdfs:range owl:ObjectProperty,
#         owl:TransitiveProperty .
#
# owl:onClass a owl:ObjectProperty ;
#     rdfs:domain owl:Restriction ;
#     rdfs:range owl:Class .
#
# owl:onProperty a owl:ObjectProperty ;
#     rdfs:domain owl:Restriction ;
#     rdfs:range owl:DatatypeProperty,
#         owl:FunctionalProperty,
#         owl:ObjectProperty,
#         owl:TransitiveProperty .
#
# owl:oneOf a owl:ObjectProperty ;
#     rdfs:domain rdfs:Datatype ;
#     rdfs:range rdf:List .
#
# owl:sameAs a owl:ObjectProperty ;
#     rdfs:domain up:Participant,
#         up:Transcript_Resource ;
#     rdfs:range up:Chain_Annotation,
#         up:External_Sequence,
#         up:Modified_Sequence,
#         up:Peptide_Annotation,
#         up:Propeptide_Annotation,
#         up:Protein,
#         up:Simple_Sequence,
#         up:Transcript_Resource .
#
# owl:someValuesFrom a owl:ObjectProperty ;
#     rdfs:domain owl:Restriction ;
#     rdfs:range rdfs:Datatype,
#         owl:Class .
#
# skos:broaderTransitive a owl:ObjectProperty ;
#     rdfs:domain up:Enzyme ;
#     rdfs:range up:Enzyme .
#
# skos:closeMatch a owl:ObjectProperty ;
#     rdfs:domain up:Proteome,
#         up:Reference_Proteome,
#         up:Representative_Proteome ;
#     rdfs:range <http://purl.obolibrary.org/obo/STATO_0000193> .
#
# skos:exactMatch a owl:ObjectProperty ;
#     rdfs:domain up:Cellular_Component ;
#     rdfs:range owl:Class .
#
# skos:narrower a owl:ObjectProperty ;
#     rdfs:domain up:Concept,
#         up:Pathway,
#         up:Proteome,
#         up:Reference_Proteome,
#         up:Representative_Proteome ;
#     rdfs:range up:Concept,
#         up:Pathway,
#         up:Proteome_Component .
#
# skos:narrowerTransitive a owl:ObjectProperty ;
#     rdfs:domain up:Enzyme,
#         up:Taxon ;
#     rdfs:range up:Enzyme,
#         up:Taxon .
#
# sh:prefixes a owl:ObjectProperty ;
#     rdfs:domain sh:SPARQLAskExecutable,
#         sh:SPARQLConstructExecutable,
#         sh:SPARQLExecutable,
#         sh:SPARQLSelectExecutable ;
#     rdfs:range owl:Ontology .
#
# <http://www.w3.org/ns/sparql-service-description#defaultDataset> a owl:ObjectProperty ;
#     rdfs:domain <http://www.w3.org/ns/sparql-service-description#Service> ;
#     rdfs:range <http://www.w3.org/ns/sparql-service-description#Dataset> .
#
# <http://www.w3.org/ns/sparql-service-description#defaultGraph> a owl:ObjectProperty ;
#     rdfs:domain <http://www.w3.org/ns/sparql-service-description#Dataset> ;
#     rdfs:range <http://www.w3.org/ns/sparql-service-description#Graph> .
#
# <http://www.w3.org/ns/sparql-service-description#endpoint> a owl:ObjectProperty ;
#     rdfs:domain <http://www.w3.org/ns/sparql-service-description#Service> ;
#     rdfs:range <http://www.w3.org/ns/sparql-service-description#Service> .
#
# foaf:depiction a owl:ObjectProperty ;
#     rdfs:domain up:Taxon ;
#     rdfs:range foaf:Image .
#
# faldo:location a owl:ObjectProperty ;
#     rdfs:domain up:RNA_Editing_Annotation ;
#     rdfs:range faldo:ExactPosition,
#         faldo:Position .
#
# <http://busco.ezlab.org/schema#Score> a owl:Class .
#
# <http://purl.obolibrary.org/obo/STATO_0000193> a owl:Class .
#
# up:Citation a owl:Class ;
#     rdfs:label "Citation" ;
#     rdfs:comment "Description of a publication from which data was obtained." .
#
# up:Database a owl:Class ;
#     rdfs:label "Database (description of)" ;
#     rdfs:comment "Metadata for a life science database." ;
#     rdfs:subClassOf owl:Class .
#
# up:Genomic_DNA a owl:Class ;
#     rdfs:label "Genomic DNA" .
#
# up:Genomic_RNA a owl:Class ;
#     rdfs:label "Genomic RNA" .
#
# up:MRNA a owl:Class ;
#     rdfs:label "mRNA" .
#
# up:Mass_Measurement_Method a owl:Class ;
#     rdfs:label "Mass Measurement" ;
#     rdfs:comment "An experimental method for measuring the mass of a molecule." ;
#     rdfs:subClassOf up:Method .
#
# up:Organelle a owl:Class ;
#     rdfs:label "Organelle" .
#
# up:Other_DNA a owl:Class ;
#     rdfs:label "Other DNA" .
#
# up:Other_RNA a owl:Class ;
#     rdfs:label "Other RNA" .
#
# up:Protein_Existence a owl:Class ;
#     rdfs:label "Protein existence evidence" .
#
# up:Proteome_Component a owl:Class ;
#     rdfs:label "Proteome_Component" ;
#     rdfs:comment "The component of a proteome. e.g. Chromosome, Contig or Plasmid" .
#
# up:Status a owl:Class ;
#     rdfs:label "Status" ;
#     rdfs:comment "Indicator for the reliability of a piece of information." .
#
# up:Structure_Determination_Method a owl:Class ;
#     rdfs:label "Structure Determination" ;
#     rdfs:comment "An experimental method for determining the 3D structure of a protein." ;
#     rdfs:subClassOf up:Method .
#
# up:Structure_Resource a owl:Class ;
#     rdfs:label "Structure Resource" ;
#     rdfs:comment "A resource that describes the 3D structure of a protein." .
#
# up:Transcribed_RNA a owl:Class ;
#     rdfs:label "Transcribed RNA" .
#
# up:Transposon a owl:Class ;
#     rdfs:label "Transposon" ;
#     rdfs:comment "A transposon" .
#
# up:Unassigned_DNA a owl:Class ;
#     rdfs:label "Unassigned DNA" .
#
# up:Unassigned_RNA a owl:Class ;
#     rdfs:label "Unassigned RNA" .
#
# up:Viral_cRNA a owl:Class ;
#     rdfs:label "Viral cRNA" ;
#     rdfs:comment "Positive cRNA molecule that is made from from a single stranded genomic RNA." .
#
# owl:Axiom a owl:Class .
#
# sh:SPARQLAskExecutable a owl:Class .
#
# sh:SPARQLConstructExecutable a owl:Class .
#
# sh:SPARQLExecutable a owl:Class .
#
# sh:SPARQLSelectExecutable a owl:Class .
#
# <http://www.w3.org/ns/sparql-service-description#Graph> a owl:Class .
#
# foaf:Image a owl:Class .
#
# up:Absorption_Annotation a owl:Class ;
#     rdfs:label "Absorption" ;
#     rdfs:comment "Indicates the wavelength in nm at which photoreactive proteins such as opsins and DNA photolyases show maximal absorption." .
#
# up:Book_Citation a owl:Class ;
#     rdfs:label "Book Citation" ;
#     rdfs:comment "A chapter from a book." .
#
# up:Gene a owl:Class ;
#     rdfs:label "Gene" .
#
# up:Non_Self_Interaction a owl:Class ;
#     rdfs:label "Non self interaction" ;
#     rdfs:comment "Description of a non self protein-protein interaction." ;
#     rdfs:subClassOf up:Interaction .
#
# up:Observation_Citation a owl:Class ;
#     rdfs:label "Observation Citation" ;
#     rdfs:comment "Citation of an unpublished result." .
#
# up:Participant a owl:Class ;
#     rdfs:label "Interaction participant" ;
#     rdfs:comment "A participant in a protein-protein interaction." .
#
# up:Patent_Citation a owl:Class ;
#     rdfs:label "Patent Citation" ;
#     rdfs:comment "A patent application." .
#
# up:Rank a owl:Class ;
#     rdfs:label "Taxon rank" ;
#     rdfs:comment "A rank of a taxon." .
#
# up:Redox_Potential_Annotation a owl:Class ;
#     rdfs:label "Redox Potential" ;
#     rdfs:comment "Reports the value of the standard (midpoint) oxido-reduction potential(s) for electron transport proteins." .
#
# up:Self_Interaction a owl:Class ;
#     rdfs:label "Self protein interaction" ;
#     rdfs:comment "Description of a self protein-protein interaction." ;
#     rdfs:subClassOf up:Interaction .
#
# up:Submission_Citation a owl:Class ;
#     rdfs:label "Submission Citation" ;
#     rdfs:comment "Data that was submitted directly to a database." .
#
# up:Thesis_Citation a owl:Class ;
#     rdfs:label "Thesis Citation" ;
#     rdfs:comment "A Ph.D. thesis." .
#
# rdfs:Class a owl:Class .
#
# owl:NamedIndividual a owl:Class .
#
# owl:Ontology a owl:Class .
#
# <http://www.w3.org/ns/sparql-service-description#Dataset> a owl:Class .
#
# faldo:Region a owl:Class .
#
# up:Activity_Regulation_Annotation a owl:Class ;
#     rdfs:label "Activity Regulation" ;
#     rdfs:comment "Description of an enzyme, transporter and microbial transcription regulation mechanism." ;
#     rdfs:subClassOf up:Annotation .
#
# up:Allergen_Annotation a owl:Class ;
#     rdfs:label "Allergen" ;
#     rdfs:comment "Information relevant to allergenic proteins." ;
#     rdfs:subClassOf up:Annotation .
#
# up:Alternative_Initiation_Annotation a owl:Class ;
#     rdfs:label "Alternative Initiation" ;
#     rdfs:subClassOf up:Alternative_Products_Annotation .
#
# up:Alternative_Promoter_Usage_Annotation a owl:Class ;
#     rdfs:label "Alternative Promoter Usage" ;
#     rdfs:subClassOf up:Alternative_Products_Annotation .
#
# up:Alternative_Splicing_Annotation a owl:Class ;
#     rdfs:label "Alternative Splicing" ;
#     rdfs:subClassOf up:Alternative_Products_Annotation .
#
# up:Beta_Strand_Annotation a owl:Class ;
#     rdfs:label "Strand" ;
#     rdfs:comment "Beta strand regions within the experimentally determined protein structure" ;
#     rdfs:subClassOf up:Secondary_Structure_Annotation .
#
# up:Biotechnology_Annotation a owl:Class ;
#     rdfs:label "Biotechnology" ;
#     rdfs:comment "Description of the use of a specific protein in a biotechnological process." ;
#     rdfs:subClassOf up:Annotation .
#
# up:Catalytic_Activity a owl:Class ;
#     rdfs:label "Catalytic Activity" ;
#     rdfs:comment "The catalytic activity of an enzyme." .
#
# up:Caution_Annotation a owl:Class ;
#     rdfs:label "Caution" ;
#     rdfs:comment "Warning about possible errors and/or grounds for confusion." ;
#     rdfs:subClassOf up:Annotation .
#
# up:Cofactor_Annotation a owl:Class ;
#     rdfs:label "Cofactor" ;
#     rdfs:comment "Description of an enzyme cofactor." ;
#     rdfs:subClassOf up:Annotation .
#
# up:Compositional_Bias_Annotation a owl:Class ;
#     rdfs:label "Compositionally Biased Region" ;
#     rdfs:comment "Extent of a compositionally biased region." ;
#     rdfs:subClassOf up:Region_Annotation .
#
# up:Developmental_Stage_Annotation a owl:Class ;
#     rdfs:label "Developmental Stage" ;
#     rdfs:comment "Description of the developmentally-specific expression of a protein." ;
#     rdfs:subClassOf up:Annotation .
#
# up:Disease_Annotation a owl:Class ;
#     rdfs:label "Disease Annotation" ;
#     rdfs:comment "Description of the diseases associated with a deficiency of a protein." ;
#     rdfs:subClassOf up:Annotation .
#
# up:Disruption_Phenotype_Annotation a owl:Class ;
#     rdfs:label "Disruption Phenotype" ;
#     rdfs:subClassOf up:Annotation .
#
# up:Domain_Annotation a owl:Class ;
#     rdfs:label "Domain" ;
#     rdfs:comment "Description of the domain structure of a protein." ;
#     rdfs:subClassOf up:Annotation .
#
# up:Domain_Extent_Annotation a owl:Class ;
#     rdfs:label "Domain Extent" ;
#     rdfs:comment "Extent of a domain, which is defined as a specific combination of secondary structures organized into a characteristic three-dimensional structure or fold." ;
#     rdfs:subClassOf up:Region_Annotation .
#
# up:Electronic_Citation a owl:Class ;
#     rdfs:label "Electronic Citation" ;
#     rdfs:comment "An electronic publication." .
#
# up:Erroneous_Translation_Annotation a owl:Class ;
#     rdfs:label "Erroneous Translation" ;
#     rdfs:subClassOf up:Sequence_Caution_Annotation .
#
# up:Function_Annotation a owl:Class ;
#     rdfs:label "Function" ;
#     rdfs:comment "General description of the functions of a protein." ;
#     rdfs:subClassOf up:Annotation .
#
# up:Helix_Annotation a owl:Class ;
#     rdfs:label "Helix" ;
#     rdfs:comment "Helical regions within the experimentally determined protein structure" ;
#     rdfs:subClassOf up:Secondary_Structure_Annotation .
#
# up:Induction_Annotation a owl:Class ;
#     rdfs:label "Induction" ;
#     rdfs:comment "Description of the compounds or conditions that stimulate the synthesis of a protein." ;
#     rdfs:subClassOf up:Annotation .
#
# up:Kinetics_Annotation a owl:Class ;
#     rdfs:label "Kinetics" ;
#     rdfs:comment "Mentions the Michaelis-Menten constant (KM) and maximal velocity (Vmax) of enzymes." ;
#     rdfs:subClassOf up:Biophysicochemical_Annotation .
#
# up:Mass_Spectrometry_Annotation a owl:Class ;
#     rdfs:label "Mass" ;
#     rdfs:comment "Indicates the mass of a sequence determined by mass spectrometry." ;
#     rdfs:subClassOf up:Experimental_Information_Annotation .
#
# up:Non-adjacent_Residues_Annotation a owl:Class ;
#     rdfs:label "Non-consecutive Residues" ;
#     rdfs:comment "Indicates that two residues in a sequence are not consecutive and that there are a number of unsequenced residues between them." ;
#     rdfs:subClassOf up:Experimental_Information_Annotation .
#
# up:Non-standard_Residue_Annotation a owl:Class ;
#     rdfs:label "Non standard residue" ;
#     rdfs:comment "Describes the occurrence of a non standard residue in the sequence record." ;
#     rdfs:subClassOf up:Modification_Annotation .
#
# up:Non-terminal_Residue_Annotation a owl:Class ;
#     rdfs:label "Non-terminal Residue" ;
#     rdfs:comment "The residue at an extremity of the sequence is not the terminal residue." ;
#     rdfs:subClassOf up:Experimental_Information_Annotation .
#
# up:Nucleotide_Binding_Annotation a owl:Class ;
#     rdfs:label "DNA Binding" ;
#     rdfs:comment "Extent of a DNA-binding region." ;
#     rdfs:subClassOf up:Region_Annotation .
#
# up:PH_Dependence_Annotation a owl:Class ;
#     rdfs:label "pH Dependence" ;
#     rdfs:comment "Describes the optimum pH for enzyme activity and/or the variation of enzyme activity with pH variation." ;
#     rdfs:subClassOf up:Biophysicochemical_Annotation .
#
# up:PTM_Annotation a owl:Class ;
#     rdfs:label "PTM" ;
#     rdfs:comment "Description of a posttranslational modification." ;
#     rdfs:subClassOf up:Annotation .
#
# up:Pathway_Annotation a owl:Class ;
#     rdfs:label "Pathway annotation" ;
#     rdfs:comment "Description of the metabolic pathways with which a protein is associated." ;
#     rdfs:subClassOf up:Annotation .
#
# up:Pharmaceutical_Annotation a owl:Class ;
#     rdfs:label "Pharmaceutical" ;
#     rdfs:comment "Description of the use of a protein as a pharmaceutical drug." ;
#     rdfs:subClassOf up:Annotation .
#
# up:Plasmid a owl:Class ;
#     rdfs:label "Plasmid" ;
#     rdfs:comment "Description of a Plasmid" .
#
# up:Polymorphism_Annotation a owl:Class ;
#     rdfs:label "Polymorphism" ;
#     rdfs:comment "Description of polymorphisms." ;
#     rdfs:subClassOf up:Annotation .
#
# up:Repeat_Annotation a owl:Class ;
#     rdfs:label "Repeat" ;
#     rdfs:comment "Extent of an internal sequence repetition." ;
#     rdfs:subClassOf up:Region_Annotation .
#
# up:Ribosomal_Frameshifting a owl:Class ;
#     rdfs:label "Ribosomal Frameshifting" ;
#     rdfs:subClassOf up:Alternative_Products_Annotation .
#
# up:Sequence_Uncertainty_Annotation a owl:Class ;
#     rdfs:label "Unsure Residue" ;
#     rdfs:comment "Used to describe region(s) of a sequence for which the authors are unsure about the sequence assignment." ;
#     rdfs:subClassOf up:Experimental_Information_Annotation .
#
# up:Signal_Peptide_Annotation a owl:Class ;
#     rdfs:label "Signal Peptide" ;
#     rdfs:comment "Extent of a signal sequence (prepeptide)." ;
#     rdfs:subClassOf up:Molecule_Processing_Annotation .
#
# up:Similarity_Annotation a owl:Class ;
#     rdfs:label "Similarity" ;
#     rdfs:comment "Description of the similarities (sequence or structural) of a protein with other proteins." ;
#     rdfs:subClassOf up:Annotation .
#
# up:Strain a owl:Class ;
#     rdfs:label "Strain",
#         "Taxonomy rank Strain" ;
#     rdfs:comment "A strain of a species." .
#
# up:Subcellular_Location_Annotation a owl:Class ;
#     rdfs:label "Subcellular Location Annotation" ;
#     rdfs:comment "Description of the subcellular location of the mature protein." ;
#     rdfs:subClassOf up:Annotation .
#
# up:Subunit_Annotation a owl:Class ;
#     rdfs:label "Subunit" ;
#     rdfs:comment "Description of the quaternary structure of a protein." ;
#     rdfs:subClassOf up:Annotation .
#
# up:Temperature_Dependence_Annotation a owl:Class ;
#     rdfs:label "Temperature Dependence" ;
#     rdfs:comment "Indicates the optimum temperature for enzyme activity and/or the variation of enzyme activity with temperature variation; the thermostability/thermolability of the enzyme is also mentioned when it is known." ;
#     rdfs:subClassOf up:Biophysicochemical_Annotation .
#
# up:Tissue a owl:Class ;
#     rdfs:label "Tissue" ;
#     rdfs:comment "A tissue such as lung or heart." .
#
# up:Tissue_Specificity_Annotation a owl:Class ;
#     rdfs:label "Tissue Specificity" ;
#     rdfs:comment "Description of the tissue specificity of a protein." ;
#     rdfs:subClassOf up:Annotation .
#
# up:Toxic_Dose_Annotation a owl:Class ;
#     rdfs:label "Toxic Dose" ;
#     rdfs:comment "Information on the LD(50). LD stands for \"Lethal Dose\". LD(50) is the amount of a toxin, given all at once, which causes the death of 50% (one half) of a group of test animals." ;
#     rdfs:subClassOf up:Annotation .
#
# up:Turn_Annotation a owl:Class ;
#     rdfs:label "Turn" ;
#     rdfs:comment "Turns within the experimentally determined protein structure." ;
#     rdfs:subClassOf up:Secondary_Structure_Annotation .
#
# up:Unknown_Sequence a owl:Class ;
#     rdfs:label "Unknown Sequence" .
#
# up:Zinc_Finger_Annotation a owl:Class ;
#     rdfs:label "Zinc Finger" ;
#     rdfs:comment "Extent of a zinc finger region." ;
#     rdfs:subClassOf up:Region_Annotation .
#
# rdf:List a owl:Class .
#
# rdfs:Datatype a owl:Class .
#
# owl:InverseFunctionalProperty a owl:Class .
#
# owl:TransitiveProperty a owl:Class .
#
# <http://www.w3.org/ns/sparql-service-description#Service> a owl:Class .
#
# faldo:OneOfPosition a owl:Class .
#
# up:Active_Site_Annotation a owl:Class ;
#     rdfs:label "Active Site" ;
#     rdfs:comment "Amino acid(s) involved in the activity of an enzyme." ;
#     rdfs:subClassOf up:Site_Annotation .
#
# up:Alternative_Sequence_Annotation a owl:Class ;
#     rdfs:label "Splice Variant" ;
#     rdfs:comment "Description of sequence variants produced by alternative splicing." ;
#     rdfs:subClassOf up:Natural_Variation_Annotation .
#
# up:Binding_Site_Annotation a owl:Class ;
#     rdfs:label "Binding Site" ;
#     rdfs:comment "Binding site for any chemical group (co-enzyme, prosthetic group, etc.)." ;
#     rdfs:subClassOf up:Site_Annotation .
#
# up:Catalytic_Activity_Annotation a owl:Class ;
#     rdfs:label "Catalytic Activity Annotation" ;
#     rdfs:comment "Description of the reactions catalyzed by an enzyme." ;
#     rdfs:subClassOf up:Annotation .
#
# up:Cluster a owl:Class ;
#     rdfs:label "Cluster (UniRef)" ;
#     rdfs:comment "Cluster of proteins with similar sequences." ;
#     rdfs:subClassOf owl:Thing .
#
# up:Coiled_Coil_Annotation a owl:Class ;
#     rdfs:label "Coiled-Coil" ;
#     rdfs:comment "Extent of a coiled-coil region." ;
#     rdfs:subClassOf up:Region_Annotation .
#
# up:Cross-link_Annotation a owl:Class ;
#     rdfs:label "Crosslink" ;
#     rdfs:comment "Posttranslationally formed amino acid bonds." ;
#     rdfs:subClassOf up:Modification_Annotation .
#
# up:Disulfide_Bond_Annotation a owl:Class ;
#     rdfs:label "Disulfide Bond" ;
#     rdfs:comment "Describes residues which are linked by an intra-chain disulfide bond. If the endpoints are identical, the disulfide bond is an interchain one." ;
#     rdfs:subClassOf up:Modification_Annotation .
#
# up:Erroneous_Gene_Model_Prediction_Annotation a owl:Class ;
#     rdfs:label "Erroneous Gene Model Prediction" ;
#     rdfs:subClassOf up:Sequence_Caution_Annotation .
#
# up:Erroneous_Initiation_Annotation a owl:Class ;
#     rdfs:label "Erroneous Initiation" ;
#     rdfs:subClassOf up:Sequence_Caution_Annotation .
#
# up:Erroneous_Termination_Annotation a owl:Class ;
#     rdfs:label "Erroneous Termination" ;
#     rdfs:subClassOf up:Sequence_Caution_Annotation .
#
# up:Frameshift_Annotation a owl:Class ;
#     rdfs:label "Frameshift" ;
#     rdfs:subClassOf up:Sequence_Caution_Annotation .
#
# up:Glycosylation_Annotation a owl:Class ;
#     rdfs:label "Glycosylation Site" ;
#     rdfs:comment "Describes the occurrence of the attachment of a glycan (mono- or polysaccharide) to a residue of a protein." ;
#     rdfs:subClassOf up:Modification_Annotation .
#
# up:Initiator_Methionine_Annotation a owl:Class ;
#     rdfs:label "Initiator Methionine" ;
#     rdfs:comment "Indicates that the initiator methionine has been cleaved off and is not shown in the sequence." ;
#     rdfs:subClassOf up:Molecule_Processing_Annotation .
#
# up:Interaction a owl:Class ;
#     rdfs:label "Interaction" ;
#     rdfs:comment "Description of a protein-protein interaction." .
#
# up:Intramembrane_Annotation a owl:Class ;
#     rdfs:label "INTRAMEM" ;
#     rdfs:comment "Extent of a region located in a membrane without crossing it" ;
#     rdfs:subClassOf up:Region_Annotation .
#
# up:Journal_Citation a owl:Class ;
#     rdfs:label "Journal Citation" ;
#     rdfs:comment "An article published in a journal." ;
#     rdfs:subClassOf up:Published_Citation .
#
# up:Lipidation_Annotation a owl:Class ;
#     rdfs:label "Lipid Binding" ;
#     rdfs:comment "Covalent binding of a lipid moiety." ;
#     rdfs:subClassOf up:Modification_Annotation .
#
# up:Modified_Residue_Annotation a owl:Class ;
#     rdfs:label "Modified Residue" ;
#     rdfs:comment "Posttranslational modification of a residue." ;
#     rdfs:subClassOf up:Modification_Annotation .
#
# up:Motif_Annotation a owl:Class ;
#     rdfs:label "Motif" ;
#     rdfs:comment "Short (<=20 amino acids) sequence motif of biological interest." ;
#     rdfs:subClassOf up:Region_Annotation .
#
# up:Mutagenesis_Annotation a owl:Class ;
#     rdfs:label "Mutagenesis Site" ;
#     rdfs:comment "Site which has been experimentally altered." ;
#     rdfs:subClassOf up:Experimental_Information_Annotation .
#
# up:Natural_Variant_Annotation a owl:Class ;
#     rdfs:label "Sequence Variant" ;
#     rdfs:comment "Authors report that sequence variants exist." ;
#     rdfs:subClassOf up:Natural_Variation_Annotation .
#
# up:Nucleotide_Resource a owl:Class ;
#     rdfs:label "Nucleotide Resource" ;
#     rdfs:comment "A resource that descripes a nucleotide sequence." ;
#     rdfs:subClassOf up:Resource .
#
# up:Pathway a owl:Class ;
#     rdfs:label "Pathway" ;
#     rdfs:comment "A hierarchical discription of a metabolic pathway." .
#
# up:Propeptide_Annotation a owl:Class ;
#     rdfs:label "Propeptide" ;
#     rdfs:comment "Extent of a propeptide." ;
#     rdfs:subClassOf up:Molecule_Processing_Annotation .
#
# up:RNA_Editing_Annotation a owl:Class ;
#     rdfs:label "RNA Editing" ;
#     rdfs:comment "Description of any type of RNA editing that leads to one or more amino acid changes." ;
#     rdfs:subClassOf up:Annotation .
#
# up:Resource a owl:Class ;
#     rdfs:label "Resource" ;
#     rdfs:comment "A life science resource." .
#
# up:Sequence a owl:Class ;
#     rdfs:label "Sequence" ;
#     rdfs:comment "An amino acid sequence." .
#
# up:Structured_Name a owl:Class ;
#     rdfs:label "Structured_Name" ;
#     rdfs:comment "A resource that holds a set of the known names for this protein together." .
#
# up:Topological_Domain_Annotation a owl:Class ;
#     rdfs:label "Topological Domain" ;
#     rdfs:comment "A topological domain." ;
#     rdfs:subClassOf up:Region_Annotation .
#
# up:Topology a owl:Class ;
#     rdfs:label "Topology" ;
#     rdfs:subClassOf up:Subcellular_Location .
#
# up:Transit_Peptide_Annotation a owl:Class ;
#     rdfs:label "Transit Peptide" ;
#     rdfs:comment "Extent of a transit peptide (mitochondrion, chloroplast, thylakoid, cyanelle or microbody)." ;
#     rdfs:subClassOf up:Molecule_Processing_Annotation .
#
# up:Transmembrane_Annotation a owl:Class ;
#     rdfs:label "Transmembrane" ;
#     rdfs:comment "Extent of a transmembrane region." ;
#     rdfs:subClassOf up:Region_Annotation .
#
# faldo:InRangePosition a owl:Class .
#
# up:Chain_Annotation a owl:Class ;
#     rdfs:label "Chain" ;
#     rdfs:comment "Extent of a polypeptide chain in the mature protein." ;
#     rdfs:subClassOf up:Molecule_Processing_Annotation .
#
# up:Citation_Statement a owl:Class ;
#     rdfs:label "Citation Statement" ;
#     rdfs:comment "The relationship between a resource and a citation." ;
#     rdfs:subClassOf rdf:Statement .
#
# up:Part a owl:Class ;
#     rdfs:label "Protein part" ;
#     rdfs:comment "Description of a part of a protein." ;
#     rdfs:subClassOf owl:Thing .
#
# up:Peptide_Annotation a owl:Class ;
#     rdfs:label "Peptide" ;
#     rdfs:comment "Extent of a released active peptide." ;
#     rdfs:subClassOf up:Molecule_Processing_Annotation .
#
# up:Sequence_Conflict_Annotation a owl:Class ;
#     rdfs:label "Sequence Conflict" ;
#     rdfs:comment "Different sources report differing sequences." ;
#     rdfs:subClassOf up:Experimental_Information_Annotation .
#
# owl:FunctionalProperty a owl:Class .
#
# owl:Thing a owl:Class .
#
# faldo:ExactPosition a owl:Class .
#
# up:Site_Annotation a owl:Class ;
#     rdfs:label "Site" ;
#     rdfs:comment "Any interesting single amino-acid site on the sequence, that is not defined by another feature key. It can also apply to an amino acid bond which is represented by the positions of the two flanking amino acids." ;
#     rdfs:subClassOf up:Sequence_Annotation .
#
# owl:DatatypeProperty a owl:Class .
#
# owl:Restriction a owl:Class .
#
# up:Concept a owl:Class ;
#     rdfs:label "Concept" ;
#     rdfs:comment "A concept used to classify resources." ;
#     rdfs:subClassOf owl:Class .
#
# up:Simple_Sequence a owl:Class ;
#     rdfs:label "Simple Sequence" .
#
# rdf:Statement a owl:Class .
#
# up:Cellular_Component a owl:Class ;
#     rdfs:label "Cellular Component" ;
#     rdfs:subClassOf up:Subcellular_Location .
#
# up:Modified_Sequence a owl:Class ;
#     rdfs:label "Modified Sequence" ;
#     rdfs:subClassOf up:Known_Sequence .
#
# up:Reference_Proteome a owl:Class ;
#     rdfs:label "Reference_Proteome" ;
#     rdfs:comment """Some proteomes have been (manually and algorithmically) selected as reference
# proteomes.""" ;
#     rdfs:subClassOf up:Proteome .
#
# up:Representative_Proteome a owl:Class ;
#     rdfs:label "Representative_Proteome" ;
#     rdfs:comment "A proteome that is believed by curators, or selected programmatically to be representative for a number of related Proteomes" ;
#     rdfs:subClassOf up:Proteome .
#
# up:Transcript_Resource a owl:Class ;
#     rdfs:label "Transcript Resource" ;
#     rdfs:subClassOf up:Resource .
#
# faldo:Position a owl:Class .
#
# up:Sequence_Caution_Annotation a owl:Class ;
#     rdfs:label "Sequence Caution" ;
#     rdfs:comment "Warning about possible errors related to the protein sequence" ;
#     rdfs:subClassOf up:Annotation .
#
# up:Proteome a owl:Class ;
#     rdfs:label "Proteome" ;
#     rdfs:comment "Description of a proteome." .
#
# up:Enzyme a owl:Class ;
#     rdfs:label "Enzyme" ;
#     rdfs:comment "A specific catalytic activity, defined by the Enzyme Commission of the Nomenclature Committee of the International Union of Biochemistry and Molecular Biology (IUBMB)." .
#
# up:External_Sequence a owl:Class ;
#     rdfs:label "External Sequence" ;
#     rdfs:comment "The protein described in the linked record is an alternative splice form of the same gene product as described in this record. The function between the two isoforms is highly divergent." ;
#     rdfs:subClassOf up:Known_Sequence .
#
# up:Taxon a owl:Class ;
#     rdfs:label "Taxon" ;
#     rdfs:comment "An element of a taxonomy for classifying life forms." .
#
# up:Region_Annotation a owl:Class ;
#     rdfs:label "Region" ;
#     rdfs:subClassOf up:Sequence_Annotation .
#
# up:Protein a owl:Class ;
#     rdfs:label "Protein" ;
#     rdfs:comment "Description of a protein." ;
#     rdfs:subClassOf owl:Thing .
#
# up:Annotation a owl:Class ;
#     rdfs:label "Annotation" ;
#     rdfs:comment "Description of a resource on a specific topic." .
#
# owl:ObjectProperty a owl:Class .
#
# owl:Class a owl:Class .
#
#
# 1223

# %%
import requests
from rdflib import Graph

# TODO: build decent SHACL shapes?

query = """PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX sh: <http://www.w3.org/ns/shacl#>
PREFIX void: <http://rdfs.org/ns/void#>

CONSTRUCT {
    # ?classShape a sh:NodeShape ;
                sh:targetClass ?class1 ;
                sh:property ?propertyShape ;
                rdfs:label ?class1Label .

    # ?propertyShape sh:path ?prop ;
                   sh:class ?class2 ;
                   sh:description ?propLabel ;
                   sh:node ?class2Shape ;
                   sh:minCount 0 ;
                   sh:maxCount ?maxCount .

    # ?class2Shape a sh:NodeShape ;
                 sh:targetClass ?class2 ;
                 rdfs:label ?class2Label .
} WHERE {
    # ?s <http://www.w3.org/ns/sparql-service-description#graph> ?graph .
    # ?graph void:classPartition ?cp1 .
    # ?cp1 void:class ?class1 ;
          void:propertyPartition ?pp1 .
    # ?pp1 void:property ?prop ;
          void:triples ?pp1triples ;
          void:classPartition ?cp2 .
    # ?cp2 void:class ?class2 .

    OPTIONAL { ?class1 rdfs:label ?class1Label . }
    OPTIONAL { ?class2 rdfs:label ?class2Label . }
    OPTIONAL { ?prop rdfs:label ?propLabel . }

    # Generate unique shapes for classes and properties
    BIND(IRI(CONCAT(STR(?class1), "_Shape")) AS ?classShape)
    BIND(IRI(CONCAT(STR(?class2), "_Shape")) AS ?class2Shape)
    BIND(IRI(CONCAT(STR(?class1), "/property/", STRAFTER(STR(?prop), "#"))) AS ?propertyShape)

    # For demonstration, setting maxCount as a static example. It can be adjusted based on the actual data or requirements
    BIND(1 AS ?maxCount)
} ORDER BY DESC(?pp1triples)"""

response = requests.post(
    "https://sparql.uniprot.org/sparql/",
    headers={"Accept": "text/turtle"},
    data={"query": query},
    timeout=60,
)
response.raise_for_status()
g = Graph()
g.bind("faldo", "http://biohackathon.org/resource/faldo#")
g.bind("up", "http://purl.uniprot.org/core/")

g.parse(data=response.text.replace("[ ],", ""), format="turtle")
# NOTE: replace is a hack to remove useless blank nodes

# print(response.text)
print(g.serialize(format="turtle"))
print(len(g))
# Out:
# @prefix faldo: <http://biohackathon.org/resource/faldo#> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix sh: <http://www.w3.org/ns/shacl#> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
# @prefix up: <http://purl.uniprot.org/core/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# up:Database_Shape a sh:NodeShape ;
#     rdfs:label "Database (description of)" ;
#     sh:property <http://purl.uniprot.org/core/Database/property/> ;
#     sh:targetClass up:Database .
#
# up:Mass_Measurement_Method_Shape a sh:NodeShape ;
#     rdfs:label "Mass Measurement" ;
#     sh:property <http://purl.uniprot.org/core/Mass_Measurement_Method/property/isDefinedBy> ;
#     sh:targetClass up:Mass_Measurement_Method .
#
# up:Organelle_Shape a sh:NodeShape ;
#     rdfs:label "Organelle" ;
#     sh:property <http://purl.uniprot.org/core/Organelle/property/isDefinedBy> ;
#     sh:targetClass up:Organelle .
#
# up:Protein_Existence_Shape a sh:NodeShape ;
#     rdfs:label "Protein existence evidence" ;
#     sh:property <http://purl.uniprot.org/core/Protein_Existence/property/isDefinedBy> ;
#     sh:targetClass up:Protein_Existence .
#
# up:Status_Shape a sh:NodeShape ;
#     rdfs:label "Status" ;
#     sh:property <http://purl.uniprot.org/core/Status/property/isDefinedBy> ;
#     sh:targetClass up:Status .
#
# up:Structure_Determination_Method_Shape a sh:NodeShape ;
#     rdfs:label "Structure Determination" ;
#     sh:property <http://purl.uniprot.org/core/Structure_Determination_Method/property/isDefinedBy> ;
#     sh:targetClass up:Structure_Determination_Method .
#
# owl:Axiom_Shape a sh:NodeShape ;
#     sh:property <http://www.w3.org/2002/07/owl#Axiom/property/annotatedSource> ;
#     sh:targetClass owl:Axiom .
#
# owl:InverseFunctionalProperty_Shape a sh:NodeShape ;
#     sh:property <http://www.w3.org/2002/07/owl#InverseFunctionalProperty/property/domain>,
#         <http://www.w3.org/2002/07/owl#InverseFunctionalProperty/property/isDefinedBy>,
#         <http://www.w3.org/2002/07/owl#InverseFunctionalProperty/property/range> ;
#     sh:targetClass owl:InverseFunctionalProperty .
#
# sh:SPARQLAskExecutable_Shape a sh:NodeShape ;
#     sh:property <http://www.w3.org/ns/shacl#SPARQLAskExecutable/property/prefixes> ;
#     sh:targetClass sh:SPARQLAskExecutable .
#
# sh:SPARQLConstructExecutable_Shape a sh:NodeShape ;
#     sh:property <http://www.w3.org/ns/shacl#SPARQLConstructExecutable/property/prefixes> ;
#     sh:targetClass sh:SPARQLConstructExecutable .
#
# sh:SPARQLExecutable_Shape a sh:NodeShape ;
#     sh:property <http://www.w3.org/ns/shacl#SPARQLExecutable/property/prefixes> ;
#     sh:targetClass sh:SPARQLExecutable .
#
# sh:SPARQLSelectExecutable_Shape a sh:NodeShape ;
#     sh:property <http://www.w3.org/ns/shacl#SPARQLSelectExecutable/property/prefixes> ;
#     sh:targetClass sh:SPARQLSelectExecutable .
#
# <http://biohackathon.org/resource/faldo#ExactPosition/property/reference> sh:class up:External_Sequence,
#         up:Modified_Sequence,
#         up:Simple_Sequence ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:External_Sequence_Shape,
#         up:Modified_Sequence_Shape,
#         up:Simple_Sequence_Shape ;
#     sh:path faldo:reference .
#
# <http://biohackathon.org/resource/faldo#InRangePosition/property/begin> sh:class faldo:ExactPosition,
#         faldo:Position ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:ExactPosition_Shape,
#         faldo:Position_Shape ;
#     sh:path faldo:begin .
#
# <http://biohackathon.org/resource/faldo#InRangePosition/property/end> sh:class faldo:ExactPosition,
#         faldo:Position ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:ExactPosition_Shape,
#         faldo:Position_Shape ;
#     sh:path faldo:end .
#
# <http://biohackathon.org/resource/faldo#InRangePosition/property/reference> sh:class up:External_Sequence,
#         up:Simple_Sequence ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:External_Sequence_Shape,
#         up:Simple_Sequence_Shape ;
#     sh:path faldo:reference .
#
# <http://biohackathon.org/resource/faldo#OneOfPosition/property/possiblePosition> sh:class faldo:ExactPosition,
#         faldo:Position ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:ExactPosition_Shape,
#         faldo:Position_Shape ;
#     sh:path faldo:possiblePosition .
#
# <http://biohackathon.org/resource/faldo#OneOfPosition/property/reference> sh:class up:External_Sequence,
#         up:Simple_Sequence ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:External_Sequence_Shape,
#         up:Simple_Sequence_Shape ;
#     sh:path faldo:reference .
#
# <http://biohackathon.org/resource/faldo#Position/property/begin> sh:class faldo:ExactPosition,
#         faldo:Position ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:ExactPosition_Shape,
#         faldo:Position_Shape ;
#     sh:path faldo:begin .
#
# <http://biohackathon.org/resource/faldo#Position/property/end> sh:class faldo:ExactPosition,
#         faldo:Position ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:ExactPosition_Shape,
#         faldo:Position_Shape ;
#     sh:path faldo:end .
#
# <http://biohackathon.org/resource/faldo#Position/property/possiblePosition> sh:class faldo:ExactPosition,
#         faldo:Position ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:ExactPosition_Shape,
#         faldo:Position_Shape ;
#     sh:path faldo:possiblePosition .
#
# <http://biohackathon.org/resource/faldo#Position/property/reference> sh:class up:External_Sequence,
#         up:Modified_Sequence,
#         up:Simple_Sequence ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:External_Sequence_Shape,
#         up:Modified_Sequence_Shape,
#         up:Simple_Sequence_Shape ;
#     sh:path faldo:reference .
#
# <http://biohackathon.org/resource/faldo#Region/property/begin> sh:class faldo:ExactPosition,
#         faldo:InRangePosition,
#         faldo:OneOfPosition,
#         faldo:Position ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:ExactPosition_Shape,
#         faldo:InRangePosition_Shape,
#         faldo:OneOfPosition_Shape,
#         faldo:Position_Shape ;
#     sh:path faldo:begin .
#
# <http://biohackathon.org/resource/faldo#Region/property/end> sh:class faldo:ExactPosition,
#         faldo:InRangePosition,
#         faldo:OneOfPosition,
#         faldo:Position ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:ExactPosition_Shape,
#         faldo:InRangePosition_Shape,
#         faldo:OneOfPosition_Shape,
#         faldo:Position_Shape ;
#     sh:path faldo:end .
#
# <http://purl.uniprot.org/core/Active_Site_Annotation/property/> sh:class faldo:Region,
#         up:Modified_Sequence ;
#     sh:description "range",
#         "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:Region_Shape,
#         up:Modified_Sequence_Shape ;
#     sh:path up:range,
#         up:sequence .
#
# <http://purl.uniprot.org/core/Activity_Regulation_Annotation/property/> sh:class up:Chain_Annotation,
#         up:Modified_Sequence,
#         up:Peptide_Annotation,
#         up:Simple_Sequence,
#         up:Unknown_Sequence ;
#     sh:description "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Chain_Annotation_Shape,
#         up:Modified_Sequence_Shape,
#         up:Peptide_Annotation_Shape,
#         up:Simple_Sequence_Shape,
#         up:Unknown_Sequence_Shape ;
#     sh:path up:sequence .
#
# <http://purl.uniprot.org/core/Allergen_Annotation/property/> sh:class up:Chain_Annotation ;
#     sh:description "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Chain_Annotation_Shape ;
#     sh:path up:sequence .
#
# <http://purl.uniprot.org/core/Alternative_Initiation_Annotation/property/> sh:class up:External_Sequence,
#         up:Modified_Sequence,
#         up:Simple_Sequence,
#         up:Unknown_Sequence ;
#     sh:description "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:External_Sequence_Shape,
#         up:Modified_Sequence_Shape,
#         up:Simple_Sequence_Shape,
#         up:Unknown_Sequence_Shape ;
#     sh:path up:sequence .
#
# <http://purl.uniprot.org/core/Alternative_Promoter_Usage_Annotation/property/> sh:class up:External_Sequence,
#         up:Modified_Sequence,
#         up:Simple_Sequence,
#         up:Unknown_Sequence ;
#     sh:description "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:External_Sequence_Shape,
#         up:Modified_Sequence_Shape,
#         up:Simple_Sequence_Shape,
#         up:Unknown_Sequence_Shape ;
#     sh:path up:sequence .
#
# <http://purl.uniprot.org/core/Alternative_Sequence_Annotation/property/> sh:class faldo:Region ;
#     sh:description "range" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:Region_Shape ;
#     sh:path up:range .
#
# <http://purl.uniprot.org/core/Alternative_Splicing_Annotation/property/> sh:class up:External_Sequence,
#         up:Modified_Sequence,
#         up:Simple_Sequence,
#         up:Unknown_Sequence ;
#     sh:description "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:External_Sequence_Shape,
#         up:Modified_Sequence_Shape,
#         up:Simple_Sequence_Shape,
#         up:Unknown_Sequence_Shape ;
#     sh:path up:sequence .
#
# <http://purl.uniprot.org/core/Annotation/property/> sh:class up:Chain_Annotation,
#         up:External_Sequence,
#         up:Modified_Sequence,
#         up:Peptide_Annotation,
#         up:Simple_Sequence,
#         up:Unknown_Sequence ;
#     sh:description "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Chain_Annotation_Shape,
#         up:External_Sequence_Shape,
#         up:Modified_Sequence_Shape,
#         up:Peptide_Annotation_Shape,
#         up:Simple_Sequence_Shape,
#         up:Unknown_Sequence_Shape ;
#     sh:path up:sequence .
#
# <http://purl.uniprot.org/core/Beta_Strand_Annotation/property/> sh:class faldo:Region ;
#     sh:description "range" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:Region_Shape ;
#     sh:path up:range .
#
# <http://purl.uniprot.org/core/Binding_Site_Annotation/property/> sh:class faldo:Region,
#         up:Modified_Sequence ;
#     sh:description "range",
#         "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:Region_Shape,
#         up:Modified_Sequence_Shape ;
#     sh:path up:range,
#         up:sequence .
#
# <http://purl.uniprot.org/core/Biotechnology_Annotation/property/> sh:class up:Chain_Annotation,
#         up:Modified_Sequence ;
#     sh:description "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Chain_Annotation_Shape,
#         up:Modified_Sequence_Shape ;
#     sh:path up:sequence .
#
# <http://purl.uniprot.org/core/Catalytic_Activity_Annotation/property/> sh:class up:Catalytic_Activity,
#         up:Chain_Annotation,
#         up:Modified_Sequence,
#         up:Simple_Sequence,
#         up:Unknown_Sequence ;
#     sh:description "catalytic activity",
#         "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Catalytic_Activity_Shape,
#         up:Chain_Annotation_Shape,
#         up:Modified_Sequence_Shape,
#         up:Simple_Sequence_Shape,
#         up:Unknown_Sequence_Shape ;
#     sh:path up:catalyticActivity,
#         up:sequence .
#
# <http://purl.uniprot.org/core/Caution_Annotation/property/> sh:class up:Chain_Annotation,
#         up:Modified_Sequence,
#         up:Peptide_Annotation,
#         up:Simple_Sequence ;
#     sh:description "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Chain_Annotation_Shape,
#         up:Modified_Sequence_Shape,
#         up:Peptide_Annotation_Shape,
#         up:Simple_Sequence_Shape ;
#     sh:path up:sequence .
#
# <http://purl.uniprot.org/core/Cellular_Component/property/> sh:class up:Cellular_Component,
#         up:Citation ;
#     sh:description "citation",
#         "part of",
#         "related location" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Cellular_Component_Shape,
#         up:Citation_Shape ;
#     sh:path up:citation,
#         up:partOf,
#         up:relatedLocation .
#
# <http://purl.uniprot.org/core/Cellular_Component/property/exactMatch> sh:class owl:Class ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node owl:Class_Shape ;
#     sh:path skos:exactMatch .
#
# <http://purl.uniprot.org/core/Cellular_Component/property/subClassOf> sh:class up:Cellular_Component ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Cellular_Component_Shape ;
#     sh:path rdfs:subClassOf .
#
# <http://purl.uniprot.org/core/Chain_Annotation/property/> sh:class faldo:Region ;
#     sh:description "range" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:Region_Shape ;
#     sh:path up:range .
#
# <http://purl.uniprot.org/core/Citation_Statement/property/> sh:class up:Annotation,
#         up:Plasmid,
#         up:Strain,
#         up:Tissue,
#         up:Transposon ;
#     sh:description "context",
#         "mapped annotation" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Annotation_Shape,
#         up:Plasmid_Shape,
#         up:Strain_Shape,
#         up:Tissue_Shape,
#         up:Transposon_Shape ;
#     sh:path up:context,
#         up:mappedAnnotation .
#
# <http://purl.uniprot.org/core/Citation_Statement/property/object> sh:class up:Book_Citation,
#         up:Electronic_Citation,
#         up:Journal_Citation,
#         up:Observation_Citation,
#         up:Patent_Citation,
#         up:Submission_Citation,
#         up:Thesis_Citation ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Book_Citation_Shape,
#         up:Electronic_Citation_Shape,
#         up:Journal_Citation_Shape,
#         up:Observation_Citation_Shape,
#         up:Patent_Citation_Shape,
#         up:Submission_Citation_Shape,
#         up:Thesis_Citation_Shape ;
#     sh:path rdf:object .
#
# <http://purl.uniprot.org/core/Citation_Statement/property/subject> sh:class up:Protein ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Protein_Shape ;
#     sh:path rdf:subject .
#
# up:Citation_Statement_Shape a sh:NodeShape ;
#     rdfs:label "Citation Statement" ;
#     sh:property <http://purl.uniprot.org/core/Citation_Statement/property/>,
#         <http://purl.uniprot.org/core/Citation_Statement/property/object>,
#         <http://purl.uniprot.org/core/Citation_Statement/property/subject> ;
#     sh:targetClass up:Citation_Statement .
#
# <http://purl.uniprot.org/core/Cluster/property/> sh:class up:Sequence ;
#     sh:description "member" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Sequence_Shape ;
#     sh:path up:member .
#
# up:Cluster_Shape a sh:NodeShape ;
#     rdfs:label "Cluster (UniRef)" ;
#     sh:property <http://purl.uniprot.org/core/Cluster/property/> ;
#     sh:targetClass up:Cluster .
#
# <http://purl.uniprot.org/core/Cofactor_Annotation/property/> sh:class up:Chain_Annotation,
#         up:Modified_Sequence,
#         up:Peptide_Annotation,
#         up:Simple_Sequence,
#         up:Unknown_Sequence ;
#     sh:description "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Chain_Annotation_Shape,
#         up:Modified_Sequence_Shape,
#         up:Peptide_Annotation_Shape,
#         up:Simple_Sequence_Shape,
#         up:Unknown_Sequence_Shape ;
#     sh:path up:sequence .
#
# <http://purl.uniprot.org/core/Coiled_Coil_Annotation/property/> sh:class faldo:Region,
#         up:Modified_Sequence ;
#     sh:description "range",
#         "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:Region_Shape,
#         up:Modified_Sequence_Shape ;
#     sh:path up:range,
#         up:sequence .
#
# <http://purl.uniprot.org/core/Compositional_Bias_Annotation/property/> sh:class faldo:Region ;
#     sh:description "range" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:Region_Shape ;
#     sh:path up:range .
#
# <http://purl.uniprot.org/core/Concept/property/> sh:class up:Concept ;
#     sh:description "category" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Concept_Shape ;
#     sh:path up:category .
#
# <http://purl.uniprot.org/core/Concept/property/narrower> sh:class up:Concept ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Concept_Shape ;
#     sh:path skos:narrower .
#
# <http://purl.uniprot.org/core/Concept/property/seeAlso> sh:class owl:Class ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node owl:Class_Shape ;
#     sh:path rdfs:seeAlso .
#
# <http://purl.uniprot.org/core/Concept/property/subClassOf> sh:class up:Concept ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Concept_Shape ;
#     sh:path rdfs:subClassOf .
#
# <http://purl.uniprot.org/core/Cross-link_Annotation/property/> sh:class faldo:Region,
#         up:Modified_Sequence ;
#     sh:description "range",
#         "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:Region_Shape,
#         up:Modified_Sequence_Shape ;
#     sh:path up:range,
#         up:sequence .
#
# <http://purl.uniprot.org/core/Database/property/> sh:class up:Citation ;
#     sh:description "citation" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Citation_Shape ;
#     sh:path up:citation .
#
# <http://purl.uniprot.org/core/Developmental_Stage_Annotation/property/> sh:class up:Chain_Annotation,
#         up:Modified_Sequence,
#         up:Peptide_Annotation,
#         up:Simple_Sequence ;
#     sh:description "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Chain_Annotation_Shape,
#         up:Modified_Sequence_Shape,
#         up:Peptide_Annotation_Shape,
#         up:Simple_Sequence_Shape ;
#     sh:path up:sequence .
#
# <http://purl.uniprot.org/core/Disease_Annotation/property/> sh:class up:Chain_Annotation,
#         up:Modified_Sequence ;
#     sh:description "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Chain_Annotation_Shape,
#         up:Modified_Sequence_Shape ;
#     sh:path up:sequence .
#
# <http://purl.uniprot.org/core/Disruption_Phenotype_Annotation/property/> sh:class up:Chain_Annotation,
#         up:Modified_Sequence,
#         up:Peptide_Annotation,
#         up:Simple_Sequence ;
#     sh:description "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Chain_Annotation_Shape,
#         up:Modified_Sequence_Shape,
#         up:Peptide_Annotation_Shape,
#         up:Simple_Sequence_Shape ;
#     sh:path up:sequence .
#
# <http://purl.uniprot.org/core/Disulfide_Bond_Annotation/property/> sh:class faldo:Region,
#         up:Modified_Sequence ;
#     sh:description "range",
#         "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:Region_Shape,
#         up:Modified_Sequence_Shape ;
#     sh:path up:range,
#         up:sequence .
#
# <http://purl.uniprot.org/core/Domain_Annotation/property/> sh:class up:Chain_Annotation,
#         up:External_Sequence,
#         up:Modified_Sequence,
#         up:Peptide_Annotation,
#         up:Simple_Sequence ;
#     sh:description "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Chain_Annotation_Shape,
#         up:External_Sequence_Shape,
#         up:Modified_Sequence_Shape,
#         up:Peptide_Annotation_Shape,
#         up:Simple_Sequence_Shape ;
#     sh:path up:sequence .
#
# <http://purl.uniprot.org/core/Domain_Extent_Annotation/property/> sh:class faldo:Region ;
#     sh:description "range" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:Region_Shape ;
#     sh:path up:range .
#
# <http://purl.uniprot.org/core/Enzyme/property/> sh:class up:Catalytic_Activity,
#         up:Citation,
#         up:Enzyme ;
#     sh:description "catalytic activity",
#         "citation",
#         "replaced by",
#         "replaces" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Catalytic_Activity_Shape,
#         up:Citation_Shape,
#         up:Enzyme_Shape ;
#     sh:path up:activity,
#         up:citation,
#         up:replacedBy,
#         up:replaces .
#
# <http://purl.uniprot.org/core/Enzyme/property/broaderTransitive> sh:class up:Enzyme ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Enzyme_Shape ;
#     sh:path skos:broaderTransitive .
#
# <http://purl.uniprot.org/core/Enzyme/property/narrowerTransitive> sh:class up:Enzyme ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Enzyme_Shape ;
#     sh:path skos:narrowerTransitive .
#
# <http://purl.uniprot.org/core/Enzyme/property/subClassOf> sh:class up:Enzyme ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Enzyme_Shape ;
#     sh:path rdfs:subClassOf .
#
# <http://purl.uniprot.org/core/Erroneous_Gene_Model_Prediction_Annotation/property/> sh:class up:External_Sequence,
#         up:Modified_Sequence ;
#     sh:description "conflicting sequence",
#         "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:External_Sequence_Shape,
#         up:Modified_Sequence_Shape ;
#     sh:path up:conflictingSequence,
#         up:sequence .
#
# <http://purl.uniprot.org/core/Erroneous_Initiation_Annotation/property/> sh:class up:External_Sequence,
#         up:Modified_Sequence,
#         up:Simple_Sequence ;
#     sh:description "conflicting sequence",
#         "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:External_Sequence_Shape,
#         up:Modified_Sequence_Shape,
#         up:Simple_Sequence_Shape ;
#     sh:path up:conflictingSequence,
#         up:sequence .
#
# <http://purl.uniprot.org/core/Erroneous_Termination_Annotation/property/> sh:class up:External_Sequence,
#         up:Modified_Sequence ;
#     sh:description "conflicting sequence",
#         "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:External_Sequence_Shape,
#         up:Modified_Sequence_Shape ;
#     sh:path up:conflictingSequence,
#         up:sequence .
#
# <http://purl.uniprot.org/core/Erroneous_Translation_Annotation/property/> sh:class up:External_Sequence ;
#     sh:description "conflicting sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:External_Sequence_Shape ;
#     sh:path up:conflictingSequence .
#
# <http://purl.uniprot.org/core/External_Sequence/property/> sh:class up:Alternative_Sequence_Annotation,
#         up:Book_Citation,
#         up:Electronic_Citation,
#         up:External_Sequence,
#         up:Journal_Citation,
#         up:Nucleotide_Resource,
#         up:Observation_Citation,
#         up:Patent_Citation,
#         up:Simple_Sequence,
#         up:Submission_Citation,
#         up:Thesis_Citation ;
#     sh:description "based on",
#         "citation",
#         "modification",
#         "translated from" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Alternative_Sequence_Annotation_Shape,
#         up:Book_Citation_Shape,
#         up:Electronic_Citation_Shape,
#         up:External_Sequence_Shape,
#         up:Journal_Citation_Shape,
#         up:Nucleotide_Resource_Shape,
#         up:Observation_Citation_Shape,
#         up:Patent_Citation_Shape,
#         up:Simple_Sequence_Shape,
#         up:Submission_Citation_Shape,
#         up:Thesis_Citation_Shape ;
#     sh:path up:basedOn,
#         up:citation,
#         up:modification,
#         up:translatedFrom .
#
# <http://purl.uniprot.org/core/Frameshift_Annotation/property/> sh:class up:External_Sequence,
#         up:Modified_Sequence,
#         up:Simple_Sequence ;
#     sh:description "conflicting sequence",
#         "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:External_Sequence_Shape,
#         up:Modified_Sequence_Shape,
#         up:Simple_Sequence_Shape ;
#     sh:path up:conflictingSequence,
#         up:sequence .
#
# <http://purl.uniprot.org/core/Function_Annotation/property/> sh:class up:Chain_Annotation,
#         up:External_Sequence,
#         up:Modified_Sequence,
#         up:Peptide_Annotation,
#         up:Simple_Sequence,
#         up:Unknown_Sequence ;
#     sh:description "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Chain_Annotation_Shape,
#         up:External_Sequence_Shape,
#         up:Modified_Sequence_Shape,
#         up:Peptide_Annotation_Shape,
#         up:Simple_Sequence_Shape,
#         up:Unknown_Sequence_Shape ;
#     sh:path up:sequence .
#
# up:Genomic_DNA_Shape a sh:NodeShape ;
#     rdfs:label "Genomic DNA" ;
#     sh:targetClass up:Genomic_DNA .
#
# up:Genomic_RNA_Shape a sh:NodeShape ;
#     rdfs:label "Genomic RNA" ;
#     sh:targetClass up:Genomic_RNA .
#
# <http://purl.uniprot.org/core/Glycosylation_Annotation/property/> sh:class faldo:Region,
#         up:Modified_Sequence ;
#     sh:description "range",
#         "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:Region_Shape,
#         up:Modified_Sequence_Shape ;
#     sh:path up:range,
#         up:sequence .
#
# <http://purl.uniprot.org/core/Helix_Annotation/property/> sh:class faldo:Region ;
#     sh:description "range" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:Region_Shape ;
#     sh:path up:range .
#
# <http://purl.uniprot.org/core/Induction_Annotation/property/> sh:class up:Chain_Annotation,
#         up:External_Sequence,
#         up:Modified_Sequence,
#         up:Peptide_Annotation,
#         up:Simple_Sequence ;
#     sh:description "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Chain_Annotation_Shape,
#         up:External_Sequence_Shape,
#         up:Modified_Sequence_Shape,
#         up:Peptide_Annotation_Shape,
#         up:Simple_Sequence_Shape ;
#     sh:path up:sequence .
#
# <http://purl.uniprot.org/core/Initiator_Methionine_Annotation/property/> sh:class faldo:Region,
#         up:External_Sequence,
#         up:Modified_Sequence ;
#     sh:description "range",
#         "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:Region_Shape,
#         up:External_Sequence_Shape,
#         up:Modified_Sequence_Shape ;
#     sh:path up:range,
#         up:sequence .
#
# <http://purl.uniprot.org/core/Interaction/property/> sh:class up:Participant ;
#     sh:description "participant" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Participant_Shape ;
#     sh:path up:participant .
#
# up:Interaction_Shape a sh:NodeShape ;
#     rdfs:label "Interaction" ;
#     sh:property <http://purl.uniprot.org/core/Interaction/property/> ;
#     sh:targetClass up:Interaction .
#
# <http://purl.uniprot.org/core/Intramembrane_Annotation/property/> sh:class faldo:Region,
#         up:Modified_Sequence ;
#     sh:description "range",
#         "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:Region_Shape,
#         up:Modified_Sequence_Shape ;
#     sh:path up:range,
#         up:sequence .
#
# <http://purl.uniprot.org/core/Journal_Citation/property/> sh:class up:Electronic_Citation,
#         up:Journal_Citation ;
#     sh:description "erratum" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Electronic_Citation_Shape,
#         up:Journal_Citation_Shape ;
#     sh:path up:erratum .
#
# <http://purl.uniprot.org/core/Kinetics_Annotation/property/> sh:class up:Chain_Annotation,
#         up:Modified_Sequence,
#         up:Simple_Sequence ;
#     sh:description "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Chain_Annotation_Shape,
#         up:Modified_Sequence_Shape,
#         up:Simple_Sequence_Shape ;
#     sh:path up:sequence .
#
# <http://purl.uniprot.org/core/Lipidation_Annotation/property/> sh:class faldo:Region,
#         up:Modified_Sequence ;
#     sh:description "range",
#         "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:Region_Shape,
#         up:Modified_Sequence_Shape ;
#     sh:path up:range,
#         up:sequence .
#
# up:MRNA_Shape a sh:NodeShape ;
#     rdfs:label "mRNA" ;
#     sh:targetClass up:MRNA .
#
# <http://purl.uniprot.org/core/Mass_Measurement_Method/property/isDefinedBy> sh:class owl:Ontology ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node owl:Ontology_Shape ;
#     sh:path rdfs:isDefinedBy .
#
# <http://purl.uniprot.org/core/Mass_Spectrometry_Annotation/property/> sh:class up:Chain_Annotation,
#         up:Modified_Sequence,
#         up:Peptide_Annotation,
#         up:Simple_Sequence ;
#     sh:description "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Chain_Annotation_Shape,
#         up:Modified_Sequence_Shape,
#         up:Peptide_Annotation_Shape,
#         up:Simple_Sequence_Shape ;
#     sh:path up:sequence .
#
# <http://purl.uniprot.org/core/Modified_Residue_Annotation/property/> sh:class faldo:Region,
#         up:External_Sequence,
#         up:Modified_Sequence ;
#     sh:description "range",
#         "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:Region_Shape,
#         up:External_Sequence_Shape,
#         up:Modified_Sequence_Shape ;
#     sh:path up:range,
#         up:sequence .
#
# <http://purl.uniprot.org/core/Modified_Sequence/property/> sh:class up:Alternative_Sequence_Annotation,
#         up:External_Sequence,
#         up:Simple_Sequence ;
#     sh:description "based on",
#         "modification" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Alternative_Sequence_Annotation_Shape,
#         up:External_Sequence_Shape,
#         up:Simple_Sequence_Shape ;
#     sh:path up:basedOn,
#         up:modification .
#
# <http://purl.uniprot.org/core/Motif_Annotation/property/> sh:class faldo:Region,
#         up:Modified_Sequence ;
#     sh:description "range",
#         "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:Region_Shape,
#         up:Modified_Sequence_Shape ;
#     sh:path up:range,
#         up:sequence .
#
# <http://purl.uniprot.org/core/Mutagenesis_Annotation/property/> sh:class faldo:Region,
#         up:Modified_Sequence ;
#     sh:description "range",
#         "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:Region_Shape,
#         up:Modified_Sequence_Shape ;
#     sh:path up:range,
#         up:sequence .
#
# <http://purl.uniprot.org/core/Natural_Variant_Annotation/property/> sh:class faldo:Region,
#         up:Modified_Sequence ;
#     sh:description "range",
#         "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:Region_Shape,
#         up:Modified_Sequence_Shape ;
#     sh:path up:range,
#         up:sequence .
#
# <http://purl.uniprot.org/core/Non-adjacent_Residues_Annotation/property/> sh:class faldo:Region ;
#     sh:description "range" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:Region_Shape ;
#     sh:path up:range .
#
# <http://purl.uniprot.org/core/Non-standard_Residue_Annotation/property/> sh:class faldo:Region ;
#     sh:description "range" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:Region_Shape ;
#     sh:path up:range .
#
# <http://purl.uniprot.org/core/Non-terminal_Residue_Annotation/property/> sh:class faldo:Region ;
#     sh:description "range" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:Region_Shape ;
#     sh:path up:range .
#
# <http://purl.uniprot.org/core/Non_Self_Interaction/property/> sh:class up:Participant ;
#     sh:description "participant" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Participant_Shape ;
#     sh:path up:participant .
#
# up:Non_Self_Interaction_Shape a sh:NodeShape ;
#     rdfs:label "Non self interaction" ;
#     sh:property <http://purl.uniprot.org/core/Non_Self_Interaction/property/> ;
#     sh:targetClass up:Non_Self_Interaction .
#
# <http://purl.uniprot.org/core/Nucleotide_Binding_Annotation/property/> sh:class faldo:Region ;
#     sh:description "range" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:Region_Shape ;
#     sh:path up:range .
#
# <http://purl.uniprot.org/core/Nucleotide_Resource/property/> sh:class up:Book_Citation,
#         up:Electronic_Citation,
#         up:Genomic_DNA,
#         up:Genomic_RNA,
#         up:Journal_Citation,
#         up:MRNA,
#         up:Other_DNA,
#         up:Other_RNA,
#         up:Patent_Citation,
#         up:Submission_Citation,
#         up:Thesis_Citation,
#         up:Transcribed_RNA,
#         up:Unassigned_DNA,
#         up:Unassigned_RNA,
#         up:Viral_cRNA ;
#     sh:description "citation",
#         "located on" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Book_Citation_Shape,
#         up:Electronic_Citation_Shape,
#         up:Genomic_DNA_Shape,
#         up:Genomic_RNA_Shape,
#         up:Journal_Citation_Shape,
#         up:MRNA_Shape,
#         up:Other_DNA_Shape,
#         up:Other_RNA_Shape,
#         up:Patent_Citation_Shape,
#         up:Submission_Citation_Shape,
#         up:Thesis_Citation_Shape,
#         up:Transcribed_RNA_Shape,
#         up:Unassigned_DNA_Shape,
#         up:Unassigned_RNA_Shape,
#         up:Viral_cRNA_Shape ;
#     sh:path up:citation,
#         up:locatedOn .
#
# <http://purl.uniprot.org/core/Organelle/property/isDefinedBy> sh:class owl:Ontology ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node owl:Ontology_Shape ;
#     sh:path rdfs:isDefinedBy .
#
# up:Other_DNA_Shape a sh:NodeShape ;
#     rdfs:label "Other DNA" ;
#     sh:targetClass up:Other_DNA .
#
# up:Other_RNA_Shape a sh:NodeShape ;
#     rdfs:label "Other RNA" ;
#     sh:targetClass up:Other_RNA .
#
# <http://purl.uniprot.org/core/PH_Dependence_Annotation/property/> sh:class up:Chain_Annotation,
#         up:Modified_Sequence,
#         up:Peptide_Annotation,
#         up:Simple_Sequence ;
#     sh:description "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Chain_Annotation_Shape,
#         up:Modified_Sequence_Shape,
#         up:Peptide_Annotation_Shape,
#         up:Simple_Sequence_Shape ;
#     sh:path up:sequence .
#
# <http://purl.uniprot.org/core/PTM_Annotation/property/> sh:class up:Chain_Annotation,
#         up:External_Sequence,
#         up:Modified_Sequence,
#         up:Peptide_Annotation,
#         up:Simple_Sequence,
#         up:Unknown_Sequence ;
#     sh:description "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Chain_Annotation_Shape,
#         up:External_Sequence_Shape,
#         up:Modified_Sequence_Shape,
#         up:Peptide_Annotation_Shape,
#         up:Simple_Sequence_Shape,
#         up:Unknown_Sequence_Shape ;
#     sh:path up:sequence .
#
# <http://purl.uniprot.org/core/Part/property/> sh:class up:Structured_Name ;
#     sh:description "alternativeName",
#         "recommended name" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Structured_Name_Shape ;
#     sh:path up:alternativeName,
#         up:recommendedName .
#
# <http://purl.uniprot.org/core/Participant/property/sameAs> sh:class up:Chain_Annotation,
#         up:External_Sequence,
#         up:Modified_Sequence,
#         up:Peptide_Annotation,
#         up:Propeptide_Annotation,
#         up:Protein,
#         up:Simple_Sequence ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Chain_Annotation_Shape,
#         up:External_Sequence_Shape,
#         up:Modified_Sequence_Shape,
#         up:Peptide_Annotation_Shape,
#         up:Propeptide_Annotation_Shape,
#         up:Protein_Shape,
#         up:Simple_Sequence_Shape ;
#     sh:path owl:sameAs .
#
# <http://purl.uniprot.org/core/Pathway/property/narrower> sh:class up:Pathway ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Pathway_Shape ;
#     sh:path skos:narrower .
#
# <http://purl.uniprot.org/core/Pathway/property/subClassOf> sh:class up:Pathway ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Pathway_Shape ;
#     sh:path rdfs:subClassOf .
#
# <http://purl.uniprot.org/core/Pathway_Annotation/property/> sh:class up:Modified_Sequence,
#         up:Simple_Sequence ;
#     sh:description "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Modified_Sequence_Shape,
#         up:Simple_Sequence_Shape ;
#     sh:path up:sequence .
#
# <http://purl.uniprot.org/core/Peptide_Annotation/property/> sh:class faldo:Region ;
#     sh:description "range" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:Region_Shape ;
#     sh:path up:range .
#
# <http://purl.uniprot.org/core/Pharmaceutical_Annotation/property/> sh:class up:Peptide_Annotation ;
#     sh:description "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Peptide_Annotation_Shape ;
#     sh:path up:sequence .
#
# <http://purl.uniprot.org/core/Polymorphism_Annotation/property/> sh:class up:Chain_Annotation,
#         up:Modified_Sequence ;
#     sh:description "sequence" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Chain_Annotation_Shape,
#         up:Modified_Sequence_Shape ;
#     sh:path up:sequence .
#
# <http://purl.uniprot.org/core/Propeptide_Annotation/property/> sh:class faldo:Region ;
#     sh:description "range" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node faldo:Region_Shape ;
#     sh:path up:range .
#
# <http://purl.uniprot.org/core/Protein/property/> sh:class up:Absorption_Annotation,
#         up:Active_Site_Annotation,
#         up:Activity_Regulation_Annotation,
#         up:Allergen_Annotation,
#         up:Alternative_Initiation_Annotation,
#         up:Alternative_Promoter_Usage_Annotation,
#         up:Alternative_Sequence_Annotation,
#         up:Alternative_Splicing_Annotation,
#         up:Annotation,
#         up:Beta_Strand_Annotation,
#         up:Binding_Site_Annotation,
#         up:Biotechnology_Annotation,
#         up:Book_Citation,
#         up:Catalytic_Activity_Annotation,
#         up:Caution_Annotation,
#         up:Chain_Annotation,
#         up:Cofactor_Annotation,
#         up:Coiled_Coil_Annotation,
#         up:Compositional_Bias_Annotation,
#         up:Cross-link_Annotation,
#         up:Developmental_Stage_Annotation,
#         up:Disease_Annotation,
#         up:Disruption_Phenotype_Annotation,
#         up:Disulfide_Bond_Annotation,
#         up:Domain_Annotation,
#         up:Domain_Extent_Annotation,
#         up:Electronic_Citation,
#         up:Erroneous_Gene_Model_Prediction_Annotation,
#         up:Erroneous_Initiation_Annotation,
#         up:Erroneous_Termination_Annotation,
#         up:Erroneous_Translation_Annotation,
#         up:External_Sequence,
#         up:Frameshift_Annotation,
#         up:Function_Annotation,
#         up:Gene,
#         up:Glycosylation_Annotation,
#         up:Helix_Annotation,
#         up:Induction_Annotation,
#         up:Initiator_Methionine_Annotation,
#         up:Interaction,
#         up:Intramembrane_Annotation,
#         up:Journal_Citation,
#         up:Kinetics_Annotation,
#         up:Lipidation_Annotation,
#         up:Mass_Spectrometry_Annotation,
#         up:Modified_Residue_Annotation,
#         up:Modified_Sequence,
#         up:Motif_Annotation,
#         up:Mutagenesis_Annotation,
#         up:Natural_Variant_Annotation,
#         up:Non-adjacent_Residues_Annotation,
#         up:Non-standard_Residue_Annotation,
#         up:Non-terminal_Residue_Annotation,
#         up:Non_Self_Interaction,
#         up:Nucleotide_Binding_Annotation,
#         up:Observation_Citation,
#         up:PH_Dependence_Annotation,
#         up:PTM_Annotation,
#         up:Part,
#         up:Patent_Citation,
#         up:Pathway_Annotation,
#         up:Peptide_Annotation,
#         up:Pharmaceutical_Annotation,
#         up:Plasmid,
#         up:Polymorphism_Annotation,
#         up:Propeptide_Annotation,
#         up:Protein,
#         up:RNA_Editing_Annotation,
#         up:Redox_Potential_Annotation,
#         up:Region_Annotation,
#         up:Repeat_Annotation,
#         up:Ribosomal_Frameshifting,
#         up:Self_Interaction,
#         up:Sequence_Caution_Annotation,
#         up:Sequence_Conflict_Annotation,
#         up:Sequence_Uncertainty_Annotation,
#         up:Signal_Peptide_Annotation,
#         up:Similarity_Annotation,
#         up:Simple_Sequence,
#         up:Site_Annotation,
#         up:Structured_Name,
#         up:Subcellular_Location_Annotation,
#         up:Submission_Citation,
#         up:Subunit_Annotation,
#         up:Temperature_Dependence_Annotation,
#         up:Thesis_Citation,
#         up:Tissue,
#         up:Tissue_Specificity_Annotation,
#         up:Topological_Domain_Annotation,
#         up:Toxic_Dose_Annotation,
#         up:Transit_Peptide_Annotation,
#         up:Transmembrane_Annotation,
#         up:Turn_Annotation,
#         up:Unknown_Sequence,
#         up:Zinc_Finger_Annotation ;
#     sh:description "alternativeName",
#         "annotation",
#         "citation",
#         "conflicting sequence",
#         "domain",
#         "encoded by",
#         "encoded in",
#         "interaction",
#         "isolatedFrom",
#         "potential sequence",
#         "proteome component",
#         "recommended name",
#         "replaced by",
#         "sequence",
#         "submitted name" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Absorption_Annotation_Shape,
#         up:Active_Site_Annotation_Shape,
#         up:Activity_Regulation_Annotation_Shape,
#         up:Allergen_Annotation_Shape,
#         up:Alternative_Initiation_Annotation_Shape,
#         up:Alternative_Promoter_Usage_Annotation_Shape,
#         up:Alternative_Sequence_Annotation_Shape,
#         up:Alternative_Splicing_Annotation_Shape,
#         up:Annotation_Shape,
#         up:Beta_Strand_Annotation_Shape,
#         up:Binding_Site_Annotation_Shape,
#         up:Biotechnology_Annotation_Shape,
#         up:Book_Citation_Shape,
#         up:Catalytic_Activity_Annotation_Shape,
#         up:Caution_Annotation_Shape,
#         up:Chain_Annotation_Shape,
#         up:Cofactor_Annotation_Shape,
#         up:Coiled_Coil_Annotation_Shape,
#         up:Compositional_Bias_Annotation_Shape,
#         up:Cross-link_Annotation_Shape,
#         up:Developmental_Stage_Annotation_Shape,
#         up:Disease_Annotation_Shape,
#         up:Disruption_Phenotype_Annotation_Shape,
#         up:Disulfide_Bond_Annotation_Shape,
#         up:Domain_Annotation_Shape,
#         up:Domain_Extent_Annotation_Shape,
#         up:Electronic_Citation_Shape,
#         up:Erroneous_Gene_Model_Prediction_Annotation_Shape,
#         up:Erroneous_Initiation_Annotation_Shape,
#         up:Erroneous_Termination_Annotation_Shape,
#         up:Erroneous_Translation_Annotation_Shape,
#         up:External_Sequence_Shape,
#         up:Frameshift_Annotation_Shape,
#         up:Function_Annotation_Shape,
#         up:Gene_Shape,
#         up:Glycosylation_Annotation_Shape,
#         up:Helix_Annotation_Shape,
#         up:Induction_Annotation_Shape,
#         up:Initiator_Methionine_Annotation_Shape,
#         up:Interaction_Shape,
#         up:Intramembrane_Annotation_Shape,
#         up:Journal_Citation_Shape,
#         up:Kinetics_Annotation_Shape,
#         up:Lipidation_Annotation_Shape,
#         up:Mass_Spectrometry_Annotation_Shape,
#         up:Modified_Residue_Annotation_Shape,
#         up:Modified_Sequence_Shape,
#         up:Motif_Annotation_Shape,
#         up:Mutagenesis_Annotation_Shape,
#         up:Natural_Variant_Annotation_Shape,
#         up:Non-adjacent_Residues_Annotation_Shape,
#         up:Non-standard_Residue_Annotation_Shape,
#         up:Non-terminal_Residue_Annotation_Shape,
#         up:Non_Self_Interaction_Shape,
#         up:Nucleotide_Binding_Annotation_Shape,
#         up:Observation_Citation_Shape,
#         up:PH_Dependence_Annotation_Shape,
#         up:PTM_Annotation_Shape,
#         up:Part_Shape,
#         up:Patent_Citation_Shape,
#         up:Pathway_Annotation_Shape,
#         up:Peptide_Annotation_Shape,
#         up:Pharmaceutical_Annotation_Shape,
#         up:Plasmid_Shape,
#         up:Polymorphism_Annotation_Shape,
#         up:Propeptide_Annotation_Shape,
#         up:Protein_Shape,
#         up:RNA_Editing_Annotation_Shape,
#         up:Redox_Potential_Annotation_Shape,
#         up:Region_Annotation_Shape,
#         up:Repeat_Annotation_Shape,
#         up:Ribosomal_Frameshifting_Shape,
#         up:Self_Interaction_Shape,
#         up:Sequence_Caution_Annotation_Shape,
#         up:Sequence_Conflict_Annotation_Shape,
#         up:Sequence_Uncertainty_Annotation_Shape,
#         up:Signal_Peptide_Annotation_Shape,
#         up:Similarity_Annotation_Shape,
#         up:Simple_Sequence_Shape,
#         up:Site_Annotation_Shape,
#         up:Structured_Name_Shape,
#         up:Subcellular_Location_Annotation_Shape,
#         up:Submission_Citation_Shape,
#         up:Subunit_Annotation_Shape,
#         up:Temperature_Dependence_Annotation_Shape,
#         up:Thesis_Citation_Shape,
#         up:Tissue_Shape,
#         up:Tissue_Specificity_Annotation_Shape,
#         up:Topological_Domain_Annotation_Shape,
#         up:Toxic_Dose_Annotation_Shape,
#         up:Transit_Peptide_Annotation_Shape,
#         up:Transmembrane_Annotation_Shape,
#         up:Turn_Annotation_Shape,
#         up:Unknown_Sequence_Shape,
#         up:Zinc_Finger_Annotation_Shape ;
#     sh:path up:alternativeName,
#         up:annotation,
#         up:citation,
#         up:component,
#         up:conflictingSequence,
#         up:domain,
#         up:encodedBy,
#         up:encodedIn,
#         up:interaction,
#         up:isolatedFrom,
#         up:potentialSequence,
#         up:recommendedName,
#         up:replacedBy,
#         up:sequence,
#         up:submittedName .
#
# <http://purl.uniprot.org/core/Protein/property/seeAlso> sh:class up:Nucleotide_Resource,
#         up:Resource,
#         up:Structure_Resource,
#         up:Transcript_Resource ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Nucleotide_Resource_Shape,
#         up:Resource_Shape,
#         up:Structure_Resource_Shape,
#         up:Transcript_Resource_Shape ;
#     sh:path rdfs:seeAlso .
#
# <http://purl.uniprot.org/core/Protein_Existence/property/isDefinedBy> sh:class owl:Ontology ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node owl:Ontology_Shape ;
#     sh:path rdfs:isDefinedBy .
#
# <http://purl.uniprot.org/core/Proteome/property/> sh:class up:Book_Citation,
#         up:Journal_Citation,
#         up:Proteome,
#         up:Reference_Proteome,
#         up:Representative_Proteome,
#         up:Strain,
#         up:Submission_Citation ;
#     sh:description "citation",
#         "panproteome",
#         "redundantTo",
#         "strain" ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Book_Citation_Shape,
#         up:Journal_Citation_Shape,
#         up:Proteome_Shape,
#         up:Reference_Proteome_Shape,
#         up:Representative_Proteome_Shape,
#         up:Strain_Shape,
#         up:Submission_Citation_Shape ;
#     sh:path up:citation,
#         up:panproteome,
#         up:redundantTo,
#         up:strain .
#
# <http://purl.uniprot.org/core/Proteome/property/closeMatch> sh:class <http://purl.obolibrary.org/obo/STATO_0000193> ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node <http://purl.obolibrary.org/obo/STATO_0000193_Shape> ;
#     sh:path skos:closeMatch .
#
# <http://purl.uniprot.org/core/Proteome/property/has_score> sh:class <http://busco.ezlab.org/schema#Score> ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node <http://busco.ezlab.org/schema#Score_Shape> ;
#     sh:path <http://busco.ezlab.org/schema#has_score> .
#
# <http://purl.uniprot.org/core/Proteome/property/narrower> sh:class up:Proteome_Component ;
#     sh:maxCount "1"^^xsd:int ;
#     sh:minCount "0"^^xsd:int ;
#     sh:node up:Proteome_Component_Shape ;
#     sh:path skos:narrower .
#
# ...
#     sh:targetClass up:Part .
#
# up:Pathway_Annotation_Shape a sh:NodeShape ;
#     rdfs:label "Pathway annotation" ;
#     sh:property <http://purl.uniprot.org/core/Pathway_Annotation/property/> ;
#     sh:targetClass up:Pathway_Annotation .
#
# up:Pathway_Shape a sh:NodeShape ;
#     rdfs:label "Pathway" ;
#     sh:property <http://purl.uniprot.org/core/Pathway/property/narrower>,
#         <http://purl.uniprot.org/core/Pathway/property/subClassOf> ;
#     sh:targetClass up:Pathway .
#
# up:Pharmaceutical_Annotation_Shape a sh:NodeShape ;
#     rdfs:label "Pharmaceutical" ;
#     sh:property <http://purl.uniprot.org/core/Pharmaceutical_Annotation/property/> ;
#     sh:targetClass up:Pharmaceutical_Annotation .
#
# up:Polymorphism_Annotation_Shape a sh:NodeShape ;
#     rdfs:label "Polymorphism" ;
#     sh:property <http://purl.uniprot.org/core/Polymorphism_Annotation/property/> ;
#     sh:targetClass up:Polymorphism_Annotation .
#
# up:RNA_Editing_Annotation_Shape a sh:NodeShape ;
#     rdfs:label "RNA Editing" ;
#     sh:property <http://purl.uniprot.org/core/RNA_Editing_Annotation/property/>,
#         <http://purl.uniprot.org/core/RNA_Editing_Annotation/property/location> ;
#     sh:targetClass up:RNA_Editing_Annotation .
#
# up:Redox_Potential_Annotation_Shape a sh:NodeShape ;
#     rdfs:label "Redox Potential" ;
#     sh:targetClass up:Redox_Potential_Annotation .
#
# up:Region_Annotation_Shape a sh:NodeShape ;
#     rdfs:label "Region" ;
#     sh:property <http://purl.uniprot.org/core/Region_Annotation/property/> ;
#     sh:targetClass up:Region_Annotation .
#
# up:Repeat_Annotation_Shape a sh:NodeShape ;
#     rdfs:label "Repeat" ;
#     sh:property <http://purl.uniprot.org/core/Repeat_Annotation/property/> ;
#     sh:targetClass up:Repeat_Annotation .
#
# up:Ribosomal_Frameshifting_Shape a sh:NodeShape ;
#     rdfs:label "Ribosomal Frameshifting" ;
#     sh:property <http://purl.uniprot.org/core/Ribosomal_Frameshifting/property/> ;
#     sh:targetClass up:Ribosomal_Frameshifting .
#
# up:Sequence_Caution_Annotation_Shape a sh:NodeShape ;
#     rdfs:label "Sequence Caution" ;
#     sh:property <http://purl.uniprot.org/core/Sequence_Caution_Annotation/property/> ;
#     sh:targetClass up:Sequence_Caution_Annotation .
#
# up:Sequence_Conflict_Annotation_Shape a sh:NodeShape ;
#     rdfs:label "Sequence Conflict" ;
#     sh:property <http://purl.uniprot.org/core/Sequence_Conflict_Annotation/property/> ;
#     sh:targetClass up:Sequence_Conflict_Annotation .
#
# up:Sequence_Uncertainty_Annotation_Shape a sh:NodeShape ;
#     rdfs:label "Unsure Residue" ;
#     sh:property <http://purl.uniprot.org/core/Sequence_Uncertainty_Annotation/property/> ;
#     sh:targetClass up:Sequence_Uncertainty_Annotation .
#
# up:Signal_Peptide_Annotation_Shape a sh:NodeShape ;
#     rdfs:label "Signal Peptide" ;
#     sh:property <http://purl.uniprot.org/core/Signal_Peptide_Annotation/property/> ;
#     sh:targetClass up:Signal_Peptide_Annotation .
#
# up:Similarity_Annotation_Shape a sh:NodeShape ;
#     rdfs:label "Similarity" ;
#     sh:property <http://purl.uniprot.org/core/Similarity_Annotation/property/> ;
#     sh:targetClass up:Similarity_Annotation .
#
# up:Site_Annotation_Shape a sh:NodeShape ;
#     rdfs:label "Site" ;
#     sh:property <http://purl.uniprot.org/core/Site_Annotation/property/> ;
#     sh:targetClass up:Site_Annotation .
#
# up:Subcellular_Location_Annotation_Shape a sh:NodeShape ;
#     rdfs:label "Subcellular Location Annotation" ;
#     sh:property <http://purl.uniprot.org/core/Subcellular_Location_Annotation/property/> ;
#     sh:targetClass up:Subcellular_Location_Annotation .
#
# up:Subunit_Annotation_Shape a sh:NodeShape ;
#     rdfs:label "Subunit" ;
#     sh:property <http://purl.uniprot.org/core/Subunit_Annotation/property/> ;
#     sh:targetClass up:Subunit_Annotation .
#
# up:Temperature_Dependence_Annotation_Shape a sh:NodeShape ;
#     rdfs:label "Temperature Dependence" ;
#     sh:property <http://purl.uniprot.org/core/Temperature_Dependence_Annotation/property/> ;
#     sh:targetClass up:Temperature_Dependence_Annotation .
#
# up:Tissue_Specificity_Annotation_Shape a sh:NodeShape ;
#     rdfs:label "Tissue Specificity" ;
#     sh:property <http://purl.uniprot.org/core/Tissue_Specificity_Annotation/property/> ;
#     sh:targetClass up:Tissue_Specificity_Annotation .
#
# up:Topological_Domain_Annotation_Shape a sh:NodeShape ;
#     rdfs:label "Topological Domain" ;
#     sh:property <http://purl.uniprot.org/core/Topological_Domain_Annotation/property/> ;
#     sh:targetClass up:Topological_Domain_Annotation .
#
# up:Topology_Shape a sh:NodeShape ;
#     rdfs:label "Topology" ;
#     sh:property <http://purl.uniprot.org/core/Topology/property/>,
#         <http://purl.uniprot.org/core/Topology/property/subClassOf> ;
#     sh:targetClass up:Topology .
#
# up:Toxic_Dose_Annotation_Shape a sh:NodeShape ;
#     rdfs:label "Toxic Dose" ;
#     sh:property <http://purl.uniprot.org/core/Toxic_Dose_Annotation/property/> ;
#     sh:targetClass up:Toxic_Dose_Annotation .
#
# up:Transit_Peptide_Annotation_Shape a sh:NodeShape ;
#     rdfs:label "Transit Peptide" ;
#     sh:property <http://purl.uniprot.org/core/Transit_Peptide_Annotation/property/> ;
#     sh:targetClass up:Transit_Peptide_Annotation .
#
# up:Transmembrane_Annotation_Shape a sh:NodeShape ;
#     rdfs:label "Transmembrane" ;
#     sh:property <http://purl.uniprot.org/core/Transmembrane_Annotation/property/> ;
#     sh:targetClass up:Transmembrane_Annotation .
#
# up:Transposon_Shape a sh:NodeShape ;
#     rdfs:label "Transposon" ;
#     sh:targetClass up:Transposon .
#
# up:Turn_Annotation_Shape a sh:NodeShape ;
#     rdfs:label "Turn" ;
#     sh:property <http://purl.uniprot.org/core/Turn_Annotation/property/> ;
#     sh:targetClass up:Turn_Annotation .
#
# up:Zinc_Finger_Annotation_Shape a sh:NodeShape ;
#     rdfs:label "Zinc Finger" ;
#     sh:property <http://purl.uniprot.org/core/Zinc_Finger_Annotation/property/> ;
#     sh:targetClass up:Zinc_Finger_Annotation .
#
# rdf:List_Shape a sh:NodeShape ;
#     sh:property <http://www.w3.org/1999/02/22-rdf-syntax-ns#List/property/rest> ;
#     sh:targetClass rdf:List .
#
# owl:Restriction_Shape a sh:NodeShape ;
#     sh:property <http://www.w3.org/2002/07/owl#Restriction/property/allValuesFrom>,
#         <http://www.w3.org/2002/07/owl#Restriction/property/onClass>,
#         <http://www.w3.org/2002/07/owl#Restriction/property/onProperty>,
#         <http://www.w3.org/2002/07/owl#Restriction/property/someValuesFrom> ;
#     sh:targetClass owl:Restriction .
#
# owl:TransitiveProperty_Shape a sh:NodeShape ;
#     sh:property <http://www.w3.org/2002/07/owl#TransitiveProperty/property/inverseOf> ;
#     sh:targetClass owl:TransitiveProperty .
#
# <http://busco.ezlab.org/schema#Score_Shape> a sh:NodeShape ;
#     sh:targetClass <http://busco.ezlab.org/schema#Score> .
#
# <http://purl.obolibrary.org/obo/STATO_0000193_Shape> a sh:NodeShape ;
#     sh:targetClass <http://purl.obolibrary.org/obo/STATO_0000193> .
#
# up:Catalytic_Activity_Shape a sh:NodeShape ;
#     rdfs:label "Catalytic Activity" ;
#     sh:targetClass up:Catalytic_Activity .
#
# up:Cellular_Component_Shape a sh:NodeShape ;
#     rdfs:label "Cellular Component" ;
#     sh:property <http://purl.uniprot.org/core/Cellular_Component/property/>,
#         <http://purl.uniprot.org/core/Cellular_Component/property/exactMatch>,
#         <http://purl.uniprot.org/core/Cellular_Component/property/subClassOf> ;
#     sh:targetClass up:Cellular_Component .
#
# up:Citation_Shape a sh:NodeShape ;
#     rdfs:label "Citation" ;
#     sh:targetClass up:Citation .
#
# up:Concept_Shape a sh:NodeShape ;
#     rdfs:label "Concept" ;
#     sh:property <http://purl.uniprot.org/core/Concept/property/>,
#         <http://purl.uniprot.org/core/Concept/property/narrower>,
#         <http://purl.uniprot.org/core/Concept/property/seeAlso>,
#         <http://purl.uniprot.org/core/Concept/property/subClassOf> ;
#     sh:targetClass up:Concept .
#
# up:Participant_Shape a sh:NodeShape ;
#     rdfs:label "Interaction participant" ;
#     sh:property <http://purl.uniprot.org/core/Participant/property/sameAs> ;
#     sh:targetClass up:Participant .
#
# up:Propeptide_Annotation_Shape a sh:NodeShape ;
#     rdfs:label "Propeptide" ;
#     sh:property <http://purl.uniprot.org/core/Propeptide_Annotation/property/> ;
#     sh:targetClass up:Propeptide_Annotation .
#
# up:Proteome_Component_Shape a sh:NodeShape ;
#     rdfs:label "Proteome_Component" ;
#     sh:targetClass up:Proteome_Component .
#
# up:Proteome_Shape a sh:NodeShape ;
#     rdfs:label "Proteome" ;
#     sh:property <http://purl.uniprot.org/core/Proteome/property/>,
#         <http://purl.uniprot.org/core/Proteome/property/closeMatch>,
#         <http://purl.uniprot.org/core/Proteome/property/has_score>,
#         <http://purl.uniprot.org/core/Proteome/property/narrower> ;
#     sh:targetClass up:Proteome .
#
# up:Reference_Proteome_Shape a sh:NodeShape ;
#     rdfs:label "Reference_Proteome" ;
#     sh:property <http://purl.uniprot.org/core/Reference_Proteome/property/>,
#         <http://purl.uniprot.org/core/Reference_Proteome/property/closeMatch>,
#         <http://purl.uniprot.org/core/Reference_Proteome/property/has_score>,
#         <http://purl.uniprot.org/core/Reference_Proteome/property/narrower> ;
#     sh:targetClass up:Reference_Proteome .
#
# up:Representative_Proteome_Shape a sh:NodeShape ;
#     rdfs:label "Representative_Proteome" ;
#     sh:property <http://purl.uniprot.org/core/Representative_Proteome/property/>,
#         <http://purl.uniprot.org/core/Representative_Proteome/property/closeMatch>,
#         <http://purl.uniprot.org/core/Representative_Proteome/property/has_score>,
#         <http://purl.uniprot.org/core/Representative_Proteome/property/narrower> ;
#     sh:targetClass up:Representative_Proteome .
#
# up:Structured_Name_Shape a sh:NodeShape ;
#     rdfs:label "Structured_Name" ;
#     sh:targetClass up:Structured_Name .
#
# up:Taxon_Shape a sh:NodeShape ;
#     rdfs:label "Taxon" ;
#     sh:property <http://purl.uniprot.org/core/Taxon/property/>,
#         <http://purl.uniprot.org/core/Taxon/property/narrowerTransitive>,
#         <http://purl.uniprot.org/core/Taxon/property/subClassOf> ;
#     sh:targetClass up:Taxon .
#
# up:Transcript_Resource_Shape a sh:NodeShape ;
#     rdfs:label "Transcript Resource" ;
#     sh:property <http://purl.uniprot.org/core/Transcript_Resource/property/>,
#         <http://purl.uniprot.org/core/Transcript_Resource/property/sameAs>,
#         <http://purl.uniprot.org/core/Transcript_Resource/property/seeAlso> ;
#     sh:targetClass up:Transcript_Resource .
#
# rdfs:Datatype_Shape a sh:NodeShape ;
#     sh:property <http://www.w3.org/2000/01/rdf-schema#Datatype/property/oneOf> ;
#     sh:targetClass rdfs:Datatype .
#
# up:Alternative_Sequence_Annotation_Shape a sh:NodeShape ;
#     rdfs:label "Splice Variant" ;
#     sh:property <http://purl.uniprot.org/core/Alternative_Sequence_Annotation/property/> ;
#     sh:targetClass up:Alternative_Sequence_Annotation .
#
# up:Annotation_Shape a sh:NodeShape ;
#     rdfs:label "Annotation" ;
#     sh:property <http://purl.uniprot.org/core/Annotation/property/> ;
#     sh:targetClass up:Annotation .
#
# up:Enzyme_Shape a sh:NodeShape ;
#     rdfs:label "Enzyme" ;
#     sh:property <http://purl.uniprot.org/core/Enzyme/property/>,
#         <http://purl.uniprot.org/core/Enzyme/property/broaderTransitive>,
#         <http://purl.uniprot.org/core/Enzyme/property/narrowerTransitive>,
#         <http://purl.uniprot.org/core/Enzyme/property/subClassOf> ;
#     sh:targetClass up:Enzyme .
#
# up:Plasmid_Shape a sh:NodeShape ;
#     rdfs:label "Plasmid" ;
#     sh:targetClass up:Plasmid .
#
# up:Protein_Shape a sh:NodeShape ;
#     rdfs:label "Protein" ;
#     sh:property <http://purl.uniprot.org/core/Protein/property/>,
#         <http://purl.uniprot.org/core/Protein/property/seeAlso> ;
#     sh:targetClass up:Protein .
#
# up:Tissue_Shape a sh:NodeShape ;
#     rdfs:label "Tissue" ;
#     sh:targetClass up:Tissue .
#
# owl:DatatypeProperty_Shape a sh:NodeShape ;
#     sh:property <http://www.w3.org/2002/07/owl#DatatypeProperty/property/domain>,
#         <http://www.w3.org/2002/07/owl#DatatypeProperty/property/isDefinedBy>,
#         <http://www.w3.org/2002/07/owl#DatatypeProperty/property/range>,
#         <http://www.w3.org/2002/07/owl#DatatypeProperty/property/subPropertyOf> ;
#     sh:targetClass owl:DatatypeProperty .
#
# owl:ObjectProperty_Shape a sh:NodeShape ;
#     sh:property <http://www.w3.org/2002/07/owl#ObjectProperty/property/domain>,
#         <http://www.w3.org/2002/07/owl#ObjectProperty/property/inverseOf>,
#         <http://www.w3.org/2002/07/owl#ObjectProperty/property/isDefinedBy>,
#         <http://www.w3.org/2002/07/owl#ObjectProperty/property/range>,
#         <http://www.w3.org/2002/07/owl#ObjectProperty/property/subPropertyOf> ;
#     sh:targetClass owl:ObjectProperty .
#
# up:Observation_Citation_Shape a sh:NodeShape ;
#     rdfs:label "Observation Citation" ;
#     sh:targetClass up:Observation_Citation .
#
# up:Patent_Citation_Shape a sh:NodeShape ;
#     rdfs:label "Patent Citation" ;
#     sh:targetClass up:Patent_Citation .
#
# up:Thesis_Citation_Shape a sh:NodeShape ;
#     rdfs:label "Thesis Citation" ;
#     sh:targetClass up:Thesis_Citation .
#
# up:Electronic_Citation_Shape a sh:NodeShape ;
#     rdfs:label "Electronic Citation" ;
#     sh:targetClass up:Electronic_Citation .
#
# up:Strain_Shape a sh:NodeShape ;
#     rdfs:label "Strain",
#         "Taxonomy rank Strain" ;
#     sh:targetClass up:Strain .
#
# up:Book_Citation_Shape a sh:NodeShape ;
#     rdfs:label "Book Citation" ;
#     sh:targetClass up:Book_Citation .
#
# up:Submission_Citation_Shape a sh:NodeShape ;
#     rdfs:label "Submission Citation" ;
#     sh:targetClass up:Submission_Citation .
#
# faldo:ExactPosition_Shape a sh:NodeShape ;
#     sh:property <http://biohackathon.org/resource/faldo#ExactPosition/property/reference> ;
#     sh:targetClass faldo:ExactPosition .
#
# faldo:Position_Shape a sh:NodeShape ;
#     sh:property <http://biohackathon.org/resource/faldo#Position/property/begin>,
#         <http://biohackathon.org/resource/faldo#Position/property/end>,
#         <http://biohackathon.org/resource/faldo#Position/property/possiblePosition>,
#         <http://biohackathon.org/resource/faldo#Position/property/reference> ;
#     sh:targetClass faldo:Position .
#
# up:Journal_Citation_Shape a sh:NodeShape ;
#     rdfs:label "Journal Citation" ;
#     sh:property <http://purl.uniprot.org/core/Journal_Citation/property/> ;
#     sh:targetClass up:Journal_Citation .
#
# up:Unknown_Sequence_Shape a sh:NodeShape ;
#     rdfs:label "Unknown Sequence" ;
#     sh:targetClass up:Unknown_Sequence .
#
# owl:Ontology_Shape a sh:NodeShape ;
#     sh:targetClass owl:Ontology .
#
# owl:Class_Shape a sh:NodeShape ;
#     sh:property <http://www.w3.org/2002/07/owl#Class/property/disjointWith>,
#         <http://www.w3.org/2002/07/owl#Class/property/equivalentClass>,
#         <http://www.w3.org/2002/07/owl#Class/property/isDefinedBy>,
#         <http://www.w3.org/2002/07/owl#Class/property/replaces>,
#         <http://www.w3.org/2002/07/owl#Class/property/seeAlso>,
#         <http://www.w3.org/2002/07/owl#Class/property/subClassOf> ;
#     sh:targetClass owl:Class .
#
# up:Peptide_Annotation_Shape a sh:NodeShape ;
#     rdfs:label "Peptide" ;
#     sh:property <http://purl.uniprot.org/core/Peptide_Annotation/property/> ;
#     sh:targetClass up:Peptide_Annotation .
#
# up:Chain_Annotation_Shape a sh:NodeShape ;
#     rdfs:label "Chain" ;
#     sh:property <http://purl.uniprot.org/core/Chain_Annotation/property/> ;
#     sh:targetClass up:Chain_Annotation .
#
# up:External_Sequence_Shape a sh:NodeShape ;
#     rdfs:label "External Sequence" ;
#     sh:property <http://purl.uniprot.org/core/External_Sequence/property/> ;
#     sh:targetClass up:External_Sequence .
#
# faldo:Region_Shape a sh:NodeShape ;
#     sh:property <http://biohackathon.org/resource/faldo#Region/property/begin>,
#         <http://biohackathon.org/resource/faldo#Region/property/end> ;
#     sh:targetClass faldo:Region .
#
# up:Simple_Sequence_Shape a sh:NodeShape ;
#     rdfs:label "Simple Sequence" ;
#     sh:targetClass up:Simple_Sequence .
#
# up:Modified_Sequence_Shape a sh:NodeShape ;
#     rdfs:label "Modified Sequence" ;
#     sh:property <http://purl.uniprot.org/core/Modified_Sequence/property/> ;
#     sh:targetClass up:Modified_Sequence .
#
#
# 2655
